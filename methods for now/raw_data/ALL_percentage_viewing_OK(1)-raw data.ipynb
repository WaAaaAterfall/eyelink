# %% [raw]
# Trail messages
#
# selfpaced_start_m_start
# selfpaced_start_m_end
#
# forcedmemory_start_pic_0
# forcedmemory_end_pic_0
# 	memory_iti_start
# 	memory_iti_end
#
# forcedmemory_start_pic_1
# forcedmemory_end_pic_1
# 	memory_iti_start
# 	memory_iti_end
#
# forcedmemory_start_pic_2
# forcedmemory_end_pic_2
# 	memory_iti_start
# 	memory_iti_end
#
# forcedmemory_start_pic_3
# forcedmemory_end_pic_3
# 	memory_iti_start
# 	memory_iti_end
#
# delay_start
# delay_end
#
# forcedchoice_start_0
# forcedchoice_end_0
# 	reward_start_0/ punishment_start_
# 	reward_end_0/ punishment_end_
# 	jitter_iti_start_0
# 	jitter_iti_end_0
#
# forcedchoice_start_1
# forcedchoice_end_1
# 	reward_start_1/ punishment_start_
# 	reward_end_1/ punishment_end_
# 	jitter_iti_start_1
# 	jitter_iti_end_1
#
# forcedchoice_start_2
# forcedchoice_end_2
# 	reward_start_2/ punishment_start_
# 	reward_end_2/ punishment_end_
# 	jitter_iti_start_2
# 	jitter_iti_end_2
#
# forcedchoice_start_3
# forcedchoice_end_3
# 	reward_start_3/ punishment_start_
# 	reward_end_3/ punishment_end_
# 	jitter_iti_start_3
# 	jitter_iti_end_3

# %%
import os
import pandas as pd
import numpy as np

# %%
# 定义文件夹路径和文件扩展名
folder_path = r"." #"D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC"
file_extension = ".asc"

# 获取所有ASC文件的路径列表
asc_file_paths = [os.path.join(folder_path, file_name) for file_name in os.listdir(folder_path) if file_name.endswith(file_extension)]
# asc_file_paths

# # 对每个ASC文件执行批处理操作
# for asc_file_path in asc_file_paths:
#     # 执行你要进行的批处理操作
#     # 以下示例操作是将文件复制到一个新文件夹中
#     new_folder_path = os.path.join(folder_path, "processed")
#     os.makedirs(new_folder_path, exist_ok=True)
#     file_name = os.path.basename(asc_file_path)
#     new_file_path = os.path.join(new_folder_path, file_name)
#     shutil.copy(asc_file_path, new_file_path)
# Out:
# ['./J030703.asc',
#  './J030702.asc',
#  './J030701.asc',
#  './J030705.asc',
#  './J030704.asc']

# %%
def is_number(line):
    try: 
        int(line[0])
    except ValueError:
        return False
    return True

def is_msg(line):
    if line[0:3] == 'MSG':
        return True
    return False 

def is_newline(line):
    if line == '' or line == '\n':
        return True
    return False

def is_fix(line):
    if "SFIX" in line or "EFIX" in line:
        return True
    return False

def is_sacc(line):
    if "SSACC" in line or "ESACC" in line:
        return True
    return False

def is_blink(line):
    if "SBLINK" in line or "EBLINK" in line:
        return True
    return False

# %%
file_to_parse = "./J030701.asc"
print("start parsing file %s"%file_to_parse)
file = open(file_to_parse, 'r')
lines = file.read().splitlines(True)
header_split = 0
for i in range(0, len(lines) - 2):
    if is_msg(lines[i]) & is_newline(lines[i+1]) & is_number(lines[i+2]):
        header_split = i + 2
        break

original_removed_header = np.array(lines[header_split:])
print('finish remove header')
# Out:
# start parsing file ./J030701.asc
# finish remove header

# %%
original_size = np.size(original_removed_header)
print(original_size)
# Out:
# 749351

# %%
msg = []
fix = []
sacc = []
blink = []
miss = []
removed_header = original_removed_header

# %%
for i in reversed(range(np.size(removed_header))):
    if is_number(removed_header[i]):
        continue
    else:
        if is_msg(removed_header[i]):
            msg.append(removed_header[i])
        elif is_blink(removed_header[i]):
            blink.append(removed_header[i])
        elif is_fix(removed_header[i]):
            fix.append(removed_header[i])
        elif is_sacc(removed_header[i]):
            sacc.append(removed_header[i])
        else:
            miss.append(removed_header[i])
        removed_header = np.delete(removed_header, i, 0)
print(len(msg) + len(fix) + len(blink) + len(sacc) + len(miss) + np.size(removed_header) == original_size)
# Out:
# True

# %%
len(msg) + len(fix) + len(blink) + len(sacc) + len(miss) + np.size(removed_header)
# Out:
# 749351

# %%
nparr = np.asarray(removed_header)
out_arr = np.char.split(nparr)

# %%
arr = np.asarray([np.array(line) for line in out_arr])
# Out:
# 6

# %%
remove_dot = arr[:, :-1]
pd.DataFrame(remove_dot).to_csv('sample.csv', index_label = "Index", header  = ['Time','x','y','pupil size','CR'])

# %%
print(msg)
for i in range(len(msg)):
    msg[i] = msg[i].replace('\t', ' ')
print(msg)
split_msg = np.char.split(msg)
for i in range(len(split_msg)):
    if len(split_msg[i])>3:
        for str in split_msg[i][3:]:
            split_msg[i][2] += " "
            split_msg[i][2] += str
            split_msg[i].remove(str)
print(split_msg)
np_msg = np.asarray([np.array(line) for line in split_msg])
np_msg
# Out:
# ['MSG 333976184 jitter_iti_end_3\n', 'MSG 333974623 jitter_iti_start_3\n', 'MSG 333972630 reward_end_3\n', 'MSG 333972630 !V CLEAR 0 0 0\n', 'MSG 333970633 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320\n', 'MSG 333970633 reward_start_3\n', 'MSG 333970614 forcedchoice_end_3\n', 'MSG 333970614 !V CLEAR 0 0 0\n', 'MSG 333968914 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333968914 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333968914 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333968914 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333968914 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333968914 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333968914 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1920 251 576 320\n', 'MSG 333968914 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 640 251 576 320\n', 'MSG 333968913 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320\n', 'MSG 333968913 forcedchoice_start_3\n', 'MSG 333968871 target_position : bottom\n', 'MSG 333968868 jitter_iti_end_2\n', 'MSG 333967043 jitter_iti_start_2\n', 'MSG 333965050 reward_end_2\n', 'MSG 333965050 !V CLEAR 0 0 0\n', 'MSG 333963053 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320\n', 'MSG 333963053 reward_start_2\n', 'MSG 333963035 forcedchoice_end_2\n', 'MSG 333963035 !V CLEAR 0 0 0\n', 'MSG 333960593 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333960593 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333960593 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333960593 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333960593 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333960593 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 1920 251 576 320\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 640 251 576 320\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320\n', 'MSG 333960593 forcedchoice_start_2\n', 'MSG 333960550 target_position : bottom\n', 'MSG 333960548 jitter_iti_end_1\n', 'MSG 333958643 jitter_iti_start_1\n', 'MSG 333956649 reward_end_1\n', 'MSG 333956649 !V CLEAR 0 0 0\n', 'MSG 333954652 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320\n', 'MSG 333954652 reward_start_1\n', 'MSG 333954635 forcedchoice_end_1\n', 'MSG 333954635 !V CLEAR 0 0 0\n', 'MSG 333951225 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333951225 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333951225 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333951225 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333951225 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333951225 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 640 251 576 320\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 1280 972 576 320\n', 'MSG 333951225 forcedchoice_start_1\n', 'MSG 333951185 target_position : right\n', 'MSG 333951182 jitter_iti_end_0\n', 'MSG 333948854 jitter_iti_start_0\n', 'MSG 333948854 punishment_end_0\n', 'MSG 333940851 punishment_start_0\n', 'MSG 333940851 forcedchoice_end_0\n', 'MSG 333940851 !V CLEAR 0 0 0\n', 'MSG 333938253 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333938253 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333938253 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333938253 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333938253 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333938253 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333938253 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1920 251 576 320\n', 'MSG 33 ...
# ['MSG 333976184 jitter_iti_end_3\n', 'MSG 333974623 jitter_iti_start_3\n', 'MSG 333972630 reward_end_3\n', 'MSG 333972630 !V CLEAR 0 0 0\n', 'MSG 333970633 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320\n', 'MSG 333970633 reward_start_3\n', 'MSG 333970614 forcedchoice_end_3\n', 'MSG 333970614 !V CLEAR 0 0 0\n', 'MSG 333968914 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333968914 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333968914 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333968914 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333968914 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333968914 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333968914 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1920 251 576 320\n', 'MSG 333968914 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 640 251 576 320\n', 'MSG 333968913 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320\n', 'MSG 333968913 forcedchoice_start_3\n', 'MSG 333968871 target_position : bottom\n', 'MSG 333968868 jitter_iti_end_2\n', 'MSG 333967043 jitter_iti_start_2\n', 'MSG 333965050 reward_end_2\n', 'MSG 333965050 !V CLEAR 0 0 0\n', 'MSG 333963053 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320\n', 'MSG 333963053 reward_start_2\n', 'MSG 333963035 forcedchoice_end_2\n', 'MSG 333963035 !V CLEAR 0 0 0\n', 'MSG 333960593 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333960593 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333960593 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333960593 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333960593 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333960593 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 1920 251 576 320\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 640 251 576 320\n', 'MSG 333960593 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320\n', 'MSG 333960593 forcedchoice_start_2\n', 'MSG 333960550 target_position : bottom\n', 'MSG 333960548 jitter_iti_end_1\n', 'MSG 333958643 jitter_iti_start_1\n', 'MSG 333956649 reward_end_1\n', 'MSG 333956649 !V CLEAR 0 0 0\n', 'MSG 333954652 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320\n', 'MSG 333954652 reward_start_1\n', 'MSG 333954635 forcedchoice_end_1\n', 'MSG 333954635 !V CLEAR 0 0 0\n', 'MSG 333951225 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333951225 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333951225 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333951225 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333951225 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333951225 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 640 251 576 320\n', 'MSG 333951225 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 1280 972 576 320\n', 'MSG 333951225 forcedchoice_start_1\n', 'MSG 333951185 target_position : right\n', 'MSG 333951182 jitter_iti_end_0\n', 'MSG 333948854 jitter_iti_start_0\n', 'MSG 333948854 punishment_end_0\n', 'MSG 333940851 punishment_start_0\n', 'MSG 333940851 forcedchoice_end_0\n', 'MSG 333940851 !V CLEAR 0 0 0\n', 'MSG 333938253 !V DRAWBOX 0 255 0 1845 537 1995 687\n', 'MSG 333938253 !V DRAWBOX 0 255 0 565 537 715 687\n', 'MSG 333938253 !V DRAWBOX 0 255 0 1205 1257 1355 1407\n', 'MSG 333938253 !V IAREA RECTANGLE 3 1632 92 2208 412 right_roi\n', 'MSG 333938253 !V IAREA RECTANGLE 2 352 92 928 412 left_roi\n', 'MSG 333938253 !V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi\n', 'MSG 333938253 !V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1920 251 576 320\n', 'MSG 33 ...
# [list(['MSG', '333976184', 'jitter_iti_end_3'])
#  list(['MSG', '333974623', 'jitter_iti_start_3'])
#  list(['MSG', '333972630', 'reward_end_3'])
#  list(['MSG', '333972630', '!V CLEAR 0 0 0'])
#  list(['MSG', '333970633', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320'])
#  list(['MSG', '333970633', 'reward_start_3'])
#  list(['MSG', '333970614', 'forcedchoice_end_3'])
#  list(['MSG', '333970614', '!V CLEAR 0 0 0'])
#  list(['MSG', '333968914', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333968914', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333968914', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333968914', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333968914', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333968914', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333968914', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1920 251 576 320'])
#  list(['MSG', '333968914', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 640 251 576 320'])
#  list(['MSG', '333968913', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320'])
#  list(['MSG', '333968913', 'forcedchoice_start_3'])
#  list(['MSG', '333968871', 'target_position : bottom'])
#  list(['MSG', '333968868', 'jitter_iti_end_2'])
#  list(['MSG', '333967043', 'jitter_iti_start_2'])
#  list(['MSG', '333965050', 'reward_end_2'])
#  list(['MSG', '333965050', '!V CLEAR 0 0 0'])
#  list(['MSG', '333963053', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320'])
#  list(['MSG', '333963053', 'reward_start_2'])
#  list(['MSG', '333963035', 'forcedchoice_end_2'])
#  list(['MSG', '333963035', '!V CLEAR 0 0 0'])
#  list(['MSG', '333960593', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333960593', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333960593', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333960593', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333960593', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333960593', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333960593', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 1920 251 576 320'])
#  list(['MSG', '333960593', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 640 251 576 320'])
#  list(['MSG', '333960593', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320'])
#  list(['MSG', '333960593', 'forcedchoice_start_2'])
#  list(['MSG', '333960550', 'target_position : bottom'])
#  list(['MSG', '333960548', 'jitter_iti_end_1'])
#  list(['MSG', '333958643', 'jitter_iti_start_1'])
#  list(['MSG', '333956649', 'reward_end_1'])
#  list(['MSG', '333956649', '!V CLEAR 0 0 0'])
#  list(['MSG', '333954652', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333954652', 'reward_start_1'])
#  list(['MSG', '333954635', 'forcedchoice_end_1'])
#  list(['MSG', '333954635', '!V CLEAR 0 0 0'])
#  list(['MSG', '333951225', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333951225', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333951225', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333951225', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333951225', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333951225', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333951225', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333951225', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 640 251 576 320'])
#  list(['MSG', '333951225', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 1280 972 576 320'])
#  list(['MSG', '333951225', 'forcedchoice_start_1'])
#  list(['MSG', '333951185', 'target_position : right'])
#  list(['MSG', '333951182', 'jitter_iti_end_0'])
#  list(['MSG', '333948854', 'jitter_iti_start_0'])
#  list(['MSG', '333948854', 'punishment_end_0'])
#  list(['MSG', '333940851', 'punishment_start_0'])
#  list(['MSG', '333940851', 'forcedchoice_end_0'])
#  list(['MSG', '333940851', '!V CLEAR 0 0 0'])
#  list(['MSG', '333938253', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333938253', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333938253', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333938253', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333938253', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333938253', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333938253', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1920 251 576 320'])
#  list(['MSG', '333938253', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_2.png 640 251 576 320'])
#  list(['MSG', '333938253', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 972 576 320'])
#  list(['MSG', '333938253', 'forcedchoice_start_0'])
#  list(['MSG', '333938220', 'target_position : bottom'])
#  list(['MSG', '333938219', 'delay_end'])
#  list(['MSG', '333937213', 'delay_start'])
#  list(['MSG', '333937213', '!V CLEAR 0 0 0'])
#  list(['MSG', '333937213', 'memory_iti_end'])
#  list(['MSG', '333935203', 'memory_iti_start'])
#  list(['MSG', '333935203', 'forcedmemory_end_pic_3'])
#  list(['MSG', '333935203', '!V CLEAR 0 0 0'])
#  list(['MSG', '333930213', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333930213', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 720 576 320'])
#  list(['MSG', '333930212', 'forcedmemory_start_pic_3'])
#  list(['MSG', '333930202', 'memory_iti_end'])
#  list(['MSG', '333928192', 'memory_iti_start'])
#  list(['MSG', '333928192', 'forcedmemory_end_pic_2'])
#  list(['MSG', '333928192', '!V CLEAR 0 0 0'])
#  list(['MSG', '333923192', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333923192', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 720 576 320'])
#  list(['MSG', '333923192', 'forcedmemory_start_pic_2'])
#  list(['MSG', '333923178', 'memory_iti_end'])
#  list(['MSG', '333921168', 'memory_iti_start'])
#  list(['MSG', '333921168', 'forcedmemory_end_pic_1'])
#  list(['MSG', '333921168', '!V CLEAR 0 0 0'])
#  list(['MSG', '333916169', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333916168', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 720 576 320'])
#  list(['MSG', '333916168', 'forcedmemory_start_pic_1'])
#  list(['MSG', '333916154', 'memory_iti_end'])
#  list(['MSG', '333914143', 'memory_iti_start'])
#  list(['MSG', '333914143', 'forcedmemory_end_pic_0'])
#  list(['MSG', '333914143', '!V CLEAR 0 0 0'])
#  list(['MSG', '333909142', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333909142', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1280 720 576 320'])
#  list(['MSG', '333909142', 'forcedmemory_start_pic_0'])
#  list(['MSG', '333909129', 'selfpaced_start_m_end'])
#  list(['MSG', '333908116', 'selfpaced_start_m_start'])
#  list(['MSG', '333908116', 'EYE_USED 1 RIGHT'])
#  list(['MSG', '333907981', '!MODE RECORD CR 2000 2 1 R'])
#  list(['MSG', '333907980', 'ELCL_EFIT_PARAMS 1.01 4.00 0.15 0.05 0.65 0.65 0.00 0.00 0.30'])
#  list(['MSG', '333907980', 'ELCL_PROC ELLIPSE (5)'])
#  list(['MSG', '333907980', 'PUPIL_DATA_TYPE RAW_AUTOSLIP'])
#  list(['MSG', '333907980', 'CAMERA_LENS_FOCAL_LENGTH 27.00'])
#  list(['MSG', '333907980', 'ELCL_WINDOW_SIZES 160 160 0 0'])
#  list(['MSG', '333907980', 'THRESHOLDS R 65 201'])
#  list(['MSG', '333907980', 'GAZE_COORDS 0.00 0.00 2559.00 1439.00'])
#  list(['MSG', '333907980', 'ELCLCFG MPRIM'])
#  list(['MSG', '333907980', 'RECCFG CR 2000 2 1 R'])
#  list(['MSG', '333907939', 'jitter_iti_end_3'])
#  list(['MSG', '333906563', 'jitter_iti_start_3'])
#  list(['MSG', '333906563', 'punishment_end_3'])
#  list(['MSG', '333898560', 'punishment_start_3'])
#  list(['MSG', '333898559', 'forcedchoice_end_3'])
#  list(['MSG', '333898559', '!V CLEAR 0 0 0'])
#  list(['MSG', '333895646', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333895646', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333895646', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333895646', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333895646', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333895646', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333895646', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_2.png 1920 251 576 320'])
#  list(['MSG', '333895646', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 640 251 576 320'])
#  list(['MSG', '333895646', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1280 972 576 320'])
#  list(['MSG', '333895646', 'forcedchoice_start_3'])
#  list(['MSG', '333895612', 'target_position : left'])
#  list(['MSG', '333895610', 'jitter_iti_end_2'])
#  list(['MSG', '333894366', 'jitter_iti_start_2'])
#  list(['MSG', '333894366', 'punishment_end_2'])
#  list(['MSG', '333886363', 'punishment_start_2'])
#  list(['MSG', '333886363', 'forcedchoice_end_2'])
#  list(['MSG', '333886363', '!V CLEAR 0 0 0'])
#  list(['MSG', '333884040', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333884040', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333884040', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333884040', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333884040', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333884040', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333884040', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1920 251 576 320'])
#  list(['MSG', '333884040', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 640 251 576 320'])
#  list(['MSG', '333884040', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 1280 972 576 320'])
#  list(['MSG', '333884040', 'forcedchoice_start_2'])
#  list(['MSG', '333883998', 'target_position : right'])
#  list(['MSG', '333883995', 'jitter_iti_end_1'])
#  list(['MSG', '333882011', 'jitter_iti_start_1'])
#  list(['MSG', '333880017', 'reward_end_1'])
#  list(['MSG', '333880017', '!V CLEAR 0 0 0'])
#  list(['MSG', '333878020', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333878020', 'reward_start_1'])
#  list(['MSG', '333878002', 'forcedchoice_end_1'])
#  list(['MSG', '333878002', '!V CLEAR 0 0 0'])
#  list(['MSG', '333876815', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333876815', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333876815', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333876815', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333876815', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333876815', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333876815', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333876815', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 640 251 576 320'])
#  list(['MSG', '333876815', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 1280 972 576 320'])
#  list(['MSG', '333876814', 'forcedchoice_start_1'])
#  list(['MSG', '333876775', 'target_position : right'])
#  list(['MSG', '333876772', 'jitter_iti_end_0'])
#  list(['MSG', '333874669', 'jitter_iti_start_0'])
#  list(['MSG', '333874669', 'punishment_end_0'])
#  list(['MSG', '333866666', 'punishment_start_0'])
#  list(['MSG', '333866666', 'forcedchoice_end_0'])
#  list(['MSG', '333866666', '!V CLEAR 0 0 0'])
#  list(['MSG', '333865149', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333865149', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333865149', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333865149', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333865149', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333865149', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333865149', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1920 251 576 320'])
#  list(['MSG', '333865149', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 640 251 576 320'])
#  list(['MSG', '333865149', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 1280 972 576 320'])
#  list(['MSG', '333865149', 'forcedchoice_start_0'])
#  list(['MSG', '333865107', 'target_position : right'])
#  list(['MSG', '333865105', 'delay_end'])
#  list(['MSG', '333864100', 'delay_start'])
#  list(['MSG', '333864100', '!V CLEAR 0 0 0'])
#  list(['MSG', '333864100', 'memory_iti_end'])
#  list(['MSG', '333862090', 'memory_iti_start'])
#  list(['MSG', '333862090', 'forcedmemory_end_pic_3'])
#  list(['MSG', '333862090', '!V CLEAR 0 0 0'])
#  list(['MSG', '333857090', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333857090', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 720 576 320'])
#  list(['MSG', '333857090', 'forcedmemory_start_pic_3'])
#  list(['MSG', '333857075', 'memory_iti_end'])
#  list(['MSG', '333855065', 'memory_iti_start'])
#  list(['MSG', '333855065', 'forcedmemory_end_pic_2'])
#  list(['MSG', '333855065', '!V CLEAR 0 0 0'])
#  list(['MSG', '333850065', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333850065', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 720 576 320'])
#  list(['MSG', '333850065', 'forcedmemory_start_pic_2'])
#  list(['MSG', '333850051', 'memory_iti_end'])
#  list(['MSG', '333848041', 'memory_iti_start'])
#  list(['MSG', '333848041', 'forcedmemory_end_pic_1'])
#  list(['MSG', '333848041', '!V CLEAR 0 0 0'])
#  list(['MSG', '333843040', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333843040', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1280 720 576 320'])
#  list(['MSG', '333843040', 'forcedmemory_start_pic_1'])
#  list(['MSG', '333843027', 'memory_iti_end'])
#  list(['MSG', '333841017', 'memory_iti_start'])
#  list(['MSG', '333841017', 'forcedmemory_end_pic_0'])
#  list(['MSG', '333841017', '!V CLEAR 0 0 0'])
#  list(['MSG', '333836026', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333836026', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 720 576 320'])
#  list(['MSG', '333836026', 'forcedmemory_start_pic_0'])
#  list(['MSG', '333836015', 'selfpaced_start_m_end'])
#  list(['MSG', '333835007', 'selfpaced_start_m_start'])
#  list(['MSG', '333835007', 'EYE_USED 1 RIGHT'])
#  list(['MSG', '333834869', '!MODE RECORD CR 2000 2 1 R'])
#  list(['MSG', '333834868', 'ELCL_EFIT_PARAMS 1.01 4.00 0.15 0.05 0.65 0.65 0.00 0.00 0.30'])
#  list(['MSG', '333834868', 'ELCL_PROC ELLIPSE (5)'])
#  list(['MSG', '333834868', 'PUPIL_DATA_TYPE RAW_AUTOSLIP'])
#  list(['MSG', '333834868', 'CAMERA_LENS_FOCAL_LENGTH 27.00'])
#  list(['MSG', '333834868', 'ELCL_WINDOW_SIZES 160 160 0 0'])
#  list(['MSG', '333834868', 'THRESHOLDS R 65 201'])
#  list(['MSG', '333834868', 'GAZE_COORDS 0.00 0.00 2559.00 1439.00'])
#  list(['MSG', '333834868', 'ELCLCFG MPRIM'])
#  list(['MSG', '333834868', 'RECCFG CR 2000 2 1 R'])
#  list(['MSG', '333834825', 'jitter_iti_end_3'])
#  list(['MSG', '333833291', 'jitter_iti_start_3'])
#  list(['MSG', '333833291', 'punishment_end_3'])
#  list(['MSG', '333825287', 'punishment_start_3'])
#  list(['MSG', '333825287', 'forcedchoice_end_3'])
#  list(['MSG', '333825287', '!V CLEAR 0 0 0'])
#  list(['MSG', '333822184', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333822184', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333822184', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333822184', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333822183', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333822183', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333822183', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1920 251 576 320'])
#  list(['MSG', '333822183', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 640 251 576 320'])
#  list(['MSG', '333822183', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 972 576 320'])
#  list(['MSG', '333822183', 'forcedchoice_start_3'])
#  list(['MSG', '333822141', 'target_position : bottom'])
#  list(['MSG', '333822139', 'jitter_iti_end_2'])
#  list(['MSG', '333820671', 'jitter_iti_start_2'])
#  list(['MSG', '333820671', 'punishment_end_2'])
#  list(['MSG', '333812668', 'punishment_start_2'])
#  list(['MSG', '333812668', 'forcedchoice_end_2'])
#  list(['MSG', '333812668', '!V CLEAR 0 0 0'])
#  list(['MSG', '333809310', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333809310', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333809310', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333809310', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333809310', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333809310', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333809310', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333809310', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 640 251 576 320'])
#  list(['MSG', '333809310', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 1280 972 576 320'])
#  list(['MSG', '333809310', 'forcedchoice_start_2'])
#  list(['MSG', '333809271', 'target_position : right'])
#  list(['MSG', '333809268', 'jitter_iti_end_1'])
#  list(['MSG', '333806741', 'jitter_iti_start_1'])
#  list(['MSG', '333806741', 'punishment_end_1'])
#  list(['MSG', '333798738', 'punishment_start_1'])
#  list(['MSG', '333798738', 'forcedchoice_end_1'])
#  list(['MSG', '333798738', '!V CLEAR 0 0 0'])
#  list(['MSG', '333795293', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333795293', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333795293', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333795293', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333795293', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333795293', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333795293', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 1920 251 576 320'])
#  list(['MSG', '333795293', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 640 251 576 320'])
#  list(['MSG', '333795293', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 1280 972 576 320'])
#  list(['MSG', '333795293', 'forcedchoice_start_1'])
#  list(['MSG', '333795248', 'target_position : left'])
#  list(['MSG', '333795246', 'jitter_iti_end_0'])
#  list(['MSG', '333794267', 'jitter_iti_start_0'])
#  list(['MSG', '333794267', 'punishment_end_0'])
#  list(['MSG', '333786263', 'punishment_start_0'])
#  list(['MSG', '333786263', 'forcedchoice_end_0'])
#  list(['MSG', '333786263', '!V CLEAR 0 0 0'])
#  list(['MSG', '333783890', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333783890', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333783890', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333783890', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333783890', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333783890', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333783890', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1920 251 576 320'])
#  list(['MSG', '333783890', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 640 251 576 320'])
#  list(['MSG', '333783890', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_2.png 1280 972 576 320'])
#  list(['MSG', '333783890', 'forcedchoice_start_0'])
#  list(['MSG', '333783857', 'target_position : left'])
#  list(['MSG', '333783856', 'delay_end'])
#  list(['MSG', '333782850', 'delay_start'])
#  list(['MSG', '333782850', '!V CLEAR 0 0 0'])
#  list(['MSG', '333782850', 'memory_iti_end'])
#  list(['MSG', '333780841', 'memory_iti_start'])
#  list(['MSG', '333780840', 'forcedmemory_end_pic_3'])
#  list(['MSG', '333780840', '!V CLEAR 0 0 0'])
#  list(['MSG', '333775840', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333775840', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1280 720 576 320'])
#  list(['MSG', '333775840', 'forcedmemory_start_pic_3'])
#  list(['MSG', '333775827', 'memory_iti_end'])
#  list(['MSG', '333773816', 'memory_iti_start'])
#  list(['MSG', '333773816', 'forcedmemory_end_pic_2'])
#  list(['MSG', '333773816', '!V CLEAR 0 0 0'])
#  list(['MSG', '333768826', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333768826', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 720 576 320'])
#  list(['MSG', '333768825', 'forcedmemory_start_pic_2'])
#  list(['MSG', '333768815', 'memory_iti_end'])
#  list(['MSG', '333766805', 'memory_iti_start'])
#  list(['MSG', '333766805', 'forcedmemory_end_pic_1'])
#  list(['MSG', '333766805', '!V CLEAR 0 0 0'])
#  list(['MSG', '333761805', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333761805', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 720 576 320'])
#  list(['MSG', '333761805', 'forcedmemory_start_pic_1'])
#  list(['MSG', '333761791', 'memory_iti_end'])
#  list(['MSG', '333759781', 'memory_iti_start'])
#  list(['MSG', '333759781', 'forcedmemory_end_pic_0'])
#  list(['MSG', '333759781', '!V CLEAR 0 0 0'])
#  list(['MSG', '333754781', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333754781', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 720 576 320'])
#  list(['MSG', '333754781', 'forcedmemory_start_pic_0'])
#  list(['MSG', '333754766', 'selfpaced_start_m_end'])
#  list(['MSG', '333753637', 'selfpaced_start_m_start'])
#  list(['MSG', '333753637', 'EYE_USED 1 RIGHT'])
#  list(['MSG', '333753500', '!MODE RECORD CR 2000 2 1 R'])
#  list(['MSG', '333753499', 'ELCL_EFIT_PARAMS 1.01 4.00 0.15 0.05 0.65 0.65 0.00 0.00 0.30'])
#  list(['MSG', '333753499', 'ELCL_PROC ELLIPSE (5)'])
#  list(['MSG', '333753499', 'PUPIL_DATA_TYPE RAW_AUTOSLIP'])
#  list(['MSG', '333753499', 'CAMERA_LENS_FOCAL_LENGTH 27.00'])
#  list(['MSG', '333753499', 'ELCL_WINDOW_SIZES 160 160 0 0'])
#  list(['MSG', '333753499', 'THRESHOLDS R 65 201'])
#  list(['MSG', '333753499', 'GAZE_COORDS 0.00 0.00 2559.00 1439.00'])
#  list(['MSG', '333753499', 'ELCLCFG MPRIM'])
#  list(['MSG', '333753499', 'RECCFG CR 2000 2 1 R'])
#  list(['MSG', '333753457', 'jitter_iti_end_3'])
#  list(['MSG', '333750996', 'jitter_iti_start_3'])
#  list(['MSG', '333749003', 'reward_end_3'])
#  list(['MSG', '333749003', '!V CLEAR 0 0 0'])
#  list(['MSG', '333747007', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1920 251 576 320'])
#  list(['MSG', '333747007', 'reward_start_3'])
#  list(['MSG', '333746988', 'forcedchoice_end_3'])
#  list(['MSG', '333746988', '!V CLEAR 0 0 0'])
#  list(['MSG', '333743805', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333743805', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333743805', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333743805', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333743805', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333743805', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333743805', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1920 251 576 320'])
#  list(['MSG', '333743805', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 640 251 576 320'])
#  list(['MSG', '333743805', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1280 972 576 320'])
#  list(['MSG', '333743805', 'forcedchoice_start_3'])
#  list(['MSG', '333743763', 'target_position : right'])
#  list(['MSG', '333743761', 'jitter_iti_end_2'])
#  list(['MSG', '333742332', 'jitter_iti_start_2'])
#  list(['MSG', '333742332', 'punishment_end_2'])
#  list(['MSG', '333734329', 'punishment_start_2'])
#  list(['MSG', '333734328', 'forcedchoice_end_2'])
#  list(['MSG', '333734328', '!V CLEAR 0 0 0'])
#  list(['MSG', '333731369', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333731369', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333731369', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333731369', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333731369', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333731369', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333731369', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333731369', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 640 251 576 320'])
#  list(['MSG', '333731368', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 1280 972 576 320'])
#  list(['MSG', '333731368', 'forcedchoice_start_2'])
#  list(['MSG', '333731328', 'target_position : right'])
#  list(['MSG', '333731326', 'jitter_iti_end_1'])
#  list(['MSG', '333729698', 'jitter_iti_start_1'])
#  list(['MSG', '333729698', 'punishment_end_1'])
#  list(['MSG', '333721695', 'punishment_start_1'])
#  list(['MSG', '333721695', 'forcedchoice_end_1'])
#  list(['MSG', '333721695', '!V CLEAR 0 0 0'])
#  list(['MSG', '333717382', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333717382', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333717382', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333717382', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333717382', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333717382', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333717382', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 1920 251 576 320'])
#  list(['MSG', '333717382', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 640 251 576 320'])
#  list(['MSG', '333717382', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_2.png 1280 972 576 320'])
#  list(['MSG', '333717382', 'forcedchoice_start_1'])
#  list(['MSG', '333717349', 'target_position : left'])
#  list(['MSG', '333717343', 'jitter_iti_end_0'])
#  list(['MSG', '333716113', 'jitter_iti_start_0'])
#  list(['MSG', '333716113', 'punishment_end_0'])
#  list(['MSG', '333708110', 'punishment_start_0'])
#  list(['MSG', '333708110', 'forcedchoice_end_0'])
#  list(['MSG', '333708110', '!V CLEAR 0 0 0'])
#  list(['MSG', '333706885', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333706885', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333706885', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333706885', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333706885', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333706885', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333706885', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 1920 251 576 320'])
#  list(['MSG', '333706885', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 640 251 576 320'])
#  list(['MSG', '333706885', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320'])
#  list(['MSG', '333706885', 'forcedchoice_start_0'])
#  list(['MSG', '333706841', 'target_position : bottom'])
#  list(['MSG', '333706840', 'delay_end'])
#  list(['MSG', '333705835', 'delay_start'])
#  list(['MSG', '333705835', '!V CLEAR 0 0 0'])
#  list(['MSG', '333705835', 'memory_iti_end'])
#  list(['MSG', '333703825', 'memory_iti_start'])
#  list(['MSG', '333703825', 'forcedmemory_end_pic_3'])
#  list(['MSG', '333703825', '!V CLEAR 0 0 0'])
#  list(['MSG', '333698834', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333698834', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 720 576 320'])
#  list(['MSG', '333698834', 'forcedmemory_start_pic_3'])
#  list(['MSG', '333698823', 'memory_iti_end'])
#  list(['MSG', '333696813', 'memory_iti_start'])
#  list(['MSG', '333696813', 'forcedmemory_end_pic_2'])
#  list(['MSG', '333696813', '!V CLEAR 0 0 0'])
#  list(['MSG', '333691814', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333691814', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 720 576 320'])
#  list(['MSG', '333691814', 'forcedmemory_start_pic_2'])
#  list(['MSG', '333691799', 'memory_iti_end'])
#  list(['MSG', '333689790', 'memory_iti_start'])
#  list(['MSG', '333689790', 'forcedmemory_end_pic_1'])
#  list(['MSG', '333689790', '!V CLEAR 0 0 0'])
#  list(['MSG', '333684789', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333684789', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 720 576 320'])
#  list(['MSG', '333684789', 'forcedmemory_start_pic_1'])
#  list(['MSG', '333684775', 'memory_iti_end'])
#  list(['MSG', '333682765', 'memory_iti_start'])
#  list(['MSG', '333682765', 'forcedmemory_end_pic_0'])
#  list(['MSG', '333682765', '!V CLEAR 0 0 0'])
#  list(['MSG', '333677763', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333677763', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1280 720 576 320'])
#  list(['MSG', '333677763', 'forcedmemory_start_pic_0'])
#  list(['MSG', '333677750', 'selfpaced_start_m_end'])
#  list(['MSG', '333676072', 'selfpaced_start_m_start'])
#  list(['MSG', '333676072', 'EYE_USED 1 RIGHT'])
#  list(['MSG', '333675931', '!MODE RECORD CR 2000 2 1 R'])
#  list(['MSG', '333675930', 'ELCL_EFIT_PARAMS 1.01 4.00 0.15 0.05 0.65 0.65 0.00 0.00 0.30'])
#  list(['MSG', '333675930', 'ELCL_PROC ELLIPSE (5)'])
#  list(['MSG', '333675930', 'PUPIL_DATA_TYPE RAW_AUTOSLIP'])
#  list(['MSG', '333675930', 'CAMERA_LENS_FOCAL_LENGTH 27.00'])
#  list(['MSG', '333675930', 'ELCL_WINDOW_SIZES 160 160 0 0'])
#  list(['MSG', '333675930', 'THRESHOLDS R 65 201'])
#  list(['MSG', '333675930', 'GAZE_COORDS 0.00 0.00 2559.00 1439.00'])
#  list(['MSG', '333675930', 'ELCLCFG MPRIM'])
#  list(['MSG', '333675930', 'RECCFG CR 2000 2 1 R'])
#  list(['MSG', '333675885', 'jitter_iti_end_3'])
#  list(['MSG', '333675171', 'jitter_iti_start_3'])
#  list(['MSG', '333673177', 'reward_end_3'])
#  list(['MSG', '333673177', '!V CLEAR 0 0 0'])
#  list(['MSG', '333671180', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333671180', 'reward_start_3'])
#  list(['MSG', '333671163', 'forcedchoice_end_3'])
#  list(['MSG', '333671163', '!V CLEAR 0 0 0'])
#  list(['MSG', '333664029', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333664029', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333664029', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333664029', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333664029', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333664029', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333664029', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1920 251 576 320'])
#  list(['MSG', '333664029', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_2.png 640 251 576 320'])
#  list(['MSG', '333664029', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_1.png 1280 972 576 320'])
#  list(['MSG', '333664029', 'forcedchoice_start_3'])
#  list(['MSG', '333663969', 'target_position : right'])
#  list(['MSG', '333663967', 'jitter_iti_end_2'])
#  list(['MSG', '333662022', 'jitter_iti_start_2'])
#  list(['MSG', '333662022', 'punishment_end_2'])
#  list(['MSG', '333654019', 'punishment_start_2'])
#  list(['MSG', '333654019', 'forcedchoice_end_2'])
#  list(['MSG', '333654019', '!V CLEAR 0 0 0'])
#  list(['MSG', '333652452', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333652452', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333652452', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333652452', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333652452', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333652452', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333652452', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_2.png 1920 251 576 320'])
#  list(['MSG', '333652452', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 640 251 576 320'])
#  list(['MSG', '333652452', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_1.png 1280 972 576 320'])
#  list(['MSG', '333652452', 'forcedchoice_start_2'])
#  list(['MSG', '333652381', 'target_position : left'])
#  list(['MSG', '333652379', 'jitter_iti_end_1'])
#  list(['MSG', '333650698', 'jitter_iti_start_1'])
#  list(['MSG', '333648705', 'reward_end_1'])
#  list(['MSG', '333648705', '!V CLEAR 0 0 0'])
#  list(['MSG', '333646707', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 972 576 320'])
#  list(['MSG', '333646707', 'reward_start_1'])
#  list(['MSG', '333646690', 'forcedchoice_end_1'])
#  list(['MSG', '333646690', '!V CLEAR 0 0 0'])
#  list(['MSG', '333645280', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333645280', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333645280', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333645280', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333645280', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333645280', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333645280', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_2.png 1920 251 576 320'])
#  list(['MSG', '333645280', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_3.png 640 251 576 320'])
#  list(['MSG', '333645280', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 972 576 320'])
#  list(['MSG', '333645280', 'forcedchoice_start_1'])
#  list(['MSG', '333645237', 'target_position : bottom'])
#  list(['MSG', '333645209', 'jitter_iti_end_0'])
#  list(['MSG', '333643555', 'jitter_iti_start_0'])
#  list(['MSG', '333643555', 'punishment_end_0'])
#  list(['MSG', '333635552', 'punishment_start_0'])
#  list(['MSG', '333635552', 'forcedchoice_end_0'])
#  list(['MSG', '333635552', '!V CLEAR 0 0 0'])
#  list(['MSG', '333634238', '!V DRAWBOX 0 255 0 1845 537 1995 687'])
#  list(['MSG', '333634238', '!V DRAWBOX 0 255 0 565 537 715 687'])
#  list(['MSG', '333634238', '!V DRAWBOX 0 255 0 1205 1257 1355 1407'])
#  list(['MSG', '333634238', '!V IAREA RECTANGLE 3 1632 92 2208 412 right_roi'])
#  list(['MSG', '333634238', '!V IAREA RECTANGLE 2 352 92 928 412 left_roi'])
#  list(['MSG', '333634238', '!V IAREA RECTANGLE 1 992 812 1568 1132 bottom_roi'])
#  list(['MSG', '333634238', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_3.png 1920 251 576 320'])
#  list(['MSG', '333634238', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_1.png 640 251 576 320'])
#  list(['MSG', '333634238', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 972 576 320'])
#  list(['MSG', '333634238', 'forcedchoice_start_0'])
#  list(['MSG', '333634174', 'target_position : bottom'])
#  list(['MSG', '333634163', 'delay_end'])
#  list(['MSG', '333633158', 'delay_start'])
#  list(['MSG', '333633158', '!V CLEAR 0 0 0'])
#  list(['MSG', '333633158', 'memory_iti_end'])
#  list(['MSG', '333631148', 'memory_iti_start'])
#  list(['MSG', '333631148', 'forcedmemory_end_pic_3'])
#  list(['MSG', '333631148', '!V CLEAR 0 0 0'])
#  list(['MSG', '333626153', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333626153', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\770_3.png 1280 720 576 320'])
#  list(['MSG', '333626153', 'forcedmemory_start_pic_3'])
#  list(['MSG', '333626120', 'memory_iti_end'])
#  list(['MSG', '333624110', 'memory_iti_start'])
#  list(['MSG', '333624110', 'forcedmemory_end_pic_2'])
#  list(['MSG', '333624110', '!V CLEAR 0 0 0'])
#  list(['MSG', '333619109', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333619109', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\1065_1.png 1280 720 576 320'])
#  list(['MSG', '333619109', 'forcedmemory_start_pic_2'])
#  list(['MSG', '333619070', 'memory_iti_end'])
#  list(['MSG', '333617060', 'memory_iti_start'])
#  list(['MSG', '333617060', 'forcedmemory_end_pic_1'])
#  list(['MSG', '333617060', '!V CLEAR 0 0 0'])
#  list(['MSG', '333612058', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333612058', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\682_3.png 1280 720 576 320'])
#  list(['MSG', '333612058', 'forcedmemory_start_pic_1'])
#  list(['MSG', '333612019', 'memory_iti_end'])
#  list(['MSG', '333610009', 'memory_iti_start'])
#  list(['MSG', '333610009', 'forcedmemory_end_pic_0'])
#  list(['MSG', '333610009', '!V CLEAR 0 0 0'])
#  list(['MSG', '333605015', '!V IAREA RECTANGLE 9 992 560 1568 880 memory_roi'])
#  list(['MSG', '333605015', '!V IMGLOAD CENTER F:\\Pic_TOJ\\pic_pool_step_3_formal\\782_2.png 1280 720 576 320'])
#  list(['MSG', '333605015', 'forcedmemory_start_pic_0'])
#  list(['MSG', '333604981', 'selfpaced_start_m_end'])
#  list(['MSG', '333603697', 'selfpaced_start_m_start'])
#  list(['MSG', '333603697', 'EYE_USED 1 RIGHT'])]
# array([['MSG', '333976184', 'jitter_iti_end_3'],
#        ['MSG', '333974623', 'jitter_iti_start_3'],
#        ['MSG', '333972630', 'reward_end_3'],
#        ...,
#        ['MSG', '333604981', 'selfpaced_start_m_end'],
#        ['MSG', '333603697', 'selfpaced_start_m_start'],
#        ['MSG', '333603697', 'EYE_USED 1 RIGHT']], dtype='<U79')

# %%
pd.DataFrame(np_msg).to_csv('msg.csv', index_label = "Index", header  = ['Type','Time','Desceiption'])

# %%
print(fix)
for i in range(len(fix)):
    fix[i] = fix[i].replace('\t', ' ')
split_fix = np.char.split(fix)
print(np.shape(split_fix)[0])
for i in reversed(range(np.shape(split_fix)[0])):
    if split_fix[i][0] == "SFIX":
        split_fix = np.delete(split_fix, i, 0)
print(split_fix)
# Out:
# ['EFIX R   333976098 333976193 95  1228.1   706.9    5106\n', 'SFIX R   333976098\n', 'EFIX R   333975752 333976046 294   517.3   471.5    4888\n', 'SFIX R   333975752\n', 'EFIX R   333975447 333975685 238  1276.7   712.5    5342\n', 'SFIX R   333975447\n', 'EFIX R   333975234 333975426 192  1312.2   700.5    5243\n', 'SFIX R   333975234\n', 'EFIX R   333974940 333975184 244   674.2   438.0    5087\n', 'SFIX R   333974940\n', 'EFIX R   333974646 333974878 232  1273.8   714.7    5255\n', 'SFIX R   333974646\n', 'EFIX R   333974456 333974626 170  1305.1   748.7    5225\n', 'SFIX R   333974456\n', 'EFIX R   333974233 333974404 171  2011.7   247.4    4836\n', 'SFIX R   333974233\n', 'EFIX R   333973409 333974165 756  2332.5  1102.5    4713\n', 'SFIX R   333973409\n', 'EFIX R   333972822 333973144 322  1256.9   725.9    4529\n', 'SFIX R   333972822\n', 'EFIX R   333972141 333972785 644  1055.0   919.6    4360\n', 'SFIX R   333972141\n', 'EFIX R   333971675 333972101 426  1503.3   830.2    4295\n', 'SFIX R   333971675\n', 'EFIX R   333971450 333971622 172  1079.4   902.5    4540\n', 'SFIX R   333971450\n', 'EFIX R   333971165 333971412 247  1454.3   942.2    4894\n', 'SFIX R   333971165\n', 'EFIX R   333970963 333971128 165  1268.4  1345.6    4988\n', 'SFIX R   333970963\n', 'EFIX R   333970187 333970953 766  1263.8  1335.7    4719\n', 'SFIX R   333970187\n', 'EFIX R   333969873 333970176 303  1259.7  1366.1    4352\n', 'SFIX R   333969873\n', 'EFIX R   333969618 333969864 246  1279.3  1358.2    4136\n', 'SFIX R   333969618\n', 'EFIX R   333969377 333969560 183   567.9   622.8    3686\n', 'SFIX R   333969377\n', 'EFIX R   333969183 333969360 177   599.7   602.6    3915\n', 'SFIX R   333969183\n', 'EFIX R   333968316 333969125 809  1261.9   705.6    5190\n', 'SFIX R   333968316\n', 'EFIX R   333967975 333968309 334  1280.1   716.3    5284\n', 'SFIX R   333967975\n', 'EFIX R   333967709 333967955 246  1305.5   690.6    5313\n', 'SFIX R   333967709\n', 'EFIX R   333967250 333967623 373  2384.2  1687.5    4486\n', 'SFIX R   333967250\n', 'EFIX R   333966385 333967141 756  1986.6   669.7    5081\n', 'SFIX R   333966385\n', 'EFIX R   333965962 333966255 293  1501.5  1278.8    5170\n', 'SFIX R   333965962\n', 'EFIX R   333965334 333965656 322  1263.0   714.7    4730\n', 'SFIX R   333965334\n', 'EFIX R   333964880 333965300 420  1192.6   868.9    4524\n', 'SFIX R   333964880\n', 'EFIX R   333964634 333964843 209  1445.7  1128.2    4346\n', 'SFIX R   333964634\n', 'EFIX R   333964331 333964586 255  1518.6   861.2    4291\n', 'SFIX R   333964331\n', 'EFIX R   333964019 333964277 258  1092.9   961.0    4553\n', 'SFIX R   333964019\n', 'EFIX R   333963730 333963991 261  1037.9   872.6    4564\n', 'SFIX R   333963730\n', 'EFIX R   333963460 333963699 239  1247.7   914.0    4951\n', 'SFIX R   333963460\n', 'EFIX R   333962036 333963422 1386  1258.4  1350.9    4614\n', 'SFIX R   333962036\n', 'EFIX R   333961637 333961977 340  1970.0   568.3    3918\n', 'SFIX R   333961637\n', 'EFIX R   333961477 333961614 137  1937.5   556.8    3995\n', 'SFIX R   333961477\n', 'EFIX R   333961163 333961425 262  1267.7  1374.4    3874\n', 'SFIX R   333961163\n', 'EFIX R   333960969 333961143 174  1259.1  1339.4    3678\n', 'SFIX R   333960969\n', 'EFIX R   333960798 333960931 133  1204.7   926.5    4504\n', 'SFIX R   333960798\n', 'EFIX R   333960572 333960749 177  1245.5   631.0    5208\n', 'SFIX R   333960572\n', 'EFIX R   333960220 333960512 292   374.9   387.7    5082\n', 'SFIX R   333960220\n', 'EFIX R   333959942 333960141 199  1274.6   711.9    5268\n', 'SFIX R   333959942\n', 'EFIX R   333959732 333959923 191  1314.9   735.5    5144\n', 'SFIX R   333959732\n', 'EFIX R   333959462 333959681 219   518.7   361.1    4913\n', 'SFIX R   333959462\n', 'EFIX R   333958809 333959382 573  1268.5   710.8    5156\n', 'SFIX R   333958809\n', 'EFIX R   333958556 333958795 239  1302.0   701.8    5232\n', 'SFIX R   333958556\n', 'EFIX R   333958362 333958513 151  1338.8   ...
# 1836
# [list(['EFIX', 'R', '333976098', '333976193', '95', '1228.1', '706.9', '5106'])
#  list(['EFIX', 'R', '333975752', '333976046', '294', '517.3', '471.5', '4888'])
#  list(['EFIX', 'R', '333975447', '333975685', '238', '1276.7', '712.5', '5342'])
#  list(['EFIX', 'R', '333975234', '333975426', '192', '1312.2', '700.5', '5243'])
#  list(['EFIX', 'R', '333974940', '333975184', '244', '674.2', '438.0', '5087'])
#  list(['EFIX', 'R', '333974646', '333974878', '232', '1273.8', '714.7', '5255'])
#  list(['EFIX', 'R', '333974456', '333974626', '170', '1305.1', '748.7', '5225'])
#  list(['EFIX', 'R', '333974233', '333974404', '171', '2011.7', '247.4', '4836'])
#  list(['EFIX', 'R', '333973409', '333974165', '756', '2332.5', '1102.5', '4713'])
#  list(['EFIX', 'R', '333972822', '333973144', '322', '1256.9', '725.9', '4529'])
#  list(['EFIX', 'R', '333972141', '333972785', '644', '1055.0', '919.6', '4360'])
#  list(['EFIX', 'R', '333971675', '333972101', '426', '1503.3', '830.2', '4295'])
#  list(['EFIX', 'R', '333971450', '333971622', '172', '1079.4', '902.5', '4540'])
#  list(['EFIX', 'R', '333971165', '333971412', '247', '1454.3', '942.2', '4894'])
#  list(['EFIX', 'R', '333970963', '333971128', '165', '1268.4', '1345.6', '4988'])
#  list(['EFIX', 'R', '333970187', '333970953', '766', '1263.8', '1335.7', '4719'])
#  list(['EFIX', 'R', '333969873', '333970176', '303', '1259.7', '1366.1', '4352'])
#  list(['EFIX', 'R', '333969618', '333969864', '246', '1279.3', '1358.2', '4136'])
#  list(['EFIX', 'R', '333969377', '333969560', '183', '567.9', '622.8', '3686'])
#  list(['EFIX', 'R', '333969183', '333969360', '177', '599.7', '602.6', '3915'])
#  list(['EFIX', 'R', '333968316', '333969125', '809', '1261.9', '705.6', '5190'])
#  list(['EFIX', 'R', '333967975', '333968309', '334', '1280.1', '716.3', '5284'])
#  list(['EFIX', 'R', '333967709', '333967955', '246', '1305.5', '690.6', '5313'])
#  list(['EFIX', 'R', '333967250', '333967623', '373', '2384.2', '1687.5', '4486'])
#  list(['EFIX', 'R', '333966385', '333967141', '756', '1986.6', '669.7', '5081'])
#  list(['EFIX', 'R', '333965962', '333966255', '293', '1501.5', '1278.8', '5170'])
#  list(['EFIX', 'R', '333965334', '333965656', '322', '1263.0', '714.7', '4730'])
#  list(['EFIX', 'R', '333964880', '333965300', '420', '1192.6', '868.9', '4524'])
#  list(['EFIX', 'R', '333964634', '333964843', '209', '1445.7', '1128.2', '4346'])
#  list(['EFIX', 'R', '333964331', '333964586', '255', '1518.6', '861.2', '4291'])
#  list(['EFIX', 'R', '333964019', '333964277', '258', '1092.9', '961.0', '4553'])
#  list(['EFIX', 'R', '333963730', '333963991', '261', '1037.9', '872.6', '4564'])
#  list(['EFIX', 'R', '333963460', '333963699', '239', '1247.7', '914.0', '4951'])
#  list(['EFIX', 'R', '333962036', '333963422', '1386', '1258.4', '1350.9', '4614'])
#  list(['EFIX', 'R', '333961637', '333961977', '340', '1970.0', '568.3', '3918'])
#  list(['EFIX', 'R', '333961477', '333961614', '137', '1937.5', '556.8', '3995'])
#  list(['EFIX', 'R', '333961163', '333961425', '262', '1267.7', '1374.4', '3874'])
#  list(['EFIX', 'R', '333960969', '333961143', '174', '1259.1', '1339.4', '3678'])
#  list(['EFIX', 'R', '333960798', '333960931', '133', '1204.7', '926.5', '4504'])
#  list(['EFIX', 'R', '333960572', '333960749', '177', '1245.5', '631.0', '5208'])
#  list(['EFIX', 'R', '333960220', '333960512', '292', '374.9', '387.7', '5082'])
#  list(['EFIX', 'R', '333959942', '333960141', '199', '1274.6', '711.9', '5268'])
#  list(['EFIX', 'R', '333959732', '333959923', '191', '1314.9', '735.5', '5144'])
#  list(['EFIX', 'R', '333959462', '333959681', '219', '518.7', '361.1', '4913'])
#  list(['EFIX', 'R', '333958809', '333959382', '573', '1268.5', '710.8', '5156'])
#  list(['EFIX', 'R', '333958556', '333958795', '239', '1302.0', '701.8', '5232'])
#  list(['EFIX', 'R', '333958362', '333958513', '151', '1338.8', '1102.7', '5309'])
#  list(['EFIX', 'R', '333957625', '333958272', '647', '2199.9', '557.9', '4683'])
#  list(['EFIX', 'R', '333957090', '333957375', '285', '1276.2', '722.1', '5099'])
#  list(['EFIX', 'R', '333956853', '333957070', '217', '1271.4', '681.7', '4848'])
#  list(['EFIX', 'R', '333956487', '333956812', '325', '1677.2', '136.5', '4497'])
#  list(['EFIX', 'R', '333956169', '333956455', '286', '1782.5', '276.3', '4482'])
#  list(['EFIX', 'R', '333955922', '333956123', '201', '1392.6', '653.8', '4365'])
#  list(['EFIX', 'R', '333955547', '333955863', '316', '1122.4', '1403.6', '3984'])
#  list(['EFIX', 'R', '333955418', '333955508', '90', '1088.7', '1157.5', '4019'])
#  list(['EFIX', 'R', '333955351', '333955401', '50', '1093.3', '1130.4', '4349'])
#  list(['EFIX', 'R', '333954934', '333955113', '179', '1946.7', '592.9', '4689'])
#  list(['EFIX', 'R', '333953782', '333954926', '1144', '1958.7', '577.3', '4250'])
#  list(['EFIX', 'R', '333953638', '333953761', '123', '1921.1', '562.1', '4087'])
#  list(['EFIX', 'R', '333953267', '333953571', '304', '570.5', '605.4', '4112'])
#  list(['EFIX', 'R', '333953073', '333953259', '186', '571.0', '621.6', '3738'])
#  list(['EFIX', 'R', '333952899', '333953028', '129', '909.5', '824.4', '3576'])
#  list(['EFIX', 'R', '333952584', '333952866', '282', '1016.9', '977.4', '3499'])
#  list(['EFIX', 'R', '333952390', '333952551', '161', '1299.4', '1064.6', '3876'])
#  list(['EFIX', 'R', '333952120', '333952379', '259', '1313.4', '1038.1', '3618'])
#  list(['EFIX', 'R', '333951924', '333952081', '157', '1254.8', '1368.1', '3406'])
#  list(['EFIX', 'R', '333951642', '333951888', '246', '1381.3', '1031.6', '3455'])
#  list(['EFIX', 'R', '333951449', '333951617', '168', '1288.8', '1003.8', '4049'])
#  list(['EFIX', 'R', '333951264', '333951401', '137', '1284.2', '730.9', '5109'])
#  list(['EFIX', 'R', '333950607', '333951255', '648', '1278.8', '709.0', '5306'])
#  list(['EFIX', 'R', '333950375', '333950587', '212', '1340.0', '721.2', '5413'])
#  list(['EFIX', 'R', '333950062', '333950319', '257', '703.9', '302.7', '5269'])
#  list(['EFIX', 'R', '333949539', '333949795', '256', '330.4', '722.8', '5374'])
#  list(['EFIX', 'R', '333948851', '333949463', '612', '1269.9', '714.6', '5203'])
#  list(['EFIX', 'R', '333948440', '333948842', '402', '1285.8', '708.8', '5287'])
#  list(['EFIX', 'R', '333948113', '333948433', '320', '1290.3', '721.5', '5360'])
#  list(['EFIX', 'R', '333947691', '333948042', '351', '1289.9', '708.5', '5413'])
#  list(['EFIX', 'R', '333947522', '333947667', '145', '1220.2', '653.6', '5345'])
#  list(['EFIX', 'R', '333947231', '333947463', '232', '1213.2', '116.0', '5218'])
#  list(['EFIX', 'R', '333946916', '333947145', '229', '2160.7', '493.4', '4875'])
#  list(['EFIX', 'R', '333946347', '333946752', '405', '1314.2', '684.0', '5411'])
#  list(['EFIX', 'R', '333945964', '333946315', '351', '1381.6', '766.9', '5477'])
#  list(['EFIX', 'R', '333945350', '333945896', '546', '1859.3', '1387.5', '5256'])
#  list(['EFIX', 'R', '333943971', '333945272', '1301', '1355.7', '769.7', '5304'])
#  list(['EFIX', 'R', '333943805', '333943906', '101', '2064.3', '1722.8', '4436'])
#  list(['EFIX', 'R', '333941128', '333941412', '284', '1285.2', '707.4', '4898'])
#  list(['EFIX', 'R', '333940655', '333941081', '426', '580.5', '611.2', '4380'])
#  list(['EFIX', 'R', '333939853', '333940644', '791', '579.0', '633.5', '4190'])
#  list(['EFIX', 'R', '333939580', '333939815', '235', '584.8', '341.2', '3977'])
#  list(['EFIX', 'R', '333939291', '333939550', '259', '401.8', '168.3', '4003'])
#  list(['EFIX', 'R', '333939092', '333939277', '185', '405.1', '191.2', '3821'])
#  list(['EFIX', 'R', '333938901', '333939060', '159', '717.4', '209.0', '3669'])
#  list(['EFIX', 'R', '333938696', '333938871', '175', '791.5', '335.8', '3779'])
#  list(['EFIX', 'R', '333938502', '333938649', '147', '1302.0', '962.8', '4329'])
#  list(['EFIX', 'R', '333938291', '333938471', '180', '1293.2', '702.4', '5058'])
#  list(['EFIX', 'R', '333937929', '333938240', '311', '746.2', '388.1', '4732'])
#  list(['EFIX', 'R', '333937431', '333937878', '447', '1257.5', '704.2', '5083'])
#  list(['EFIX', 'R', '333937084', '333937423', '339', '1260.7', '675.4', '5128'])
#  list(['EFIX', 'R', '333936701', '333937035', '334', '587.5', '555.8', '4755'])
#  list(['EFIX', 'R', '333936451', '333936633', '182', '1256.6', '693.9', '4205'])
#  list(['EFIX', 'R', '333936165', '333936426', '261', '1192.0', '687.9', '3649'])
#  list(['EFIX', 'R', '333935856', '333936106', '250', '1800.5', '148.7', '4230'])
#  list(['EFIX', 'R', '333935224', '333935824', '600', '1686.8', '52.4', '4585'])
#  list(['EFIX', 'R', '333934731', '333935146', '415', '2498.3', '493.8', '4309'])
#  list(['EFIX', 'R', '333934066', '333934671', '605', '2463.1', '1145.5', '4399'])
#  list(['EFIX', 'R', '333933350', '333934010', '660', '2264.0', '503.1', '4322'])
#  list(['EFIX', 'R', '333932737', '333933244', '507', '1638.0', '877.3', '4853'])
#  list(['EFIX', 'R', '333932409', '333932687', '278', '1483.2', '1434.1', '4482'])
#  list(['EFIX', 'R', '333932079', '333932359', '280', '1564.9', '842.5', '4297'])
#  list(['EFIX', 'R', '333931806', '333932039', '233', '1351.3', '796.5', '4358'])
#  list(['EFIX', 'R', '333931532', '333931772', '240', '1242.6', '794.4', '4135'])
#  list(['EFIX', 'R', '333931282', '333931465', '183', '1542.2', '-4.7', '3737'])
#  list(['EFIX', 'R', '333930847', '333931211', '364', '1156.8', '730.0', '3939'])
#  list(['EFIX', 'R', '333930645', '333930819', '174', '1273.5', '613.2', '3632'])
#  list(['EFIX', 'R', '333930459', '333930611', '152', '1123.5', '737.7', '4223'])
#  list(['EFIX', 'R', '333928414', '333929085', '671', '1259.2', '710.2', '3957'])
#  list(['EFIX', 'R', '333928175', '333928390', '215', '1237.0', '792.5', '3453'])
#  list(['EFIX', 'R', '333927882', '333928149', '267', '1250.7', '719.1', '3754'])
#  list(['EFIX', 'R', '333927613', '333927868', '255', '1238.8', '682.6', '3550'])
#  list(['EFIX', 'R', '333927183', '333927578', '395', '1073.1', '622.5', '3451'])
#  list(['EFIX', 'R', '333926950', '333927152', '202', '1246.4', '637.2', '3718'])
#  list(['EFIX', 'R', '333926668', '333926927', '259', '1221.0', '608.8', '4040'])
#  list(['EFIX', 'R', '333926441', '333926646', '205', '1162.8', '610.0', '4147'])
#  list(['EFIX', 'R', '333926238', '333926396', '158', '1468.3', '628.5', '3951'])
#  list(['EFIX', 'R', '333925980', '333926198', '218', '1060.3', '623.2', '3442'])
#  list(['EFIX', 'R', '333925769', '333925957', '188', '1069.7', '668.8', '2919'])
#  list(['EFIX', 'R', '333925518', '333925713', '195', '1082.1', '1483.8', '3654'])
#  list(['EFIX', 'R', '333924938', '333925439', '501', '1458.3', '586.9', '3459'])
#  list(['EFIX', 'R', '333924656', '333924888', '232', '1688.2', '192.2', '3669'])
#  list(['EFIX', 'R', '333923898', '333924593', '695', '1567.8', '702.2', '3999'])
#  list(['EFIX', 'R', '333923486', '333923871', '385', '1490.1', '625.9', '4083'])
#  list(['EFIX', 'R', '333923327', '333923455', '128', '1321.8', '703.9', '5244'])
#  list(['EFIX', 'R', '333922396', '333923130', '734', '2734.4', '1393.4', '4210'])
#  list(['EFIX', 'R', '333921760', '333922337', '577', '2419.1', '905.1', '4508'])
#  list(['EFIX', 'R', '333921255', '333921693', '438', '2518.6', '340.6', '3817'])
#  list(['EFIX', 'R', '333920521', '333921210', '689', '2248.8', '478.1', '3870'])
#  list(['EFIX', 'R', '333919966', '333920453', '487', '1751.4', '691.9', '3357'])
#  list(['EFIX', 'R', '333919561', '333919900', '339', '1949.8', '1466.6', '2748'])
#  list(['EFIX', 'R', '333919160', '333919494', '334', '1153.3', '1368.0', '2936'])
#  list(['EFIX', 'R', '333918839', '333919126', '287', '1012.1', '1391.3', '3168'])
#  list(['EFIX', 'R', '333918420', '333918771', '351', '1325.0', '617.0', '3293'])
#  list(['EFIX', 'R', '333918155', '333918366', '211', '1276.5', '1475.7', '3498'])
#  list(['EFIX', 'R', '333917558', '333918090', '532', '1222.5', '569.0', '3781'])
#  list(['EFIX', 'R', '333917252', '333917523', '271', '1014.4', '593.6', '3755'])
#  list(['EFIX', 'R', '333917018', '333917223', '205', '1100.5', '682.9', '3854'])
#  list(['EFIX', 'R', '333916736', '333917001', '265', '1134.1', '685.1', '3675'])
#  list(['EFIX', 'R', '333916565', '333916710', '145', '1200.4', '578.8', '3202'])
#  list(['EFIX', 'R', '333916387', '333916539', '152', '1183.5', '660.1', '3211'])
#  list(['EFIX', 'R', '333916084', '333916324', '240', '85.7', '168.9', '2989'])
#  list(['EFIX', 'R', '333915933', '333915975', '42', '-180.6', '211.8', '3229'])
#  list(['EFIX', 'R', '333915832', '333915875', '43', '-174.0', '232.5', '3405'])
#  list(['EFIX', 'R', '333915589', '333915621', '32', '263.1', '643.1', '4056'])
#  list(['EFIX', 'R', '333915387', '333915556', '169', '283.3', '632.5', '4495'])
#  list(['EFIX', 'R', '333914754', '333915179', '425', '1395.4', '59.2', '4143'])
#  list(['EFIX', 'R', '333914389', '333914690', '301', '1243.9', '687.4', '3420'])
#  list(['EFIX', 'R', '333914101', '333914358', '257', '1403.5', '681.0', '3078'])
#  list(['EFIX', 'R', '333913795', '333914086', '291', '1410.0', '712.0', '3244'])
#  list(['EFIX', 'R', '333913537', '333913768', '231', '1492.2', '712.5', '3298'])
#  list(['EFIX', 'R', '333913304', '333913517', '213', '1551.1', '707.8', '3135'])
#  list(['EFIX', 'R', '333912680', '333913275', '595', '1416.1', '691.5', '3359'])
#  list(['EFIX', 'R', '333912463', '333912636', '173', '1007.0', '643.2', '3147'])
#  list(['EFIX', 'R', '333912139', '333912426', '287', '1371.2', '671.3', '3232'])
#  list(['EFIX', 'R', '333911893', '333912108', '215', '1459.4', '621.3', '3455'])
#  list(['EFIX', 'R', '333911608', '333911873', '265', '1496.2', '650.6', '3808'])
#  list(['EFIX', 'R', '333911429', '333911577', '148', '1449.5', '860.9', '3682'])
#  list(['EFIX', 'R', '333911087', '333911399', '312', '1281.5', '842.0', '3398'])
#  list(['EFIX', 'R', '333910830', '333911059', '229', '1142.6', '803.7', '3212'])
#  list(['EFIX', 'R', '333910562', '333910807', '245', '1213.8', '785.5', '3225'])
#  list(['EFIX', 'R', '333910226', '333910543', '317', '1239.0', '758.4', '3074'])
#  list(['EFIX', 'R', '333909632', '333910201', '569', '1153.5', '726.0', '3197'])
#  list(['EFIX', 'R', '333909354', '333909615', '261', '1169.2', '766.5', '3879'])
#  list(['EFIX', 'R', '333908417', '333909326', '909', '1276.3', '710.1', '5340'])
#  list(['EFIX', 'R', '333908118', '333908402', '284', '1271.8', '698.5', '5411'])
#  list(['EFIX', 'R', '333907988', '333908055', '67', '473.2', '397.4', '5132'])
#  list(['EFIX', 'R', '333907763', '333907941', '178', '458.7', '381.5', '5137'])
#  list(['EFIX', 'R', '333907385', '333907682', '297', '1263.6', '718.6', '5151'])
#  list(['EFIX', 'R', '333907195', '333907364', '169', '1333.5', '710.0', '5479'])
#  list(['EFIX', 'R', '333906953', '333907131', '178', '2171.3', '550.1', '5089'])
#  list(['EFIX', 'R', '333906119', '333906927', '808', '2244.2', '426.1', '4948'])
#  list(['EFIX', 'R', '333905716', '333906079', '363', '2187.6', '233.9', '4828'])
#  list(['EFIX', 'R', '333904943', '333905659', '716', '2424.8', '691.3', '4741'])
#  list(['EFIX', 'R', '333904470', '333904824', '354', '1373.5', '715.7', '5181'])
#  list(['EFIX', 'R', '333903787', '333904435', '648', '1265.8', '717.1', '4931'])
#  list(['EFIX', 'R', '333903480', '333903778', '298', '1287.2', '703.3', '5159'])
#  list(['EFIX', 'R', '333902984', '333903468', '484', '1291.1', '711.9', '5447'])
#  list(['EFIX', 'R', '333902668', '333902951', '283', '1218.3', '677.0', '5780'])
#  list(['EFIX', 'R', '333902222', '333902275', '53', '113.9', '1800.1', '5242'])
#  list(['EFIX', 'R', '333901986', '333902095', '109', '118.2', '1805.6', '5131'])
#  list(['EFIX', 'R', '333901708', '333901962', '254', '114.6', '1781.4', '5136'])
#  list(['EFIX', 'R', '333901553', '333901698', '145', '116.4', '1781.7', '5040'])
#  list(['EFIX', 'R', '333901438', '333901507', '69', '422.6', '1546.8', '5209'])
#  list(['EFIX', 'R', '333901241', '333901423', '182', '414.4', '1538.6', '5064'])
#  list(['EFIX', 'R', '333901066', '333901117', '51', '391.8', '1563.1', '5099'])
#  list(['EFIX', 'R', '333900682', '333900957', '275', '1030.6', '712.7', '5205'])
#  list(['EFIX', 'R', '333900256', '333900597', '341', '1942.5', '148.5', '4952'])
#  list(['EFIX', 'R', '333899726', '333900150', '424', '1330.8', '722.5', '5374'])
#  list(['EFIX', 'R', '333899522', '333899678', '156', '635.0', '725.5', '5575'])
#  list(['EFIX', 'R', '333898829', '333899289', '460', '1310.3', '707.2', '5224'])
#  list(['EFIX', 'R', '333897561', '333898780', '1219', '1954.6', '587.1', '4257'])
#  list(['EFIX', 'R', '333897228', '333897509', '281', '1336.6', '935.2', '4547'])
#  list(['EFIX', 'R', '333896532', '333897188', '656', '1277.5', '1347.0', '4753'])
#  list(['EFIX', 'R', '333896394', '333896508', '114', '1302.9', '1289.5', '4459'])
#  list(['EFIX', 'R', '333896059', '333896340', '281', '585.6', '638.4', '4118'])
#  list(['EFIX', 'R', '333895884', '333896027', '143', '756.8', '328.2', '4407'])
#  list(['EFIX', 'R', '333895666', '333895833', '167', '1591.6', '50.5', '5098'])
#  list(['EFIX', 'R', '333894700', '333895597', '897', '1747.6', '890.6', '5108'])
#  list(['EFIX', 'R', '333894039', '333894647', '608', '1269.6', '731.0', '4861'])
#  list(['EFIX', 'R', '333893816', '333894029', '213', '1274.4', '729.8', '4394'])
#  list(['EFIX', 'R', '333893503', '333893775', '272', '1784.6', '1017.5', '3592'])
#  list(['EFIX', 'R', '333892793', '333893449', '656', '1066.4', '1456.8', '4508'])
#  list(['EFIX', 'R', '333892315', '333892737', '422', '1295.0', '721.8', '5150'])
#  list(['EFIX', 'R', '333891813', '333892296', '483', '1255.0', '723.6', '5166'])
#  list(['EFIX', 'R', '333890875', '333891797', '922', '1296.9', '702.8', '5213'])
#  list(['EFIX', 'R', '333890578', '333890862', '284', '1288.5', '717.1', '5400'])
#  list(['EFIX', 'R', '333890255', '333890511', '256', '2154.6', '1600.9', '4732'])
#  list(['EFIX', 'R', '333889397', '333890194', '797', '2191.4', '845.6', '5185'])
#  list(['EFIX', 'R', '333888242', '333889354', '1112', '2165.4', '612.8', '5073'])
#  list(['EFIX', 'R', '333887329', '333888179', '850', '1842.9', '298.3', '5053'])
#  list(['EFIX', 'R', '333886657', '333887093', '436', '1279.2', '726.9', '5274'])
#  list(['EFIX', 'R', '333885536', '333886610', '1074', '1268.1', '1335.7', '4631'])
#  list(['EFIX', 'R', '333885362', '333885520', '158', '1266.3', '1378.2', '4432'])
#  list(['EFIX', 'R', '333885014', '333885298', '284', '1961.7', '562.0', '3914'])
#  list(['EFIX', 'R', '333884852', '333884997', '145', '1948.1', '536.8', '3821'])
#  list(['EFIX', 'R', '333884421', '333884797', '376', '1263.5', '1380.4', '3562'])
#  list(['EFIX', 'R', '333884291', '333884389', '98', '1278.9', '1159.7', '4240'])
#  list(['EFIX', 'R', '333884078', '333884240', '162', '1273.3', '701.8', '5235'])
#  list(['EFIX', 'R', '333883772', '333884027', '255', '683.3', '343.4', '5088'])
#  list(['EFIX', 'R', '333883441', '333883709', '268', '181.9', '1124.2', '5101'])
#  list(['EFIX', 'R', '333882988', '333883275', '287', '1266.6', '709.8', '5100'])
#  list(['EFIX', 'R', '333882662', '333882976', '314', '1275.9', '711.8', '5046'])
#  list(['EFIX', 'R', '333882284', '333882610', '326', '1986.2', '368.9', '4751'])
#  list(['EFIX', 'R', '333881436', '333882222', '786', '2504.2', '795.8', '4706'])
#  list(['EFIX', 'R', '333880891', '333881354', '463', '2254.1', '1136.4', '4952'])
#  list(['EFIX', 'R', '333880274', '333880601', '327', '1304.6', '708.8', '4937'])
#  list(['EFIX', 'R', '333879991', '333880228', '237', '1689.1', '378.1', '4375'])
#  list(['EFIX', 'R', '333879615', '333879960', '345', '1770.6', '309.1', '4289'])
#  list(['EFIX', 'R', '333879298', '333879590', '292', '1843.2', '269.7', '4318'])
#  list(['EFIX', 'R', '333879096', '333879263', '167', '1854.0', '100.3', '4200'])
#  list(['EFIX', 'R', '333878859', '333879063', '204', '1667.1', '142.5', '4623'])
#  list(['EFIX', 'R', '333878562', '333878826', '264', '1841.5', '258.9', '4645'])
#  list(['EFIX', 'R', '333877588', '333878524', '936', '1963.8', '573.8', '4067'])
#  list(['EFIX', 'R', '333877258', '333877576', '318', '1964.4', '594.8', '3882'])
#  list(['EFIX', 'R', '333877008', '333877244', '236', '1972.4', '559.2', '4096'])
#  list(['EFIX', 'R', '333876003', '333876959', '956', '2266.2', '730.6', '4372'])
#  list(['EFIX', 'R', '333875586', '333875913', '327', '1268.7', '688.6', '3679'])
#  list(['EFIX', 'R', '333875358', '333875569', '211', '1238.2', '632.4', '2868'])
#  list(['EFIX', 'R', '333874987', '333875271', '284', '245.3', '1603.2', '2756'])
#  list(['EFIX', 'R', '333874795', '333874945', '150', '-196.7', '1457.5', '3004'])
#  list(['EFIX', 'R', '333874514', '333874760', '246', '-151.0', '1458.2', '3868'])
#  list(['EFIX', 'R', '333874187', '333874395', '208', '1268.6', '705.4', '5073'])
#  list(['EFIX', 'R', '333873942', '333874153', '211', '1188.9', '698.6', '5113'])
#  list(['EFIX', 'R', '333873567', '333873865', '298', '-12.4', '1663.9', '4785'])
#  list(['EFIX', 'R', '333873168', '333873493', '325', '129.4', '638.9', '4948'])
#  list(['EFIX', 'R', '333872323', '333873048', '725', '1261.6', '708.8', '4766'])
#  list(['EFIX', 'R', '333871404', '333872308', '904', '1262.6', '699.6', '4748'])
#  list(['EFIX', 'R', '333871110', '333871374', '264', '1273.3', '718.6', '4130'])
#  list(['EFIX', 'R', '333870888', '333871056', '168', '1797.1', '371.1', '4464'])
#  list(['EFIX', 'R', '333870064', '333870819', '755', '1273.8', '715.8', '4742'])
#  list(['EFIX', 'R', '333869833', '333870054', '221', '1241.1', '713.7', '4261'])
#  list(['EFIX', 'R', '333869563', '333869811', '248', '1227.1', '650.9', '3685'])
#  list(['EFIX', 'R', '333869099', '333869489', '390', '535.6', '1581.7', '4370'])
#  list(['EFIX', 'R', '333868742', '333869041', '299', '436.8', '1939.7', '4203'])
#  list(['EFIX', 'R', '333868689', '333868731', '42', '428.8', '1948.4', '3831'])
#  list(['EFIX', 'R', '333868126', '333868632', '506', '59.3', '1633.7', '3389'])
#  list(['EFIX', 'R', '333867597', '333868032', '435', '154.7', '674.4', '4496'])
#  list(['EFIX', 'R', '333866955', '333867348', '393', '1265.1', '722.0', '5062'])
#  list(['EFIX', 'R', '333865816', '333866907', '1091', '1258.1', '1357.2', '4276'])
#  list(['EFIX', 'R', '333865666', '333865791', '125', '1240.3', '1302.2', '3694'])
#  list(['EFIX', 'R', '333865405', '333865609', '204', '1959.4', '570.0', '3579'])
#  list(['EFIX', 'R', '333864945', '333865371', '426', '1752.2', '402.0', '4834'])
#  list(['EFIX', 'R', '333864239', '333864895', '656', '2203.3', '765.0', '4938'])
#  list(['EFIX', 'R', '333862927', '333864219', '1292', '2285.0', '736.0', '4608'])
#  list(['EFIX', 'R', '333862362', '333862657', '295', '1257.3', '709.1', '4114'])
#  list(['EFIX', 'R', '333862076', '333862331', '255', '1093.7', '608.1', '3736'])
#  list(['EFIX', 'R', '333861827', '333862055', '228', '1038.4', '662.6', '3760'])
#  list(['EFIX', 'R', '333861578', '333861798', '220', '1030.2', '774.8', '3884'])
#  list(['EFIX', 'R', '333861262', '333861548', '286', '1070.5', '669.1', '3845'])
#  list(['EFIX', 'R', '333860987', '333861240', '253', '1095.1', '626.1', '4021'])
#  list(['EFIX', 'R', '333860752', '333860965', '213', '1038.6', '692.8', '4183'])
#  list(['EFIX', 'R', '333860470', '333860728', '258', '1081.7', '642.9', '4229'])
#  list(['EFIX', 'R', '333860219', '333860437', '218', '1198.1', '803.5', '4002'])
#  list(['EFIX', 'R', '333859631', '333860186', '555', '1077.5', '637.9', '3953'])
#  list(['EFIX', 'R', '333859014', '333859624', '610', '1102.3', '642.5', '4150'])
#  list(['EFIX', 'R', '333858723', '333858986', '263', '960.6', '586.7', '3884'])
#  list(['EFIX', 'R', '333858193', '333858700', '507', '1003.6', '592.0', '3835'])
#  list(['EFIX', 'R', '333857998', '333858169', '171', '1077.0', '648.4', '3939'])
#  list(['EFIX', 'R', '333857721', '333857982', '261', '1056.2', '640.6', '3862'])
#  list(['EFIX', 'R', '333857540', '333857679', '139', '1478.3', '615.3', '3788'])
#  list(['EFIX', 'R', '333857297', '333857515', '218', '1448.4', '698.9', '4032'])
#  list(['EFIX', 'R', '333856853', '333857240', '387', '2326.0', '594.9', '3431'])
#  list(['EFIX', 'R', '333856405', '333856657', '252', '1828.8', '157.1', '3054'])
#  list(['EFIX', 'R', '333856030', '333856369', '339', '1752.6', '285.4', '3035'])
#  list(['EFIX', 'R', '333855620', '333855959', '339', '1695.5', '1559.8', '3764'])
#  list(['EFIX', 'R', '333855349', '333855532', '183', '1266.4', '720.9', '4352'])
#  list(['EFIX', 'R', '333854690', '333855317', '627', '1023.9', '603.3', '4112'])
#  list(['EFIX', 'R', '333854292', '333854662', '370', '1102.0', '692.8', '4376'])
#  list(['EFIX', 'R', '333854107', '333854263', '156', '1031.8', '620.8', '4410'])
#  list(['EFIX', 'R', '333853884', '333854082', '198', '1102.8', '676.4', '4350'])
#  list(['EFIX', 'R', '333853619', '333853856', '237', '1214.2', '618.9', '4288'])
#  list(['EFIX', 'R', '333853318', '333853584', '266', '1502.6', '777.6', '4568'])
#  list(['EFIX', 'R', '333852962', '333853284', '322', '1309.8', '601.6', '5022'])
#  list(['EFIX', 'R', '333852137', '333852896', '759', '2401.9', '489.3', '4349'])
#  list(['EFIX', 'R', '333851602', '333851930', '328', '1659.3', '-31.9', '4333'])
#  list(['EFIX', 'R', '333850995', '333851567', '572', '1876.2', '-30.7', '3742'])
#  list(['EFIX', 'R', '333850719', '333850911', '192', '1114.0', '672.9', '4194'])
#  list(['EFIX', 'R', '333850546', '333850690', '144', '1026.6', '592.0', '4095'])
#  list(['EFIX', 'R', '333850298', '333850518', '220', '1190.4', '587.1', '4518'])
#  list(['EFIX', 'R', '333850085', '333850271', '186', '1325.5', '588.0', '5627'])
#  list(['EFIX', 'R', '333848500', '333848695', '195', '1292.2', '717.1', '5190'])
#  list(['EFIX', 'R', '333848330', '333848464', '134', '1088.7', '684.3', '4998'])
#  list(['EFIX', 'R', '333847387', '333847661', '274', '62.6', '1004.2', '4293'])
#  list(['EFIX', 'R', '333846567', '333847306', '739', '1271.0', '1488.4', '4036'])
#  list(['EFIX', 'R', '333846105', '333846511', '406', '1413.2', '687.7', '4700'])
#  list(['EFIX', 'R', '333845749', '333846072', '323', '1241.5', '760.0', '4733'])
#  list(['EFIX', 'R', '333845451', '333845708', '257', '972.3', '610.5', '4702'])
#  list(['EFIX', 'R', '333845127', '333845416', '289', '1175.3', '816.7', '4843'])
#  list(['EFIX', 'R', '333844822', '333845087', '265', '1504.5', '714.2', '4568'])
#  list(['EFIX', 'R', '333844526', '333844775', '249', '1482.4', '1410.5', '4029'])
#  list(['EFIX', 'R', '333844164', '333844472', '308', '1418.5', '656.3', '4191'])
#  list(['EFIX', 'R', '333843852', '333844131', '279', '1225.2', '818.0', '4395'])
#  list(['EFIX', 'R', '333843634', '333843809', '175', '1379.6', '680.4', '4091'])
#  list(['EFIX', 'R', '333843309', '333843599', '290', '1186.6', '797.7', '4068'])
#  list(['EFIX', 'R', '333842788', '333843273', '485', '1256.8', '716.3', '5474'])
#  list(['EFIX', 'R', '333842499', '333842744', '245', '1756.0', '1035.3', '5543'])
#  list(['EFIX', 'R', '333842064', '333842456', '392', '1921.8', '801.4', '5355'])
#  list(['EFIX', 'R', '333841376', '333841998', '622', '1526.6', '1348.8', '5219'])
#  list(['EFIX', 'R', '333840731', '333841325', '594', '1405.1', '793.5', '5024'])
#  list(['EFIX', 'R', '333840341', '333840699', '358', '1308.1', '818.6', '4920'])
#  list(['EFIX', 'R', '333840107', '333840307', '200', '1410.8', '663.5', '4868'])
#  list(['EFIX', 'R', '333839703', '333840067', '364', '1114.7', '892.4', '4809'])
#  list(['EFIX', 'R', '333839498', '333839676', '178', '1199.3', '804.6', '4796'])
#  list(['EFIX', 'R', '333839122', '333839479', '357', '1231.2', '815.3', '5033'])
#  list(['EFIX', 'R', '333838764', '333839093', '329', '1336.7', '781.1', '5245'])
#  list(['EFIX', 'R', '333838429', '333838715', '286', '1610.2', '1390.3', '5024'])
#  list(['EFIX', 'R', '333838141', '333838378', '237', '1567.9', '845.9', '5019'])
#  list(['EFIX', 'R', '333837807', '333838102', '295', '1524.9', '998.8', '4752'])
#  list(['EFIX', 'R', '333837262', '333837759', '497', '1172.2', '838.5', '4733'])
#  list(['EFIX', 'R', '333837092', '333837203', '111', '1062.9', '1562.0', '4407'])
#  list(['EFIX', 'R', '333836866', '333837032', '166', '1319.5', '819.6', '4330'])
#  list(['EFIX', 'R', '333836504', '333836849', '345', '1342.3', '828.7', '3814'])
#  list(['EFIX', 'R', '333836273', '333836465', '192', '1445.9', '639.5', '3773'])
#  list(['EFIX', 'R', '333835324', '333836242', '918', '1271.1', '722.9', '5256'])
#  list(['EFIX', 'R', '333834876', '333835314', '438', '1292.8', '708.4', '5336'])
#  list(['EFIX', 'R', '333834779', '333834828', '49', '1294.9', '703.9', '5268'])
#  list(['EFIX', 'R', '333834026', '333834766', '740', '1281.1', '708.6', '5371'])
#  list(['EFIX', 'R', '333833688', '333833962', '274', '815.9', '177.6', '5179'])
#  list(['EFIX', 'R', '333833405', '333833624', '219', '131.2', '610.8', '5368'])
#  list(['EFIX', 'R', '333833301', '333833395', '94', '135.1', '620.9', '5297'])
#  list(['EFIX', 'R', '333832323', '333833148', '825', '1286.8', '711.0', '5150'])
#  list(['EFIX', 'R', '333831710', '333832274', '564', '427.9', '827.1', '5216'])
#  list(['EFIX', 'R', '333831425', '333831631', '206', '1219.8', '716.7', '4957'])
#  list(['EFIX', 'R', '333830001', '333831403', '1402', '1269.0', '721.0', '4841'])
#  list(['EFIX', 'R', '333829719', '333829990', '271', '1275.4', '703.8', '4373'])
#  list(['EFIX', 'R', '333829290', '333829661', '371', '1915.0', '613.1', '3222'])
#  list(['EFIX', 'R', '333828953', '333829229', '276', '1823.7', '178.0', '3055'])
#  list(['EFIX', 'R', '333828588', '333828923', '335', '2014.9', '201.4', '4096'])
#  list(['EFIX', 'R', '333828206', '333828521', '315', '1731.1', '154.5', '5023'])
#  list(['EFIX', 'R', '333828059', '333828131', '72', '2588.8', '586.5', '4695'])
#  list(['EFIX', 'R', '333827764', '333828048', '284', '2586.8', '583.8', '4639'])
#  list(['EFIX', 'R', '333826723', '333827717', '994', '2425.2', '886.7', '4952'])
#  list(['EFIX', 'R', '333826329', '333826587', '258', '2166.0', '1653.3', '4528'])
#  list(['EFIX', 'R', '333825578', '333825854', '276', '1286.4', '706.9', '5171'])
#  list(['EFIX', 'R', '333824453', '333825521', '1068', '1958.0', '590.8', '4529'])
#  list(['EFIX', 'R', '333824296', '333824429', '133', '1927.9', '649.7', '4545'])
#  list(['EFIX', 'R', '333824029', '333824236', '207', '949.6', '966.9', '4565'])
#  list(['EFIX', 'R', '333823738', '333823982', '244', '579.2', '640.0', '4371'])
#  list(['EFIX', 'R', '333823548', '333823697', '149', '1086.1', '917.8', '4831'])
#  list(['EFIX', 'R', '333823195', '333823502', '307', '1268.6', '1350.6', '4756'])
#  list(['EFIX', 'R', '333823041', '333823173', '132', '1318.5', '1361.4', '4493'])
#  list(['EFIX', 'R', '333822597', '333822988', '391', '1955.3', '579.0', '3808'])
#  list(['EFIX', 'R', '333822400', '333822566', '166', '1865.3', '372.4', '4395'])
#  list(['EFIX', 'R', '333821254', '333822344', '1090', '1863.4', '1400.1', '5535'])
#  list(['EFIX', 'R', '333820636', '333821226', '590', '1953.9', '1405.0', '5367'])
#  list(['EFIX', 'R', '333820261', '333820580', '319', '1643.6', '961.4', '5555'])
#  list(['EFIX', 'R', '333819762', '333820214', '452', '1961.2', '1075.3', '5327'])
#  list(['EFIX', 'R', '333819272', '333819690', '418', '1374.0', '722.6', '5412'])
#  list(['EFIX', 'R', '333819041', '333819216', '175', '1491.3', '90.1', '5196'])
#  list(['EFIX', 'R', '333818604', '333818978', '374', '1262.2', '729.1', '5411'])
#  list(['EFIX', 'R', '333818242', '333818576', '334', '1357.1', '770.5', '5377'])
#  list(['EFIX', 'R', '333817889', '333818178', '289', '2247.7', '536.0', '4807'])
#  list(['EFIX', 'R', '333817411', '333817823', '412', '2116.3', '1310.5', '4876'])
#  list(['EFIX', 'R', '333816678', '333817283', '605', '1337.3', '726.9', '5020'])
#  list(['EFIX', 'R', '333816003', '333816614', '611', '2344.9', '731.3', '4922'])
#  list(['EFIX', 'R', '333815239', '333815951', '712', '2182.5', '1031.3', '5324'])
#  list(['EFIX', 'R', '333815123', '333815217', '94', '2190.1', '998.2', '5577'])
#  list(['EFIX', 'R', '333813870', '333813989', '119', '2363.8', '2165.5', '3777'])
#  list(['EFIX', 'R', '333813545', '333813691', '146', '2158.8', '1119.0', '5040'])
#  list(['EFIX', 'R', '333812975', '333813277', '302', '1287.2', '724.7', '5059'])
#  list(['EFIX', 'R', '333811880', '333812932', '1052', '1274.7', '1349.1', '4301'])
#  list(['EFIX', 'R', '333811669', '333811870', '201', '1273.0', '1354.8', '3870'])
#  list(['EFIX', 'R', '333811529', '333811631', '102', '1012.0', '1041.8', '3909'])
#  list(['EFIX', 'R', '333811287', '333811509', '222', '1023.0', '999.8', '3688'])
#  list(['EFIX', 'R', '333811158', '333811259', '101', '969.8', '889.6', '3576'])
#  list(['EFIX', 'R', '333810850', '333811127', '277', '1194.7', '866.8', '3643'])
#  list(['EFIX', 'R', '333810700', '333810817', '117', '1401.5', '1015.5', '3645'])
#  list(['EFIX', 'R', '333810481', '333810666', '185', '1310.2', '987.9', '3968'])
#  list(['EFIX', 'R', '333810233', '333810428', '195', '760.9', '284.3', '4154'])
#  list(['EFIX', 'R', '333809927', '333810192', '265', '491.3', '228.6', '4116'])
#  list(['EFIX', 'R', '333809717', '333809883', '166', '601.6', '612.9', '3853'])
#  list(['EFIX', 'R', '333809528', '333809691', '163', '625.3', '532.7', '4486'])
#  list(['EFIX', 'R', '333809211', '333809470', '259', '527.2', '1207.6', '5493'])
#  list(['EFIX', 'R', '333808745', '333809126', '381', '1276.6', '724.6', '5298'])
#  list(['EFIX', 'R', '333808455', '333808727', '272', '1297.9', '686.8', '5323'])
#  list(['EFIX', 'R', '333808289', '333808384', '95', '49.8', '1107.0', '5389'])
#  list(['EFIX', 'R', '333807712', '333807962', '250', '1245.7', '722.9', '5297'])
#  list(['EFIX', 'R', '333807417', '333807696', '279', '1274.3', '710.0', '5249'])
#  list(['EFIX', 'R', '333806537', '333807410', '873', '1295.3', '709.2', '5365'])
#  list(['EFIX', 'R', '333805281', '333806528', '1247', '1281.8', '713.0', '5334'])
#  list(['EFIX', 'R', '333804772', '333805273', '501', '1297.0', '716.0', '5271'])
#  list(['EFIX', 'R', '333804530', '333804754', '224', '1298.7', '676.0', '5323'])
#  list(['EFIX', 'R', '333803709', '333804473', '764', '1375.5', '-54.6', '5038'])
#  list(['EFIX', 'R', '333802566', '333803651', '1085', '470.6', '-7.3', '5286'])
#  list(['EFIX', 'R', '333802403', '333802503', '100', '-98.6', '713.0', '5432'])
#  list(['EFIX', 'R', '333802112', '333802342', '230', '-102.0', '709.2', '5421'])
#  list(['EFIX', 'R', '333801526', '333802035', '509', '-87.0', '710.9', '5495'])
#  list(['EFIX', 'R', '333801211', '333801513', '302', '-74.3', '727.8', '5485'])
#  list(['EFIX', 'R', '333800791', '333801113', '322', '61.7', '1279.3', '5677'])
#  list(['EFIX', 'R', '333800683', '333800780', '97', '53.0', '1281.1', '5615'])
#  list(['EFIX', 'R', '333800584', '333800673', '89', '50.4', '1275.2', '5606'])
#  list(['EFIX', 'R', '333799796', '333800418', '622', '207.4', '1458.5', '5367'])
#  list(['EFIX', 'R', '333799021', '333799463', '442', '1255.0', '720.8', '5194'])
#  list(['EFIX', 'R', '333797742', '333798964', '1222', '1960.2', '582.8', '4093'])
#  list(['EFIX', 'R', '333797502', '333797733', '231', '1992.5', '581.5', '3261'])
#  list(['EFIX', 'R', '333797281', '333797457', '176', '1390.5', '864.3', '3641'])
#  list(['EFIX', 'R', '333797061', '333797252', '191', '1218.0', '877.6', '4169'])
#  list(['EFIX', 'R', '333796792', '333797040', '248', '1189.7', '858.7', '4212'])
#  list(['EFIX', 'R', '333796626', '333796749', '123', '581.8', '618.9', '3861'])
#  list(['EFIX', 'R', '333796460', '333796609', '149', '540.0', '625.4', '4102'])
#  list(['EFIX', 'R', '333796186', '333796412', '226', '1355.5', '860.8', '4118'])
#  list(['EFIX', 'R', '333795923', '333796144', '221', '1257.1', '1360.9', '3605'])
#  list(['EFIX', 'R', '333795704', '333795878', '174', '1184.0', '879.9', '3687'])
#  list(['EFIX', 'R', '333795534', '333795673', '139', '1385.9', '890.7', '4253'])
#  list(['EFIX', 'R', '333794632', '333795500', '868', '1279.8', '714.9', '5339'])
#  list(['EFIX', 'R', '333794370', '333794618', '248', '1263.5', '685.2', '5252'])
#  list(['EFIX', 'R', '333793972', '333794329', '357', '1533.4', '1106.7', '5181'])
#  list(['EFIX', 'R', '333793406', '333793914', '508', '2225.0', '487.4', '4900'])
#  list(['EFIX', 'R', '333792860', '333793183', '323', '1842.6', '58.9', '4895'])
#  list(['EFIX', 'R', '333792206', '333792796', '590', '2315.5', '507.0', '4742'])
#  list(['EFIX', 'R', '333791775', '333792138', '363', '2340.5', '1365.2', '4692'])
#  list(['EFIX', 'R', '333791109', '333791721', '612', '2341.4', '847.3', '4627'])
#  list(['EFIX', 'R', '333790859', '333791017', '158', '1522.7', '671.6', '5084'])
#  list(['EFIX', 'R', '333790593', '333790799', '206', '995.6', '198.1', '5012'])
#  list(['EFIX', 'R', '333790451', '333790527', '76', '237.4', '818.3', '5101'])
#  list(['EFIX', 'R', '333790301', '333790325', '24', '236.4', '841.9', '4801'])
#  list(['EFIX', 'R', '333790034', '333790250', '216', '232.5', '846.9', '4612'])
#  list(['EFIX', 'R', '333789516', '333789960', '444', '642.5', '770.8', '3784'])
#  list(['EFIX', 'R', '333789087', '333789210', '123', '-12.2', '121.1', '3433'])
#  list(['EFIX', 'R', '333788910', '333789007', '97', '-173.9', '615.1', '3818'])
#  list(['EFIX', 'R', '333788702', '333788867', '165', '-133.3', '611.3', '3941'])
#  list(['EFIX', 'R', '333788310', '333788497', '187', '928.9', '721.9', '4928'])
#  list(['EFIX', 'R', '333787882', '333788218', '336', '1972.2', '282.6', '4974'])
#  list(['EFIX', 'R', '333787516', '333787801', '285', '1301.4', '694.3', '5458'])
#  list(['EFIX', 'R', '333787287', '333787491', '204', '1339.2', '703.7', '5370'])
#  list(['EFIX', 'R', '333787180', '333787219', '39', '3270.0', '385.7', '4806'])
#  list(['EFIX', 'R', '333786532', '333786834', '302', '1291.1', '708.9', '5198'])
#  list(['EFIX', 'R', '333785264', '333786477', '1213', '1951.3', '574.9', '4386'])
#  list(['EFIX', 'R', '333785115', '333785247', '132', '1977.9', '534.9', '4234'])
#  list(['EFIX', 'R', '333784772', '333785060', '288', '1256.0', '1349.4', '4216'])
#  list(['EFIX', 'R', '333784498', '333784726', '228', '1238.3', '1028.6', '4353'])
#  list(['EFIX', 'R', '333784221', '333784453', '232', '599.0', '594.7', '4036'])
#  list(['EFIX', 'R', '333784077', '333784209', '132', '634.7', '578.5', '4913'])
#  list(['EFIX', 'R', '333783826', '333784010', '184', '367.0', '733.6', '5424'])
#  list(['EFIX', 'R', '333783559', '333783713', '154', '361.1', '717.0', '5607'])
#  list(['EFIX', 'R', '333783202', '333783472', '270', '1286.3', '678.3', '5647'])
#  list(['EFIX', 'R', '333783006', '333783176', '170', '1235.9', '702.6', '5666'])
#  list(['EFIX', 'R', '333782282', '333782565', '283', '1675.2', '2224.1', '4391'])
#  list(['EFIX', 'R', '333782231', '333782259', '28', '1645.6', '2195.2', '4452'])
#  list(['EFIX', 'R', '333781866', '333782111', '245', '1319.8', '710.8', '5277'])
#  list(['EFIX', 'R', '333781231', '333781809', '578', '1289.6', '695.1', '5303'])
#  list(['EFIX', 'R', '333781083', '333781201', '118', '1199.7', '829.7', '4994'])
#  list(['EFIX', 'R', '333780014', '333780187', '173', '1055.6', '781.6', '4546'])
#  list(['EFIX', 'R', '333779323', '333779846', '523', '1029.7', '768.1', '4691'])
#  list(['EFIX', 'R', '333778986', '333779298', '312', '1020.6', '843.0', '4673'])
#  list(['EFIX', 'R', '333778532', '333778961', '429', '1067.7', '786.7', '4610'])
#  list(['EFIX', 'R', '333778259', '333778479', '220', '1262.3', '1401.7', '4294'])
#  list(['EFIX', 'R', '333777988', '333778196', '208', '952.2', '622.4', '4142'])
#  list(['EFIX', 'R', '333777681', '333777951', '270', '1154.4', '580.2', '3952'])
#  list(['EFIX', 'R', '333777499', '333777644', '145', '1524.8', '633.7', '4094'])
#  list(['EFIX', 'R', '333777155', '333777470', '315', '1375.6', '674.8', '3966'])
#  list(['EFIX', 'R', '333776886', '333777133', '247', '1416.8', '623.5', '3802'])
#  list(['EFIX', 'R', '333776584', '333776851', '267', '1213.3', '778.5', '3921'])
#  list(['EFIX', 'R', '333776212', '333776549', '337', '1389.6', '658.8', '4033'])
#  list(['EFIX', 'R', '333775960', '333776179', '219', '1270.2', '779.9', '5198'])
#  list(['EFIX', 'R', '333775621', '333775900', '279', '1084.3', '1948.1', '5224'])
#  list(['EFIX', 'R', '333775054', '333775546', '492', '1713.2', '1483.0', '5268'])
#  list(['EFIX', 'R', '333774459', '333775017', '558', '1831.0', '1377.9', '4928'])
#  list(['EFIX', 'R', '333774090', '333774379', '289', '1264.3', '706.5', '4712'])
#  list(['EFIX', 'R', '333773828', '333774067', '239', '1194.1', '693.2', '4446'])
#  list(['EFIX', 'R', '333773165', '333773787', '622', '1312.0', '631.4', '4251'])
#  list(['EFIX', 'R', '333772788', '333773108', '320', '1410.6', '1324.1', '4117'])
#  list(['EFIX', 'R', '333772423', '333772728', '305', '1456.3', '622.3', '4550'])
#  list(['EFIX', 'R', '333772053', '333772387', '334', '1535.9', '787.6', '4682'])
#  list(['EFIX', 'R', '333771783', '333772038', '255', '1565.5', '772.3', '4436'])
#  list(['EFIX', 'R', '333771435', '333771747', '312', '1420.7', '635.6', '4163'])
#  list(['EFIX', 'R', '333771087', '333771402', '315', '1256.8', '751.8', '4164'])
#  list(['EFIX', 'R', '333770777', '333771062', '285', '1311.1', '749.9', '4568'])
#  list(['EFIX', 'R', '333770602', '333770746', '144', '1182.5', '823.5', '4505'])
#  list(['EFIX', 'R', '333770398', '333770574', '176', '1293.3', '745.2', '4449'])
#  list(['EFIX', 'R', '333770044', '333770369', '325', '1322.1', '824.6', '4298'])
#  list(['EFIX', 'R', '333769712', '333770020', '308', '1328.8', '737.6', '4024'])
#  list(['EFIX', 'R', '333769150', '333769687', '537', '1439.1', '678.5', '4310'])
#  list(['EFIX', 'R', '333767558', '333769079', '1521', '2671.5', '1057.0', '4791'])
#  list(['EFIX', 'R', '333766888', '333767521', '633', '2809.6', '1166.8', '4578'])
#  list(['EFIX', 'R', '333766114', '333766850', '736', '2806.1', '1398.8', '4372'])
#  list(['EFIX', 'R', '333765814', '333766079', '265', '2678.1', '1434.3', '4413'])
#  list(['EFIX', 'R', '333765187', '333765783', '596', '2685.4', '1595.2', '4163'])
#  list(['EFIX', 'R', '333764557', '333765154', '597', '2579.0', '1311.2', '4564'])
#  list(['EFIX', 'R', '333763461', '333764514', '1053', '2632.0', '918.1', '4289'])
#  list(['EFIX', 'R', '333762806', '333763383', '577', '2216.2', '220.7', '3836'])
#  list(['EFIX', 'R', '333762432', '333762700', '268', '1067.1', '638.3', '4240'])
#  list(['EFIX', 'R', '333762194', '333762393', '199', '1492.5', '627.0', '4020'])
#  list(['EFIX', 'R', '333762023', '333762159', '136', '1251.6', '700.1', '4757'])
#  list(['EFIX', 'R', '333761819', '333761960', '141', '289.3', '114.1', '5164'])
#  list(['EFIX', 'R', '333761469', '333761703', '234', '864.1', '484.5', '5330'])
#  list(['EFIX', 'R', '333760551', '333760738', '187', '1164.7', '736.8', '5258'])
#  list(['EFIX', 'R', '333760004', '333760474', '470', '1291.7', '722.7', '4925'])
#  list(['EFIX', 'R', '333759670', '333759970', '300', '1040.7', '611.3', '4831'])
#  list(['EFIX', 'R', '333759423', '333759641', '218', '1221.7', '609.9', '4956'])
#  list(['EFIX', 'R', '333759192', '333759392', '200', '1390.2', '648.2', '5032'])
#  list(['EFIX', 'R', '333758845', '333759132', '287', '1572.0', '1724.2', '4532'])
#  list(['EFIX', 'R', '333758371', '333758804', '433', '1647.1', '1434.3', '4319'])
#  list(['EFIX', 'R', '333757438', '333758290', '852', '2296.5', '730.4', '4187'])
#  list(['EFIX', 'R', '333757057', '333757333', '276', '1242.7', '713.6', '4490'])
#  list(['EFIX', 'R', '333756479', '333756998', '519', '1215.2', '598.4', '4648'])
#  list(['EFIX', 'R', '333756257', '333756454', '197', '1288.1', '578.2', '4602'])
#  list(['EFIX', 'R', '333755828', '333756197', '369', '2355.9', '969.0', '3951'])
#  list(['EFIX', 'R', '333755361', '333755625', '264', '1143.8', '685.9', '3364'])
#  list(['EFIX', 'R', '333755022', '333755328', '306', '1214.9', '575.2', '3363'])
#  list(['EFIX', 'R', '333753774', '333754993', '1219', '1282.7', '715.4', '5182'])
#  list(['EFIX', 'R', '333753586', '333753729', '143', '1209.0', '955.8', '5249'])
#  list(['EFIX', 'R', '333753507', '333753538', '31', '1281.5', '712.5', '5268'])
#  list(['EFIX', 'R', '333753065', '333753460', '395', '1286.8', '719.6', '5242'])
#  list(['EFIX', 'R', '333752755', '333753011', '256', '478.3', '470.9', '5043'])
#  list(['EFIX', 'R', '333752436', '333752636', '200', '1283.7', '709.1', '5287'])
#  list(['EFIX', 'R', '333752182', '333752418', '236', '1320.2', '709.6', '5231'])
#  list(['EFIX', 'R', '333752084', '333752117', '33', '253.7', '609.7', '5264'])
#  list(['EFIX', 'R', '333751976', '333752064', '88', '251.3', '601.6', '5416'])
#  list(['EFIX', 'R', '333751531', '333751840', '309', '1266.3', '699.0', '5581'])
#  list(['EFIX', 'R', '333751377', '333751505', '128', '1394.3', '688.3', '5661'])
#  list(['EFIX', 'R', '333750520', '333750577', '57', '2355.3', '1947.7', '4011'])
#  list(['EFIX', 'R', '333750270', '333750414', '144', '2354.7', '1885.7', '4089'])
#  list(['EFIX', 'R', '333749835', '333750157', '322', '2198.3', '554.9', '4606'])
#  list(['EFIX', 'R', '333749201', '333749583', '382', '1279.3', '707.8', '4930'])
# ...
#  list(['EFIX', 'R', '333676750', '333676896', '146', '1340.9', '660.7', '5452'])
#  list(['EFIX', 'R', '333676463', '333676684', '221', '1025.2', '2176.9', '4740'])
#  list(['EFIX', 'R', '333676096', '333676416', '320', '1269.1', '2121.8', '4735'])
#  list(['EFIX', 'R', '333675938', '333675981', '43', '1256.0', '684.6', '5215'])
#  list(['EFIX', 'R', '333675766', '333675888', '122', '1257.6', '684.2', '5135'])
#  list(['EFIX', 'R', '333675351', '333675578', '227', '1719.0', '2143.6', '4168'])
#  list(['EFIX', 'R', '333675193', '333675302', '109', '1695.6', '2148.4', '4137'])
#  list(['EFIX', 'R', '333674879', '333675057', '178', '1268.9', '715.5', '4468'])
#  list(['EFIX', 'R', '333674701', '333674849', '148', '1326.4', '796.6', '4056'])
#  list(['EFIX', 'R', '333674434', '333674627', '193', '1743.5', '315.1', '4477'])
#  list(['EFIX', 'R', '333674161', '333674372', '211', '2182.3', '555.9', '4508'])
#  list(['EFIX', 'R', '333673601', '333673920', '319', '1277.9', '727.7', '4678'])
#  list(['EFIX', 'R', '333673415', '333673575', '160', '1207.4', '702.0', '4290'])
#  list(['EFIX', 'R', '333673246', '333673361', '115', '1838.9', '116.4', '3687'])
#  list(['EFIX', 'R', '333673001', '333673210', '209', '2155.6', '179.1', '3680'])
#  list(['EFIX', 'R', '333672732', '333672977', '245', '2058.5', '200.3', '3839'])
#  list(['EFIX', 'R', '333672453', '333672690', '237', '1820.9', '284.6', '4557'])
#  list(['EFIX', 'R', '333672250', '333672424', '174', '1697.3', '281.6', '4913'])
#  list(['EFIX', 'R', '333672035', '333672215', '180', '1529.5', '330.4', '4995'])
#  list(['EFIX', 'R', '333671753', '333671964', '211', '1339.4', '1376.2', '4957'])
#  list(['EFIX', 'R', '333671508', '333671680', '172', '1952.1', '598.8', '4650'])
#  list(['EFIX', 'R', '333670302', '333671498', '1196', '1953.6', '581.1', '4082'])
#  list(['EFIX', 'R', '333670161', '333670291', '130', '1940.1', '587.7', '3645'])
#  list(['EFIX', 'R', '333669793', '333670127', '334', '1808.1', '270.1', '3650'])
#  list(['EFIX', 'R', '333669367', '333669728', '361', '357.3', '230.2', '3557'])
#  list(['EFIX', 'R', '333669084', '333669332', '248', '631.5', '332.6', '3689'])
#  list(['EFIX', 'R', '333668843', '333669061', '218', '637.4', '218.1', '3686'])
#  list(['EFIX', 'R', '333668576', '333668829', '253', '667.8', '232.7', '3578'])
#  list(['EFIX', 'R', '333668186', '333668539', '353', '551.0', '602.1', '3152'])
#  list(['EFIX', 'R', '333667898', '333668138', '240', '1074.9', '899.2', '3279'])
#  list(['EFIX', 'R', '333667636', '333667875', '239', '1032.1', '953.0', '3524'])
#  list(['EFIX', 'R', '333667434', '333667608', '174', '1101.3', '1042.7', '3723'])
#  list(['EFIX', 'R', '333667118', '333667403', '285', '949.3', '1136.1', '3501'])
#  list(['EFIX', 'R', '333666896', '333667088', '192', '1080.0', '1069.0', '3476'])
#  list(['EFIX', 'R', '333666714', '333666864', '150', '1167.8', '890.8', '3241'])
#  list(['EFIX', 'R', '333666453', '333666684', '231', '1368.3', '794.4', '3240'])
#  list(['EFIX', 'R', '333666225', '333666419', '194', '1514.5', '1065.8', '3240'])
#  list(['EFIX', 'R', '333665989', '333666199', '210', '1512.4', '928.9', '3193'])
#  list(['EFIX', 'R', '333665760', '333665967', '207', '1430.8', '972.7', '3152'])
#  list(['EFIX', 'R', '333665600', '333665732', '132', '1277.6', '952.8', '3439'])
#  list(['EFIX', 'R', '333665309', '333665575', '266', '1209.3', '985.3', '3997'])
#  list(['EFIX', 'R', '333665038', '333665282', '244', '1115.1', '967.9', '4668'])
#  list(['EFIX', 'R', '333664693', '333664991', '298', '1268.5', '1355.8', '4287'])
#  list(['EFIX', 'R', '333664386', '333664638', '252', '1976.2', '589.4', '3743'])
#  list(['EFIX', 'R', '333664235', '333664357', '122', '1925.8', '411.8', '4516'])
#  list(['EFIX', 'R', '333664117', '333664191', '74', '2538.3', '754.4', '4749'])
#  list(['EFIX', 'R', '333663418', '333664076', '658', '2259.8', '551.1', '4992'])
#  list(['EFIX', 'R', '333662897', '333663389', '492', '2258.9', '419.2', '4912'])
#  list(['EFIX', 'R', '333662345', '333662837', '492', '2403.1', '977.2', '4973'])
#  list(['EFIX', 'R', '333661852', '333662135', '283', '1318.8', '704.6', '5434'])
#  list(['EFIX', 'R', '333661323', '333661840', '517', '1286.7', '722.2', '5393'])
#  list(['EFIX', 'R', '333659997', '333661312', '1315', '1296.6', '712.1', '5368'])
#  list(['EFIX', 'R', '333659786', '333659975', '189', '1284.4', '676.1', '5414'])
#  list(['EFIX', 'R', '333659426', '333659748', '322', '1093.7', '198.6', '5343'])
#  list(['EFIX', 'R', '333658662', '333659339', '677', '2256.4', '108.6', '4610'])
#  list(['EFIX', 'R', '333657998', '333658603', '605', '2608.3', '750.0', '4512'])
#  list(['EFIX', 'R', '333657345', '333657941', '596', '2548.6', '1218.6', '4538'])
#  list(['EFIX', 'R', '333656767', '333657281', '514', '2175.4', '1787.9', '4272'])
#  list(['EFIX', 'R', '333656338', '333656650', '312', '1288.1', '710.0', '4446'])
#  list(['EFIX', 'R', '333656108', '333656315', '207', '1321.6', '657.7', '3863'])
#  list(['EFIX', 'R', '333655882', '333656052', '170', '1015.2', '175.8', '4446'])
#  list(['EFIX', 'R', '333655478', '333655808', '330', '774.1', '685.0', '4896'])
#  list(['EFIX', 'R', '333655344', '333655368', '24', '1995.4', '32.3', '4790'])
#  list(['EFIX', 'R', '333655238', '333655291', '53', '1996.7', '26.7', '4806'])
#  list(['EFIX', 'R', '333654315', '333654694', '379', '1297.7', '709.7', '5274'])
#  list(['EFIX', 'R', '333653190', '333654273', '1083', '1277.1', '1337.4', '4686'])
#  list(['EFIX', 'R', '333653012', '333653172', '160', '1267.1', '1387.8', '3614'])
#  list(['EFIX', 'R', '333652893', '333652979', '86', '1023.1', '1253.8', '3447'])
#  list(['EFIX', 'R', '333652692', '333652830', '138', '753.8', '244.1', '4031'])
#  list(['EFIX', 'R', '333652179', '333652645', '466', '1306.8', '681.8', '5432'])
#  list(['EFIX', 'R', '333651097', '333651364', '267', '1280.6', '721.5', '5175'])
#  list(['EFIX', 'R', '333650914', '333651068', '154', '1181.1', '727.5', '5444'])
#  list(['EFIX', 'R', '333650334', '333650837', '503', '2357.7', '650.9', '4802'])
#  list(['EFIX', 'R', '333649858', '333650260', '402', '1883.1', '664.9', '5084'])
#  list(['EFIX', 'R', '333648963', '333649275', '312', '1279.8', '715.0', '5428'])
#  list(['EFIX', 'R', '333647876', '333648920', '1044', '1286.0', '1323.4', '5296'])
#  list(['EFIX', 'R', '333647585', '333647868', '283', '1291.3', '1341.0', '5332'])
#  list(['EFIX', 'R', '333647375', '333647549', '174', '1399.0', '1054.3', '5352'])
#  list(['EFIX', 'R', '333647128', '333647347', '219', '1359.8', '945.7', '5263'])
#  list(['EFIX', 'R', '333646247', '333647087', '840', '1283.2', '1334.2', '4729'])
#  list(['EFIX', 'R', '333645972', '333646237', '265', '1268.6', '1381.6', '4005'])
#  list(['EFIX', 'R', '333645693', '333645961', '268', '1270.7', '1369.6', '3514'])
#  list(['EFIX', 'R', '333645508', '333645655', '147', '1368.4', '948.5', '4134'])
#  list(['EFIX', 'R', '333644949', '333645477', '528', '1280.8', '711.3', '5195'])
#  list(['EFIX', 'R', '333644584', '333644933', '349', '1282.6', '692.9', '5293'])
#  list(['EFIX', 'R', '333644386', '333644573', '187', '1267.2', '726.1', '5403'])
#  list(['EFIX', 'R', '333643949', '333644320', '371', '177.7', '584.6', '5391'])
#  list(['EFIX', 'R', '333643384', '333643817', '433', '1265.2', '722.1', '5139'])
#  list(['EFIX', 'R', '333643096', '333643378', '282', '1277.5', '712.0', '5264'])
#  list(['EFIX', 'R', '333642935', '333643074', '139', '1323.8', '670.4', '5595'])
#  list(['EFIX', 'R', '333642091', '333642780', '689', '2756.0', '1472.7', '4508'])
#  list(['EFIX', 'R', '333641633', '333642063', '430', '2662.8', '1301.1', '4678'])
#  list(['EFIX', 'R', '333641247', '333641589', '342', '2577.8', '930.3', '4846'])
#  list(['EFIX', 'R', '333639574', '333641216', '1642', '2638.7', '702.4', '4635'])
#  list(['EFIX', 'R', '333639229', '333639514', '285', '2679.9', '1281.0', '4427'])
#  list(['EFIX', 'R', '333638861', '333639181', '320', '2541.1', '1082.0', '4643'])
#  list(['EFIX', 'R', '333638458', '333638800', '342', '2329.7', '576.4', '4768'])
#  list(['EFIX', 'R', '333637780', '333638415', '635', '2293.3', '337.6', '4532'])
#  list(['EFIX', 'R', '333637355', '333637573', '218', '1525.9', '3.7', '4963'])
#  list(['EFIX', 'R', '333636872', '333637277', '405', '2298.5', '732.0', '4750'])
#  list(['EFIX', 'R', '333636683', '333636809', '126', '2068.4', '1693.1', '4448'])
#  list(['EFIX', 'R', '333636445', '333636675', '230', '2060.2', '1736.7', '4403'])
#  list(['EFIX', 'R', '333635809', '333636109', '300', '1272.1', '724.8', '4957'])
#  list(['EFIX', 'R', '333634565', '333635762', '1197', '588.9', '619.5', '4317'])
#  list(['EFIX', 'R', '333634442', '333634522', '80', '585.1', '295.2', '4629'])
#  list(['EFIX', 'R', '333633942', '333634387', '445', '177.2', '717.7', '4980'])
#  list(['EFIX', 'R', '333633508', '333633743', '235', '1269.1', '711.2', '4748'])
#  list(['EFIX', 'R', '333633271', '333633500', '229', '1286.0', '710.8', '4852'])
#  list(['EFIX', 'R', '333632939', '333633254', '315', '1331.8', '731.5', '4756'])
#  list(['EFIX', 'R', '333631393', '333632775', '1382', '1269.2', '707.2', '4255'])
#  list(['EFIX', 'R', '333631233', '333631366', '133', '1133.3', '683.1', '3176'])
#  list(['EFIX', 'R', '333630943', '333631216', '273', '1168.4', '715.3', '3207'])
#  list(['EFIX', 'R', '333630673', '333630917', '244', '1263.5', '776.8', '3402'])
#  list(['EFIX', 'R', '333630167', '333630648', '481', '1182.5', '801.2', '4022'])
#  list(['EFIX', 'R', '333629913', '333630150', '237', '1146.9', '809.5', '4396'])
#  list(['EFIX', 'R', '333629605', '333629879', '274', '961.0', '680.0', '4186'])
#  list(['EFIX', 'R', '333629369', '333629583', '214', '962.0', '637.7', '3915'])
#  list(['EFIX', 'R', '333629195', '333629338', '143', '985.6', '834.5', '3843'])
#  list(['EFIX', 'R', '333628946', '333629165', '219', '1114.4', '859.3', '3774'])
#  list(['EFIX', 'R', '333628683', '333628912', '229', '1325.6', '851.2', '3566'])
#  list(['EFIX', 'R', '333628402', '333628650', '248', '1447.6', '775.2', '3332'])
#  list(['EFIX', 'R', '333628151', '333628380', '229', '1432.5', '709.7', '3265'])
#  list(['EFIX', 'R', '333627911', '333628129', '218', '1489.0', '677.2', '3212'])
#  list(['EFIX', 'R', '333627647', '333627886', '239', '1526.2', '629.0', '3136'])
#  list(['EFIX', 'R', '333627432', '333627620', '188', '1393.3', '635.3', '3148'])
#  list(['EFIX', 'R', '333627093', '333627400', '307', '1161.5', '740.1', '3428'])
#  list(['EFIX', 'R', '333626886', '333627070', '184', '1117.4', '743.2', '3775'])
#  list(['EFIX', 'R', '333626658', '333626861', '203', '1133.2', '796.8', '4287'])
#  list(['EFIX', 'R', '333626462', '333626634', '172', '1241.9', '760.5', '4482'])
#  list(['EFIX', 'R', '333626260', '333626436', '176', '1277.4', '667.5', '5598'])
#  list(['EFIX', 'R', '333625916', '333626188', '272', '2579.9', '1797.1', '4224'])
#  list(['EFIX', 'R', '333624819', '333624962', '143', '2463.4', '1132.3', '4209'])
#  list(['EFIX', 'R', '333624377', '333624597', '220', '1271.6', '729.0', '4518'])
#  list(['EFIX', 'R', '333624014', '333624353', '339', '1339.3', '742.5', '4325'])
#  list(['EFIX', 'R', '333623704', '333623982', '278', '1440.4', '635.8', '4147'])
#  list(['EFIX', 'R', '333623458', '333623670', '212', '1540.2', '829.0', '4018'])
#  list(['EFIX', 'R', '333623195', '333623442', '247', '1576.4', '809.2', '3857'])
#  list(['EFIX', 'R', '333622928', '333623157', '229', '1263.2', '624.6', '3740'])
#  list(['EFIX', 'R', '333622760', '333622907', '147', '1224.5', '664.2', '3771'])
#  list(['EFIX', 'R', '333622501', '333622737', '236', '1163.2', '731.0', '3811'])
#  list(['EFIX', 'R', '333622140', '333622479', '339', '1195.3', '689.5', '3932'])
#  list(['EFIX', 'R', '333621818', '333622116', '298', '1256.6', '640.2', '4321'])
#  list(['EFIX', 'R', '333621655', '333621783', '128', '1100.4', '763.0', '4439'])
#  list(['EFIX', 'R', '333621384', '333621624', '240', '1028.6', '824.4', '4169'])
#  list(['EFIX', 'R', '333620541', '333621354', '813', '1023.1', '675.5', '3931'])
#  list(['EFIX', 'R', '333620300', '333620510', '210', '1170.7', '690.4', '4022'])
#  list(['EFIX', 'R', '333620058', '333620273', '215', '1193.4', '813.6', '3909'])
#  list(['EFIX', 'R', '333619809', '333620029', '220', '1336.4', '781.2', '3735'])
#  list(['EFIX', 'R', '333619571', '333619773', '202', '1428.9', '627.1', '3607'])
#  list(['EFIX', 'R', '333619345', '333619553', '208', '1414.6', '660.3', '3990'])
#  list(['EFIX', 'R', '333618850', '333619315', '465', '1266.3', '717.4', '5123'])
#  list(['EFIX', 'R', '333618635', '333618833', '198', '1286.2', '707.0', '5056'])
#  list(['EFIX', 'R', '333618579', '333618602', '23', '1209.3', '697.1', '5029'])
#  list(['EFIX', 'R', '333617982', '333618547', '565', '1251.7', '713.8', '5020'])
#  list(['EFIX', 'R', '333617719', '333617973', '254', '1279.5', '707.8', '5087'])
#  list(['EFIX', 'R', '333617565', '333617708', '143', '1249.1', '685.9', '5152'])
#  list(['EFIX', 'R', '333616772', '333617505', '733', '2385.1', '728.6', '4348'])
#  list(['EFIX', 'R', '333615937', '333616573', '636', '1467.1', '626.1', '4571'])
#  list(['EFIX', 'R', '333615709', '333615900', '191', '1098.4', '642.1', '4591'])
#  list(['EFIX', 'R', '333615471', '333615657', '186', '1200.0', '1469.7', '4409'])
#  list(['EFIX', 'R', '333615185', '333615401', '216', '1510.6', '597.8', '4274'])
#  list(['EFIX', 'R', '333614704', '333615166', '462', '1458.2', '602.5', '4238'])
#  list(['EFIX', 'R', '333614408', '333614688', '280', '1447.1', '636.5', '4247'])
#  list(['EFIX', 'R', '333614192', '333614379', '187', '1569.7', '699.8', '3866'])
#  list(['EFIX', 'R', '333613613', '333614164', '551', '1451.5', '616.8', '3947'])
#  list(['EFIX', 'R', '333613427', '333613596', '169', '1418.9', '621.9', '4050'])
#  list(['EFIX', 'R', '333613176', '333613388', '212', '942.5', '737.8', '3840'])
#  list(['EFIX', 'R', '333613007', '333613151', '144', '935.8', '632.7', '3610'])
#  list(['EFIX', 'R', '333612507', '333612981', '474', '1053.2', '640.2', '3591'])
#  list(['EFIX', 'R', '333612294', '333612473', '179', '1459.0', '656.5', '3989'])
#  list(['EFIX', 'R', '333612128', '333612262', '134', '1301.4', '716.2', '5234'])
#  list(['EFIX', 'R', '333611925', '333612116', '191', '1334.2', '716.5', '5187'])
#  list(['EFIX', 'R', '333611742', '333611868', '126', '364.7', '657.9', '5073'])
#  list(['EFIX', 'R', '333611628', '333611664', '36', '996.5', '686.9', '5065'])
#  list(['EFIX', 'R', '333610465', '333611553', '1088', '1262.9', '720.3', '4553'])
#  list(['EFIX', 'R', '333610211', '333610458', '247', '1247.6', '719.8', '3931'])
#  list(['EFIX', 'R', '333609983', '333610175', '192', '1527.3', '574.0', '3338'])
#  list(['EFIX', 'R', '333609734', '333609919', '185', '1259.5', '1491.2', '4024'])
#  list(['EFIX', 'R', '333609501', '333609676', '175', '942.3', '780.6', '4024'])
#  list(['EFIX', 'R', '333609147', '333609463', '316', '1038.5', '623.1', '4149'])
#  list(['EFIX', 'R', '333608733', '333609136', '403', '1017.7', '625.3', '4088'])
#  list(['EFIX', 'R', '333608093', '333608702', '609', '1200.3', '596.5', '4332'])
#  list(['EFIX', 'R', '333607607', '333608058', '451', '1581.4', '543.7', '3999'])
#  list(['EFIX', 'R', '333607344', '333607574', '230', '1548.0', '713.3', '4219'])
#  list(['EFIX', 'R', '333607133', '333607317', '184', '1572.5', '596.8', '4400'])
#  list(['EFIX', 'R', '333606997', '333607092', '95', '1201.9', '593.8', '4369'])
#  list(['EFIX', 'R', '333606767', '333606963', '196', '1568.3', '575.7', '4153'])
#  list(['EFIX', 'R', '333606480', '333606734', '254', '1500.5', '813.9', '4129'])
#  list(['EFIX', 'R', '333606261', '333606444', '183', '1112.7', '698.1', '3926'])
#  list(['EFIX', 'R', '333605981', '333606231', '250', '1217.5', '617.3', '3873'])
#  list(['EFIX', 'R', '333605717', '333605950', '233', '1058.0', '661.3', '3866'])
#  list(['EFIX', 'R', '333605456', '333605696', '240', '1001.5', '612.5', '3556'])
#  list(['EFIX', 'R', '333605226', '333605425', '199', '1230.8', '593.5', '4164'])
#  list(['EFIX', 'R', '333604149', '333605196', '1047', '1266.0', '715.0', '5095'])
#  list(['EFIX', 'R', '333603981', '333604134', '153', '1233.3', '707.6', '4386'])
#  list(['EFIX', 'R', '333603647', '333603951', '304', '1136.7', '498.4', '4019'])
#  list(['EFIX', 'R', '333603564', '333603615', '51', '1151.7', '728.3', '4125'])]

# %%
import csv
with open('FIX.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
    write.writerows(split_fix)

# %%
np_efix = np.asarray([np.array(line) for line in split_fix])
np_efix
pd.DataFrame(np_efix).to_csv('efix.csv', index_label = "Index", header  = ['Type','Eye','Start_time','End_time','Duration','Avg_x', 'Avg_y', 'Angle'])

# %%
asc_file = r'./J030701.asc'
raw = open(asc_file)
# _ = pd.read_csv(r'D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705.csv')

# #for line in data:
# #    n = 0 
# #    print(line)
data = _[['Time','x','y','pupil size','CR']]#[0:3]
data

def is_dig(char):
    """判断是否包含空格"""

    if type(char)==float:
        return True
    elif char.isdigit() == True:
        return True
    else:
        return False
    
final_data = pd.DataFrame()
event_list = [0]
df = data[['Time','x','y','pupil size','CR']]
df
#df['Time'] = str(df['Time'])
for i in df.index:
    #print(,type(int(data['Time'].loc[i])))
    z = 0
    if i % 100000 == 0:
        print('s')
    if is_dig(df['Time'].loc[i]) == False:
    
    #if is_space(df['Time'].loc[i]):
        #print('s')
        event_list.append(i)  
        event_data = df[event_list[-2]:event_list[-1]]
        
        event_data['event']= df['Time'].loc[i]
        final_data = final_data.append(event_data)
    
    final_data.to_csv(r"D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705_testtest.csv")
# Out:
# s
# C:\Users\SEANZH~1\AppData\Local\Temp/ipykernel_22772/396348675.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_data['event']= df['Time'].loc[i]
# s
# s
# s
# s
# s
# s

# %%
import pandas as pd

#asc_file = r'D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705.asc' # 

#with open(asc_file) as f:
#    pass

### 首先把.asc 文件保存成.csv (具体格式要修改一下：1.删掉开头的信息  2. 改掉部分的内容。 注：以这个csv 文件为模板：J030705-csved； 如果你要批量进行操作，你可以尝试用代码实现下)
### 修改下面的 csv 文件路径 （之后你可以写成批处理文件，批量处理csv 文件）
### 读出来的最终csv 参考 J030705_test_v3.csv； 里面 其实还有一些需要处理，比如说，在MSG 文件中， 里面 是一个混合的字符，其中包含了一些信息，你可以尝试用.split()  来对这一列进行操作


data = pd.read_csv(r'D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705-csved.csv', dtype={'Time': str})# 这里是你要导入的csv 文件路径

def is_dig(char): # 一些正则
    """判断是否为纯数字"""
    return str(char).isdigit()

c = pd.DataFrame()
event_list = [0]
_ = data[['Time','x','y','pupil size','CR']]#[0:1000]

for i in range(len(_)):
    if i % 100000 == 0:
        print('s')

    if not is_dig(_['Time'][i]):
        event_list.append(i)
        event_data = _[event_list[-2]:event_list[-1]]
        event_data['event'] = _['Time'][i]
        c = c.append(event_data)


final_data = pd.DataFrame()
event_list = [0]
df = c[['Time','x','y','pupil size','CR','event']]#[0:1000]
for i in range(len(df)):
    if i % 100000 == 0:
        print('s')

    if df['Time'][i] == 'MSG':
    #@if df['Time'][i] == 'MSG':
        event_list.append(i)
        event_data = df[event_list[-2]:event_list[-1]]
        event_data['MSG'] = df['x'][i]
        final_data = final_data.append(event_data)

final_data['event_final'] = final_data['event'].str.split().str.get(0)
final_data.to_csv(r"D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705_test_v3.csv") # 这是保存出来的路径
# Out:
# s
# C:\Users\SEANZH~1\AppData\Local\Temp/ipykernel_22772/2956313283.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_data['event'] = _['Time'][i]
# s
# s
# s
# s
# s
# s
# s
# C:\Users\SEANZH~1\AppData\Local\Temp/ipykernel_22772/2956313283.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event_data['MSG'] = df['x'][i]
# s
# s
# s
# s
# s
# s

# %%
x = 'SFIX R   335349005'
x.split(' ')[0]
# Out:
# 'SFIX'

# %%
df
# Out:
#                    Time          x      y pupil size     CR  \
# 0             335348998     1278.5  467.4     3892.0  127.0
# 1             335348998       1278    468     3883.0  127.0
# 2             335348999     1277.5  469.3     3878.0  127.0
# 3             335348999     1277.5  470.4     3882.0  127.0
# 4             335349000     1276.9  471.2     3891.0  127.0
# ..                  ...        ...    ...        ...    ...
# 865           335349426     1273.2  690.3     4027.0  127.0
# 866           335349426     1272.7  690.3     4029.0  127.0
# 867           335349427     1272.1  690.2     4028.0  127.0
# 868  ESACC R  335349388  335349427     39     1138.5  469.0
# 869           335349427     1271.5  690.4     4028.0  127.0
#
#                   event
# 0    SFIX R   335349005
# 1    SFIX R   335349005
# 2    SFIX R   335349005
# 3    SFIX R   335349005
# 4    SFIX R   335349005
# ..                  ...
# 865  ESACC R  335349388
# 866  ESACC R  335349388
# 867  ESACC R  335349388
# 868  SFIX R   335349428
# 869  SFIX R   335349428
#
# [870 rows x 6 columns]

# %%
df['Time'][i]
# Out:
# 'END'

# %%
event_data[]
# Out:
#          Time          x    y pupil size   CR event
# 662336  INPUT  335678566  127        NaN  NaN   END

# %%
final_data.to_csv(r"D:\Jupiter_eyemovement_data\Pic_TOJ\formal\SESSION1\ASC\J030705_testtest.csv")

# %%
final_data
# Out:
#                                                      Time   x   y  pupil size  \
# 0       ** CONVERTED FROM D:\Jupiter_eyemovement_data\... NaN NaN         NaN
# 1                       ** DATE: Mon Mar  6 17:24:00 2023 NaN NaN         NaN
# 2            ** TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED NaN NaN         NaN
# 3                                ** VERSION: EYELINK II 1 NaN NaN         NaN
# 4                                   ** SOURCE: EYELINK CL NaN NaN         NaN
# ...                                                   ...  ..  ..         ...
# 190873  335443982\t 1388.8\t  665.9\t 4799.0\t  127.0\... NaN NaN         NaN
# 190874  335443982\t 1389.0\t  664.5\t 4805.0\t  127.0\... NaN NaN         NaN
# 190875  335443983\t 1389.1\t  663.4\t 4803.0\t  127.0\... NaN NaN         NaN
# 190876  335443983\t 1389.0\t  662.9\t 4793.0\t  127.0\... NaN NaN         NaN
# 190877  335443984\t 1388.8\t  660.5\t 4787.0\t  127.0\... NaN NaN         NaN
#
#         CR                                              event
# 0      NaN                  ** DATE: Mon Mar  6 17:24:00 2023
# 1      NaN       ** TYPE: EDF_FILE BINARY EVENT SAMPLE TAGGED
# 2      NaN                           ** VERSION: EYELINK II 1
# 3      NaN                              ** SOURCE: EYELINK CL
# 4      NaN                 ** EYELINK II CL v5.15 Jan 24 2018
# ...     ..                                                ...
# 190873 NaN  335443982\t 1389.0\t  664.5\t 4805.0\t  127.0\...
# 190874 NaN  335443983\t 1389.1\t  663.4\t 4803.0\t  127.0\...
# 190875 NaN  335443983\t 1389.0\t  662.9\t 4793.0\t  127.0\...
# 190876 NaN  335443984\t 1388.8\t  660.5\t 4787.0\t  127.0\...
# 190877 NaN  335443984\t 1388.4\t  658.0\t 4784.0\t  127.0\...
#
# [190878 rows x 6 columns]

# %% [markdown]
# # JIanhua coding

# %%
asc = open(asc_file)

fix_x_encoding_0 = [] # List of all x positions
fix_y_encoding_0 = [] # List of all y positions
fix_duration_encoding_0 = [] # List of all durations

SACC_start_x_encoding_0 = []
SACC_start_y_encoding_0 = []
SACC_duration_encoding_0 = []
SACC_end_x_encoding_0 = []
SACC_end_y_encoding_0 = []

BLINK_duration_encoding_0 = []



new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    #memory stage-image
    if 'forcedmemory_start_pic_0' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_memory = []
        fix_y_memory = []
        fix_duration_memory = []
        
        SACC_start_x_memory = []
        SACC_start_y_memory = []
        SACC_duration_memory = []
        SACC_end_x_memory = []
        SACC_end_y_memory = []

        BLINK_duration_memory = []
    
    if 'forcedmemory_end_pic_0' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_encoding_0.extend(fix_x_memory)
        fix_y_encoding_0.extend(fix_y_memory)
        fix_duration_encoding_0.extend(fix_duration_memory)
        
        SACC_start_x_encoding_0.extend(SACC_start_x_memory)
        SACC_start_y_encoding_0.extend(SACC_start_y_memory)
        SACC_duration_encoding_0.extend(SACC_duration_memory)
        SACC_end_x_encoding_0.extend(SACC_end_x_memory)
        SACC_end_y_encoding_0.extend(SACC_end_y_memory)
        
        BLINK_duration_encoding_0.extend(BLINK_duration_memory)
        
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_e_f, x, y = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_f = duration_e_f - (trial_start - start_time)
                start_time = trial_start
            fix_x_encoding_0.append(x)
            fix_y_encoding_0.append(y)
            fix_duration_encoding_0.append(duration_e_f)  
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'ESACC' in line:
            #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity

            start_time, end_time, duration_e_s, x1, y1,x2,y2 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_s = duration_e_s - (trial_start - start_time)
                start_time = trial_start
            SACC_start_x_encoding_0.append(x1)
            SACC_start_y_encoding_0.append(y1)
            SACC_duration_encoding_0.append(duration_e_s)
            SACC_end_x_encoding_0.append(x2)
            SACC_end_y_encoding_0.append(y2)       
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
            if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

                start_time, end_time,duration_e_b = [int(float(x)) for x in tmp_data[2:]]
                if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_e_b = duration_e_b - (trial_start - start_time)
                    start_time = trial_start 
                #duration_e_b = [str(float(x)) for x in tmp_data[4:]]
                BLINK_duration_encoding_0.append(duration_e_b)
asc.close()  
# Combine the fixation data lists into a dictionary
eye_data_encoding_pic = {
    'fix_x_e_position': fix_x_encoding_0,
    'fix_y_e_position': fix_y_encoding_0,
    'fix_e_duration': fix_duration_encoding_0,
    'SACC_x_e_s_position': SACC_start_x_encoding_0,
    'SACC_y_e_s_position': SACC_start_y_encoding_0,
    'SACC_e_duration': SACC_duration_encoding_0,
    'SACC_x_e_e_position': SACC_end_x_encoding_0,
    'SACC_y_e_e_position': SACC_end_y_encoding_0, 
    'BLINK_e_duration': BLINK_duration_encoding_0, 
}               
                
df_data_encoding_pic_0 = pd.DataFrame.from_dict(eye_data_encoding_pic, orient='index')
print(df_data_encoding_pic_0.T)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\SEANZH~1\AppData\Local\Temp/ipykernel_22772/4015511013.py in <module>
# ----> 1 asc = open(asc_file)
#       2
#       3 fix_x_encoding_0 = [] # List of all x positions
#       4 fix_y_encoding_0 = [] # List of all y positions
#       5 fix_duration_encoding_0 = [] # List of all durations
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/work/lab/eye/J030705.asc'

# %%
asc = open(asc_file)

fix_x_encoding_1 = [] # List of all x positions
fix_y_encoding_1 = [] # List of all y positions
fix_duration_encoding_1 = [] # List of all durations

SACC_start_x_encoding_1 = []
SACC_start_y_encoding_1 = []
SACC_duration_encoding_1 = []
SACC_end_x_encoding_1 = []
SACC_end_y_encoding_1 = []

BLINK_duration_encoding_1 = []



new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    #memory stage-image
    if 'forcedmemory_start_pic_1' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_memory = []
        fix_y_memory = []
        fix_duration_memory = []
        
        SACC_start_x_memory = []
        SACC_start_y_memory = []
        SACC_duration_memory = []
        SACC_end_x_memory = []
        SACC_end_y_memory = []

        BLINK_duration_memory = []
    
    if 'forcedmemory_end_pic_1' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_encoding_1.extend(fix_x_memory)
        fix_y_encoding_1.extend(fix_y_memory)
        fix_duration_encoding_1.extend(fix_duration_memory)
        
        SACC_start_x_encoding_1.extend(SACC_start_x_memory)
        SACC_start_y_encoding_1.extend(SACC_start_y_memory)
        SACC_duration_encoding_1.extend(SACC_duration_memory)
        SACC_end_x_encoding_1.extend(SACC_end_x_memory)
        SACC_end_y_encoding_1.extend(SACC_end_y_memory)
        
        BLINK_duration_encoding_1.extend(BLINK_duration_memory)
        
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_e_f, x, y = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_f = duration_e_f - (trial_start - start_time)
                start_time = trial_start
            fix_x_encoding_1.append(x)
            fix_y_encoding_1.append(y)
            fix_duration_encoding_1.append(duration_e_f)  
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'ESACC' in line:
            #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity

            start_time, end_time, duration_e_s, x1, y1,x2,y2 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_s = duration_e_s - (trial_start - start_time)
                start_time = trial_start
            SACC_start_x_encoding_1.append(x1)
            SACC_start_y_encoding_1.append(y1)
            SACC_duration_encoding_1.append(duration_e_s)
            SACC_end_x_encoding_1.append(x2)
            SACC_end_y_encoding_1.append(y2)       
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
            if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

                start_time, end_time,duration_e_b = [int(float(x)) for x in tmp_data[2:]]
                if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_e_b = duration_e_b - (trial_start - start_time)
                    start_time = trial_start 
                #duration_e_b = [str(float(x)) for x in tmp_data[4:]]
                BLINK_duration_encoding_1.append(duration_e_b)
asc.close()  
# Combine the fixation data lists into a dictionary
eye_data_encoding_pic = {
    'fix_x_e_position': fix_x_encoding_1,
    'fix_y_e_position': fix_y_encoding_1,
    'fix_e_duration': fix_duration_encoding_1,
    'SACC_x_e_s_position': SACC_start_x_encoding_1,
    'SACC_y_e_s_position': SACC_start_y_encoding_1,
    'SACC_e_duration': SACC_duration_encoding_1,
    'SACC_x_e_e_position': SACC_end_x_encoding_1,
    'SACC_y_e_e_position': SACC_end_y_encoding_1, 
    'BLINK_e_duration': BLINK_duration_encoding_1, 
}               
                
df_data_encoding_pic_1 = pd.DataFrame.from_dict(eye_data_encoding_pic, orient='index')
print(df_data_encoding_pic_1.T)
# Out:
#      fix_x_e_position  fix_y_e_position  fix_e_duration  SACC_x_e_s_position  \
# 0              2362.0             982.0           419.0               2343.0
# 1              1272.0             631.0           273.0               1274.0
# 2              1379.0             668.0           247.0               1387.0
# 3              2368.0             862.0           944.0               2380.0
# 4              1845.0             321.0           564.0               1838.0
# ..                ...               ...             ...                  ...
# 174            1245.0             751.0           274.0               1927.0
# 175            1907.0             -57.0           550.0               1751.0
# 176            1754.0             326.0           385.0               1180.0
# 177            1185.0             213.0           295.0               2077.0
# 178            2069.0             988.0           366.0                  NaN
#
#      SACC_y_e_s_position  SACC_e_duration  SACC_x_e_e_position  \
# 0                  990.0             65.0               1269.0
# 1                  641.0             25.0               1377.0
# 2                  672.0             92.0               2359.0
# 3                  863.0             73.0               1860.0
# 4                  330.0             82.0               2352.0
# ..                   ...              ...                  ...
# 174                -48.0             62.0               1754.0
# 175                329.0             55.0               1227.0
# 176                207.0             96.0               2056.0
# 177                971.0             58.0               2316.0
# 178                  NaN              NaN                  NaN
#
#      SACC_y_e_e_position  BLINK_e_duration
# 0                  629.0             178.0
# 1                  661.0              38.0
# 2                  873.0             340.0
# 3                  319.0             148.0
# 4                  869.0              96.0
# ..                   ...               ...
# 174                320.0               NaN
# 175                224.0               NaN
# 176               1007.0               NaN
# 177                455.0               NaN
# 178                  NaN               NaN
#
# [179 rows x 9 columns]

# %%
asc = open(asc_file)

fix_x_encoding_2 = [] # List of all x positions
fix_y_encoding_2 = [] # List of all y positions
fix_duration_encoding_2 = [] # List of all durations

SACC_start_x_encoding_2 = []
SACC_start_y_encoding_2 = []
SACC_duration_encoding_2 = []
SACC_end_x_encoding_2 = []
SACC_end_y_encoding_2 = []

BLINK_duration_encoding_2 = []



new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    #memory stage-image
    if 'forcedmemory_start_pic_2' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_memory = []
        fix_y_memory = []
        fix_duration_memory = []
        
        SACC_start_x_memory = []
        SACC_start_y_memory = []
        SACC_duration_memory = []
        SACC_end_x_memory = []
        SACC_end_y_memory = []

        BLINK_duration_memory = []
    
    if 'forcedmemory_end_pic_2' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_encoding_2.extend(fix_x_memory)
        fix_y_encoding_2.extend(fix_y_memory)
        fix_duration_encoding_2.extend(fix_duration_memory)
        
        SACC_start_x_encoding_2.extend(SACC_start_x_memory)
        SACC_start_y_encoding_2.extend(SACC_start_y_memory)
        SACC_duration_encoding_2.extend(SACC_duration_memory)
        SACC_end_x_encoding_2.extend(SACC_end_x_memory)
        SACC_end_y_encoding_2.extend(SACC_end_y_memory)
        
        BLINK_duration_encoding_2.extend(BLINK_duration_memory)
        
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_e_f, x, y = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_f = duration_e_f - (trial_start - start_time)
                start_time = trial_start
            fix_x_encoding_2.append(x)
            fix_y_encoding_2.append(y)
            fix_duration_encoding_2.append(duration_e_f)  
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'ESACC' in line:
            #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity

            start_time, end_time, duration_e_s, x1, y1,x2,y2 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_s = duration_e_s - (trial_start - start_time)
                start_time = trial_start
            SACC_start_x_encoding_2.append(x1)
            SACC_start_y_encoding_2.append(y1)
            SACC_duration_encoding_2.append(duration_e_s)
            SACC_end_x_encoding_2.append(x2)
            SACC_end_y_encoding_2.append(y2)       
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
            if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

                start_time, end_time,duration_e_b = [int(float(x)) for x in tmp_data[2:]]
                if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_e_b = duration_e_b - (trial_start - start_time)
                    start_time = trial_start 
                #duration_e_b = [str(float(x)) for x in tmp_data[4:]]
                BLINK_duration_encoding_2.append(duration_e_b)
asc.close()  
# Combine the fixation data lists into a dictionary
eye_data_encoding_pic = {
    'fix_x_e_position': fix_x_encoding_2,
    'fix_y_e_position': fix_y_encoding_2,
    'fix_e_duration': fix_duration_encoding_2,
    'SACC_x_e_s_position': SACC_start_x_encoding_2,
    'SACC_y_e_s_position': SACC_start_y_encoding_2,
    'SACC_e_duration': SACC_duration_encoding_2,
    'SACC_x_e_e_position': SACC_end_x_encoding_2,
    'SACC_y_e_e_position': SACC_end_y_encoding_2, 
    'BLINK_e_duration': BLINK_duration_encoding_2, 
}               
                
df_data_encoding_pic_2 = pd.DataFrame.from_dict(eye_data_encoding_pic, orient='index')
print(df_data_encoding_pic_2.T)
# Out:
#     fix_x_e_position  fix_y_e_position  fix_e_duration  SACC_x_e_s_position  \
# 0             2272.0             678.0          1086.0               2266.0
# 1             1218.0             754.0           230.0               1202.0
# 2             1098.0             645.0           438.0               1085.0
# 3               22.0             882.0           197.0                 32.0
# 4             2313.0             757.0          1455.0               2319.0
# 5             1407.0             813.0           279.0               2392.0
# 6             1197.0             789.0           454.0               1399.0
# 7             1347.0             874.0           271.0               1187.0
# 8             2310.0             672.0          1492.0               1341.0
# 9             2625.0            1818.0           149.0               2348.0
# 10            1263.0             649.0           226.0               2627.0
# 11            1303.0             659.0           465.0               1250.0
# 12            1324.0             654.0           526.0               1295.0
# 13            1210.0             645.0           134.0               1326.0
# 14            1139.0             651.0           233.0               1212.0
# 15            1279.0             646.0           374.0               1138.0
# 16            1239.0             648.0           346.0               1276.0
# 17            1250.0             674.0           288.0               1238.0
# 18            1314.0             651.0           466.0               1249.0
# 19            1176.0             828.0           194.0               1312.0
# 20            1340.0             652.0           613.0               1176.0
# 21            2496.0            1262.0           632.0               1339.0
# 22            2629.0            1317.0           674.0               2492.0
# 23            2653.0            1536.0           844.0               2633.0
# 24            2624.0            1704.0           336.0               2655.0
# 25            2335.0             642.0           793.0               2625.0
# 26               NaN               NaN             NaN               2351.0
#
#     SACC_y_e_s_position  SACC_e_duration  SACC_x_e_e_position  \
# 0                 675.0            146.0               1244.0
# 1                 761.0             35.0               1118.0
# 2                 645.0            208.0                 18.0
# 3                 865.0            168.0               2316.0
# 4                 757.0             22.0               2281.0
# 5                2403.0            814.0               1421.0
# 6                 835.0           1121.0               1206.0
# 7                 803.0             28.0               1349.0
# 8                 880.0            232.0               2288.0
# 9                 689.0             51.0               2605.0
# 10               1807.0             79.0               1278.0
# 11                662.0             24.0               1317.0
# 12                662.0             22.0               1330.0
# 13                656.0             39.0               1212.0
# 14                644.0             24.0               1157.0
# 15                648.0             32.0               1280.0
# 16                646.0             20.0               1240.0
# 17                649.0             17.0               1250.0
# 18                667.0             23.0               1313.0
# 19                660.0             41.0               1175.0
# 20                826.0             38.0               1331.0
# 21                648.0             17.0               1311.0
# 22               1255.0             31.0               2614.0
# 23               1316.0             27.0               2637.0
# 24               1551.0             26.0               2620.0
# 25               1698.0            143.0               2344.0
# 26                644.0             55.0               2591.0
#
#     SACC_y_e_e_position  BLINK_e_duration
# 0                 735.0              63.0
# 1                 640.0             708.0
# 2                 881.0              15.0
# 3                 764.0             135.0
# 4                 799.0              66.0
# 5                 806.0               NaN
# 6                 776.0               NaN
# 7                 861.0               NaN
# 8                 669.0               NaN
# 9                 456.0               NaN
# 10                644.0               NaN
# 11                653.0               NaN
# 12                656.0               NaN
# 13                642.0               NaN
# 14                654.0               NaN
# 15                650.0               NaN
# 16                640.0               NaN
# 17                674.0               NaN
# 18                644.0               NaN
# 19                823.0               NaN
# 20                657.0               NaN
# 21                643.0               NaN
# 22               1322.0               NaN
# 23               1538.0               NaN
# 24               1703.0               NaN
# 25                641.0               NaN
# 26                589.0               NaN

# %%
asc = open(asc_file)

fix_x_encoding_3 = [] # List of all x positions
fix_y_encoding_3 = [] # List of all y positions
fix_duration_encoding_3 = [] # List of all durations

SACC_start_x_encoding_3 = []
SACC_start_y_encoding_3 = []
SACC_duration_encoding_3 = []
SACC_end_x_encoding_3 = []
SACC_end_y_encoding_3 = []

BLINK_duration_encoding_3 = []



new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    #memory stage-image
    if 'forcedmemory_start_pic_3' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_memory = []
        fix_y_memory = []
        fix_duration_memory = []
        
        SACC_start_x_memory = []
        SACC_start_y_memory = []
        SACC_duration_memory = []
        SACC_end_x_memory = []
        SACC_end_y_memory = []

        BLINK_duration_memory = []
    
    if 'forcedmemory_end_pic_3' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_encoding_3.extend(fix_x_memory)
        fix_y_encoding_3.extend(fix_y_memory)
        fix_duration_encoding_3.extend(fix_duration_memory)
        
        SACC_start_x_encoding_3.extend(SACC_start_x_memory)
        SACC_start_y_encoding_3.extend(SACC_start_y_memory)
        SACC_duration_encoding_3.extend(SACC_duration_memory)
        SACC_end_x_encoding_3.extend(SACC_end_x_memory)
        SACC_end_y_encoding_3.extend(SACC_end_y_memory)
        
        BLINK_duration_encoding_3.extend(BLINK_duration_memory)
        
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_e_f, x, y = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_f = duration_e_f - (trial_start - start_time)
                start_time = trial_start
            fix_x_encoding_3.append(x)
            fix_y_encoding_3.append(y)
            fix_duration_encoding_3.append(duration_e_f)  
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'ESACC' in line:
            #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity

            start_time, end_time, duration_e_s, x1, y1,x2,y2 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                duration_e_s = duration_e_s - (trial_start - start_time)
                start_time = trial_start
            SACC_start_x_encoding_3.append(x1)
            SACC_start_y_encoding_3.append(y1)
            SACC_duration_encoding_3.append(duration_e_s)
            SACC_end_x_encoding_3.append(x2)
            SACC_end_y_encoding_3.append(y2)       
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
            if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

                start_time, end_time,duration_e_b = [int(float(x)) for x in tmp_data[2:]]
                if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_e_b = duration_e_b - (trial_start - start_time)
                    start_time = trial_start 
                #duration_e_b = [str(float(x)) for x in tmp_data[4:]]
                BLINK_duration_encoding_3.append(duration_e_b)
asc.close()  
# Combine the fixation data lists into a dictionary
eye_data_encoding_pic = {
    'fix_x_e_position': fix_x_encoding_3,
    'fix_y_e_position': fix_y_encoding_3,
    'fix_e_duration': fix_duration_encoding_3,
    'SACC_x_e_s_position': SACC_start_x_encoding_3,
    'SACC_y_e_s_position': SACC_start_y_encoding_3,
    'SACC_e_duration': SACC_duration_encoding_3,
    'SACC_x_e_e_position': SACC_end_x_encoding_3,
    'SACC_y_e_e_position': SACC_end_y_encoding_3, 
    'BLINK_e_duration': BLINK_duration_encoding_3, 
}               
                
df_data_encoding_pic_3 = pd.DataFrame.from_dict(eye_data_encoding_pic, orient='index')
print(df_data_encoding_pic_3.T)
# Out:
#      fix_x_e_position  fix_y_e_position  fix_e_duration  SACC_x_e_s_position  \
# 0              2491.0            1160.0           226.0               2469.0
# 1              1484.0             705.0           494.0               1476.0
# 2              1516.0             743.0           756.0               1522.0
# 3              2384.0            1129.0           284.0               2386.0
# 4              1471.0             756.0           248.0               1472.0
# ..                ...               ...             ...                  ...
# 152            2427.0             748.0          1899.0               2048.0
# 153            2061.0             235.0           390.0               2520.0
# 154            2512.0             616.0          1040.0               2759.0
# 155            2760.0               4.0            39.0               2747.0
# 156            2760.0               5.0           371.0                  NaN
#
#      SACC_y_e_s_position  SACC_e_duration  SACC_x_e_e_position  \
# 0                 1147.0             60.0               1498.0
# 1                  709.0             23.0               1517.0
# 2                  749.0            182.0               2390.0
# 3                 1132.0             66.0               1473.0
# 4                  759.0             41.0               1509.0
# ..                   ...              ...                  ...
# 152                232.0             86.0               2503.0
# 153                612.0             68.0               2751.0
# 154                 -4.0             24.0               2769.0
# 155                 24.0             39.0               2744.0
# 156                  NaN              NaN                  NaN
#
#      SACC_y_e_e_position  BLINK_e_duration
# 0                  708.0              95.0
# 1                  739.0              89.0
# 2                 1125.0             121.0
# 3                  764.0              74.0
# 4                  655.0              83.0
# ..                   ...               ...
# 152                616.0               NaN
# 153                 14.0               NaN
# 154                 -9.0               NaN
# 155                 21.0               NaN
# 156                  NaN               NaN
#
# [157 rows x 9 columns]

# %%
df_encoding = pd.concat([df_data_encoding_pic_0.T, df_data_encoding_pic_1.T, df_data_encoding_pic_2.T, df_data_encoding_pic_3.T]).reset_index()
df_encoding
# Out:
#      index  fix_x_e_position  fix_y_e_position  fix_e_duration  \
# 0        0            1247.0             703.0           216.0
# 1        1            1319.0             644.0           389.0
# 2        2            1289.0             836.0           284.0
# 3        3            2460.0            1052.0           861.0
# 4        4            2546.0             844.0           413.0
# ..     ...               ...               ...             ...
# 400    152            2427.0             748.0          1899.0
# 401    153            2061.0             235.0           390.0
# 402    154            2512.0             616.0          1040.0
# 403    155            2760.0               4.0            39.0
# 404    156            2760.0               5.0           371.0
#
#      SACC_x_e_s_position  SACC_y_e_s_position  SACC_e_duration  \
# 0                 1245.0                714.0             27.0
# 1                 1317.0                645.0             43.0
# 2                 1291.0                837.0            171.0
# 3                 2475.0               1029.0             38.0
# 4                 2549.0                846.0             53.0
# ..                   ...                  ...              ...
# 400               2048.0                232.0             86.0
# 401               2520.0                612.0             68.0
# 402               2759.0                 -4.0             24.0
# 403               2747.0                 24.0             39.0
# 404                  NaN                  NaN              NaN
#
#      SACC_x_e_e_position  SACC_y_e_e_position  BLINK_e_duration
# 0                 1318.0                651.0              93.0
# 1                 1288.0                834.0             285.0
# 2                 2459.0               1060.0             109.0
# 3                 2527.0                860.0             104.0
# 4                 2413.0               1407.0               NaN
# ..                   ...                  ...               ...
# 400               2503.0                616.0               NaN
# 401               2751.0                 14.0               NaN
# 402               2769.0                 -9.0               NaN
# 403               2744.0                 21.0               NaN
# 404                  NaN                  NaN               NaN
#
# [405 rows x 10 columns]

# %%
df_eye = {'fix_e_duration':[], 'fix_x_e':[], 'fix_y_e':[],
         'SACC_e_duration':[], 
          'BLINK_e_duration':[], 
          'region_e':[],
         }

for i in range(0,len(df_encoding)):
    df_eye['fix_e_duration'].append(df_encoding['fix_e_duration'][i])
    df_eye['fix_x_e'].append(df_encoding['fix_x_e_position'][i])
    df_eye['fix_y_e'].append(df_encoding['fix_y_e_position'][i])
    if 992< df_encoding['fix_x_e_position'][i] <1568 and 560< df_encoding['fix_y_e_position'][i] <880:
        df_eye['region_e'].append('on_pic_e')
    elif df_encoding['fix_x_e_position'][i] <2560 and df_encoding['fix_y_e_position'][i] <1440:
        df_eye['region_e'].append('off_pic_e')
    else:
        df_eye['region_e'].append('N/A')
            
    df_eye['SACC_e_duration'].append(df_encoding['SACC_e_duration'][i])    
    df_eye['BLINK_e_duration'].append(df_encoding['BLINK_e_duration'][i])
          
df_eye = pd.DataFrame.from_dict(df_eye, orient='index')
print(df_eye.T)
df_eye = df_eye.T
print(df_eye)
# Out:
#     fix_e_duration fix_x_e fix_y_e SACC_e_duration BLINK_e_duration   region_e
# 0            216.0  1247.0   703.0            27.0             93.0   on_pic_e
# 1            389.0  1319.0   644.0            43.0            285.0   on_pic_e
# 2            284.0  1289.0   836.0           171.0            109.0   on_pic_e
# 3            861.0  2460.0  1052.0            38.0            104.0  off_pic_e
# 4            413.0  2546.0   844.0            53.0              NaN  off_pic_e
# ..             ...     ...     ...             ...              ...        ...
# 400         1899.0  2427.0   748.0            86.0              NaN  off_pic_e
# 401          390.0  2061.0   235.0            68.0              NaN  off_pic_e
# 402         1040.0  2512.0   616.0            24.0              NaN  off_pic_e
# 403           39.0  2760.0     4.0            39.0              NaN        N/A
# 404          371.0  2760.0     5.0             NaN              NaN        N/A
#
# [405 rows x 6 columns]
#     fix_e_duration fix_x_e fix_y_e SACC_e_duration BLINK_e_duration   region_e
# 0            216.0  1247.0   703.0            27.0             93.0   on_pic_e
# 1            389.0  1319.0   644.0            43.0            285.0   on_pic_e
# 2            284.0  1289.0   836.0           171.0            109.0   on_pic_e
# 3            861.0  2460.0  1052.0            38.0            104.0  off_pic_e
# 4            413.0  2546.0   844.0            53.0              NaN  off_pic_e
# ..             ...     ...     ...             ...              ...        ...
# 400         1899.0  2427.0   748.0            86.0              NaN  off_pic_e
# 401          390.0  2061.0   235.0            68.0              NaN  off_pic_e
# 402         1040.0  2512.0   616.0            24.0              NaN  off_pic_e
# 403           39.0  2760.0     4.0            39.0              NaN        N/A
# 404          371.0  2760.0     5.0             NaN              NaN        N/A
#
# [405 rows x 6 columns]

# %%
#df_eye.to_csv('df_eye_encoding_030705.csv')

fix_e_on = df_eye[df_eye['region_e']=='on_pic_e']['fix_e_duration'].sum()
fix_e_off = df_eye[df_eye['region_e']=='off_pic_e']['fix_e_duration'].sum()
fix_e_out = df_eye[df_eye['region_e']=='N/A']['fix_e_duration'].sum()
fix_e_valid = df_eye[df_eye['region_e']!='N/A']['fix_e_duration'].sum()
fix_e_total = df_eye['fix_e_duration'].sum()

SACC_e_total = df_eye['SACC_e_duration'].sum()
BLINK_e_total = df_eye['BLINK_e_duration'].sum()
#eye_e_total = fix_e_total+SACC_e_total+BLINK_e_total
eye_e_total = fix_e_total+SACC_e_total
percent_fix_e_on_pic = fix_e_on/fix_e_valid
percent_fix_e_off_pic = fix_e_off/fix_e_valid

df_eye['percent_fix_e_on_pic'] = percent_fix_e_on_pic
df_eye['percent_fix_e_off_pic'] = percent_fix_e_off_pic
df_eye['fix_e_total'] = fix_e_total
df_eye['SACC_e_total'] = SACC_e_total
df_eye['BLINK_e_total'] = BLINK_e_total
df_eye['eye_e_total'] = eye_e_total
df_eye['fix_e_valid'] = fix_e_valid
df_eye['fix_e_on'] = fix_e_on
df_eye['fix_e_off'] = fix_e_off
df_eye['fix_e_out'] = fix_e_out


df_eye_encoding= df_eye
df_eye_encoding
#df_data_encoding_pic_0.T.to_csv(r'D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/ASC/df_eye_encoding_022302_1.csv')
# Out:
#     fix_e_duration fix_x_e fix_y_e SACC_e_duration BLINK_e_duration  \
# 0            216.0  1247.0   703.0            27.0             93.0
# 1            389.0  1319.0   644.0            43.0            285.0
# 2            284.0  1289.0   836.0           171.0            109.0
# 3            861.0  2460.0  1052.0            38.0            104.0
# 4            413.0  2546.0   844.0            53.0              NaN
# ..             ...     ...     ...             ...              ...
# 400         1899.0  2427.0   748.0            86.0              NaN
# 401          390.0  2061.0   235.0            68.0              NaN
# 402         1040.0  2512.0   616.0            24.0              NaN
# 403           39.0  2760.0     4.0            39.0              NaN
# 404          371.0  2760.0     5.0             NaN              NaN
#
#       region_e  percent_fix_e_on_pic  percent_fix_e_off_pic  fix_e_total  \
# 0     on_pic_e              0.233685               0.766315     187606.0
# 1     on_pic_e              0.233685               0.766315     187606.0
# 2     on_pic_e              0.233685               0.766315     187606.0
# 3    off_pic_e              0.233685               0.766315     187606.0
# 4    off_pic_e              0.233685               0.766315     187606.0
# ..         ...                   ...                    ...          ...
# 400  off_pic_e              0.233685               0.766315     187606.0
# 401  off_pic_e              0.233685               0.766315     187606.0
# 402  off_pic_e              0.233685               0.766315     187606.0
# 403        N/A              0.233685               0.766315     187606.0
# 404        N/A              0.233685               0.766315     187606.0
#
#      SACC_e_total  BLINK_e_total  eye_e_total  fix_e_valid  fix_e_on  \
# 0         36814.0         9997.0     224420.0     160618.0   37534.0
# 1         36814.0         9997.0     224420.0     160618.0   37534.0
# 2         36814.0         9997.0     224420.0     160618.0   37534.0
# 3         36814.0         9997.0     224420.0     160618.0   37534.0
# 4         36814.0         9997.0     224420.0     160618.0   37534.0
# ..            ...            ...          ...          ...       ...
# 400       36814.0         9997.0     224420.0     160618.0   37534.0
# 401       36814.0         9997.0     224420.0     160618.0   37534.0
# 402       36814.0         9997.0     224420.0     160618.0   37534.0
# 403       36814.0         9997.0     224420.0     160618.0   37534.0
# 404       36814.0         9997.0     224420.0     160618.0   37534.0
#
#      fix_e_off  fix_e_out
# 0     123084.0    26988.0
# 1     123084.0    26988.0
# 2     123084.0    26988.0
# 3     123084.0    26988.0
# 4     123084.0    26988.0
# ..         ...        ...
# 400   123084.0    26988.0
# 401   123084.0    26988.0
# 402   123084.0    26988.0
# 403   123084.0    26988.0
# 404   123084.0    26988.0
#
# [405 rows x 16 columns]

# %%
print(fix_e_on, fix_e_off, fix_e_valid, fix_e_total, SACC_e_total, BLINK_e_total,)
print(percent_fix_e_on_pic, percent_fix_e_off_pic, SACC_e_total, BLINK_e_total)
# Out:
# 37534.0 123084.0 160618.0 187606.0 36814.0 9997.0
# 0.23368489210424734 0.7663151078957526 36814.0 9997.0

# %%
#3AFC stage  pic_0  
asc = open(asc_file)

fix_x_testing_0 = [] # List of all x positions
fix_y_testing_0 = [] # List of all y positions
fix_duration_testing_0 = [] # List of all durations

SACC_start_x_testing_0 = []
SACC_start_y_testing_0 = []
SACC_duration_testing_0 = []
SACC_end_x_testing_0 = []
SACC_end_y_testing_0 = []

BLINK_duration_testing_0 = []

new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    #memory stage-image

    if 'forcedchoice_start_0' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_testing = []
        fix_y_testing = []
        fix_duration_testing = []
        
        SACC_start_x_testing = []
        SACC_start_y_testing = []
        SACC_duration_testing = []
        SACC_end_x_testing = []
        SACC_end_y_testing = []
        
        BLINK_duration_testing = []
        
    if 'forcedchoice_end_0' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_testing_0.extend(fix_x_testing)
        fix_y_testing_0.extend(fix_y_testing)
        fix_duration_testing_0.extend(fix_duration_testing)
        
        SACC_start_x_testing_0.extend(SACC_start_x_testing)
        SACC_start_y_testing_0.extend(SACC_start_y_testing)
        SACC_duration_testing_0.extend(SACC_duration_testing) 
        SACC_end_x_testing_0.extend(SACC_end_x_testing)
        SACC_end_y_testing_0.extend(SACC_end_y_testing)
        
        BLINK_duration_testing_0.extend(BLINK_duration_testing)
        
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_t_f_0, x6, y6 = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_f_0 = duration_t_f_0 - (trial_start - start_time)
                    start_time = trial_start 
            fix_x_testing_0.append(x6)
            fix_y_testing_0.append(y6)
            fix_duration_testing_0.append(duration_t_f_0) 
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity
        if 'ESACC' in line:
            start_time, end_time,duration_t_s_0, x7, y7,x8,y8 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_s_0 = duration_t_s_0 - (trial_start - start_time)
                    start_time = trial_start 
            SACC_start_x_testing_0.append(x7)
            SACC_start_y_testing_0.append(y7)
            SACC_duration_testing_0.append(duration_t_s_0)
            SACC_end_x_testing_0.append(x8)
            SACC_end_y_testing_0.append(y8)
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

            start_time, end_time,duration_t_0_b = [int(float(x)) for x in tmp_data[2:]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_0_b = duration_t_0_b - (trial_start - start_time)
                    start_time = trial_start
            
            BLINK_duration_testing_0.append(duration_t_0_b)
            
asc.close()
            # Combine the fixation data lists into a dictionary
eye_data_testing_pic_0 = {
    'fix_x_t_position': fix_x_testing_0,
    'fix_y_t_position': fix_y_testing_0,
    'fix_t_duration': fix_duration_testing_0,
    'SACC_x_t_s_position': SACC_start_x_testing_0,
    'SACC_y_t_s_position': SACC_start_y_testing_0,
    'SACC_t_duration': SACC_duration_testing_0,
    'SACC_x_t_e_position': SACC_end_x_testing_0,
    'SACC_y_t_e_position': SACC_end_y_testing_0,
    'BLINK_t_duration': BLINK_duration_testing_0,
}

# Create a DataFrame from the fixation data dictionary
#df_fixations_0 = pd.DataFrame(fixation_data)

#df = pd.DataFrame.from_dict(d, orient='index')

#print(df)
df_data_testing_pic_0 = pd.DataFrame.from_dict(eye_data_testing_pic_0, orient='index')
print(df_data_testing_pic_0.T)

df_data_testing_pic_0 =df_data_testing_pic_0.T
# Print the first 10 rows of the DataFrame
#df_fixations_0
# Out:
#     fix_x_t_position  fix_y_t_position  fix_t_duration  SACC_x_t_s_position  \
# 0             1259.0             720.0            51.0               1246.0
# 1             1233.0             730.0           175.0               1231.0
# 2              593.0             585.0           135.0                589.0
# 3             1152.0             931.0           209.0               1148.0
# 4             1104.0             919.0           309.0               1108.0
# 5             1011.0             994.0           261.0               1008.0
# 6              955.0            1087.0           413.0                963.0
# 7              950.0            1153.0           165.0                943.0
# 8             1224.0            1340.0           208.0               1225.0
# 9             2627.0             512.0           162.0               2619.0
# 10            1906.0             364.0           186.0               1904.0
# 11            1933.0             577.0           158.0               1924.0
# 12            1968.0             265.0           209.0               1969.0
# 13            2079.0             199.0           225.0               2073.0
# 14            2132.0             152.0           321.0               2130.0
# 15            2173.0             259.0           244.0               2174.0
# 16            1208.0            1329.0           165.0               1216.0
# 17            2448.0             934.0           150.0               2443.0
# 18            1978.0             602.0           203.0               1965.0
# 19            1253.0             738.0            58.0               1257.0
# 20            1270.0             749.0           166.0               1264.0
# 21            1451.0             924.0           138.0               1444.0
# 22            1232.0            1356.0           357.0               1238.0
# 23            1972.0             551.0           111.0               1974.0
# 24            1920.0             599.0           508.0               1915.0
#
#     SACC_y_t_s_position  SACC_t_duration  SACC_x_t_e_position  \
# 0                 740.0              6.0               1232.0
# 1                 724.0             65.0                597.0
# 2                 580.0             43.0               1177.0
# 3                 932.0             18.0               1100.0
# 4                 904.0             45.0               1009.0
# 5                 994.0             31.0                942.0
# 6                1095.0             17.0                951.0
# 7                1159.0             33.0               1214.0
# 8                1334.0             15.0               1238.0
# 9                 512.0             54.0               1926.0
# 10                352.0             39.0               1944.0
# 11                571.0             40.0               1971.0
# 12                274.0             28.0               2087.0
# 13                205.0             23.0               2130.0
# 14                146.0             32.0               2175.0
# 15                259.0             71.0               1207.0
# 16               1327.0             21.0               1230.0
# 17                929.0             46.0               2012.0
# 18                602.0             20.0               1947.0
# 19                736.0             27.0               1272.0
# 20                745.0             36.0               1462.0
# 21                917.0             40.0               1233.0
# 22               1359.0             56.0               1989.0
# 23                548.0             24.0               1937.0
# 24                609.0             22.0               1918.0
#
#     SACC_y_t_e_position  BLINK_t_duration
# 0                 737.0               NaN
# 1                 593.0               NaN
# 2                 951.0               NaN
# 3                 926.0               NaN
# 4                 997.0               NaN
# 5                1076.0               NaN
# 6                1133.0               NaN
# 7                1345.0               NaN
# 8                1349.0               NaN
# 9                 377.0               NaN
# 10                587.0               NaN
# 11                263.0               NaN
# 12                193.0               NaN
# 13                160.0               NaN
# 14                250.0               NaN
# 15               1336.0               NaN
# 16               1381.0               NaN
# 17                616.0               NaN
# 18                571.0               NaN
# 19                746.0               NaN
# 20                937.0               NaN
# 21               1369.0               NaN
# 22                558.0               NaN
# 23                598.0               NaN
# 24                594.0               NaN

# %%
#3AFC stage pic_1   
asc = open(asc_file)

fix_x_testing_1 = [] # List of all x positions
fix_y_testing_1 = [] # List of all y positions
fix_duration_testing_1 = [] # List of all durations

SACC_start_x_testing_1 = []
SACC_start_y_testing_1 = []
SACC_duration_testing_1 = []
SACC_end_x_testing_1 = []
SACC_end_y_testing_1 = []

BLINK_duration_testing_1 = []

for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    if 'forcedchoice_start_1' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_testing = []
        fix_y_testing = []
        fix_duration_testing = []
        
        SACC_start_x_testing = []
        SACC_start_y_testing = []
        SACC_duration_testing = []
        SACC_end_x_testing = []
        SACC_end_y_testing = []
        
        BLINK_duration_testing = []
        
        
    if 'forcedchoice_end_1' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_testing_1.extend(fix_x_testing)
        fix_y_testing_1.extend(fix_y_testing)
        fix_duration_testing_1.extend(fix_duration_testing)
        
        SACC_start_x_testing_1.extend(SACC_start_x_testing)
        SACC_start_y_testing_1.extend(SACC_start_y_testing)
        SACC_duration_testing_1.extend(SACC_duration_testing) 
        SACC_end_x_testing_1.extend(SACC_end_x_testing)
        SACC_end_y_testing_1.extend(SACC_end_y_testing)
        
        BLINK_duration_testing_1.extend(BLINK_duration_testing)
    
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time,duration_t_f_1, x9, y9 = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_f_1 = duration_t_f_1 - (trial_start - start_time)
                    start_time = trial_start
            fix_x_testing_1.append(x9)
            fix_y_testing_1.append(y9)
            fix_duration_testing_1.append(duration_t_f_1) 
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity
        if 'ESACC' in line:
            start_time, end_time, duration_t_s_1, x10, y10,x11,y11 = [int(float(x)) for x in tmp_data[2:9]]
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_s_1 = duration_t_s_1 - (trial_start - start_time)
                    start_time = trial_start 
            SACC_start_x_testing_1.append(x10)
            SACC_start_y_testing_1.append(y10)
            SACC_duration_testing_1.append(duration_t_s_1)
            SACC_end_x_testing_1.append(x11)
            SACC_end_y_testing_1.append(y11)       
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

            start_time, end_time, duration_t_1_b = [int(float(x)) for x in tmp_data[2:]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_1_b = duration_t_1_b - (trial_start - start_time)
                    start_time = trial_start
            
            BLINK_duration_testing_1.append(duration_t_1_b)        
            
            
asc.close()
            # Combine the fixation data lists into a dictionary
eye_data_testing_pic_1 = {
    'fix_x_t_position': fix_x_testing_1,
    'fix_y_t_position': fix_y_testing_1,
    'fix_t_duration': fix_duration_testing_1,
    'SACC_x_t_s_position': SACC_start_x_testing_1,
    'SACC_y_t_s_position': SACC_start_y_testing_1,
    'SACC_t_duration': SACC_duration_testing_1,
    'SACC_x_t_e_position': SACC_end_x_testing_1,
    'SACC_y_t_e_position': SACC_end_y_testing_1,
    'BLINK_t_duration': BLINK_duration_testing_1,
}

# Create a DataFrame from the fixation data dictionary
df_data_testing_pic_1 = pd.DataFrame.from_dict(eye_data_testing_pic_1, orient='index')
print(df_data_testing_pic_1.T)
df_data_testing_pic_1 = df_data_testing_pic_1.T
# Print the first 10 rows of the DataFrame
#df_fixations_1
# Out:
#     fix_x_t_position  fix_y_t_position  fix_t_duration  SACC_x_t_s_position  \
# 0             1311.0             734.0           186.0               1305.0
# 1             1253.0            1333.0           276.0               1243.0
# 2             1184.0             114.0           173.0                250.0
# 3              656.0             422.0           107.0               1175.0
# 4              572.0             576.0           248.0                652.0
# 5              565.0             607.0           294.0                572.0
# 6              568.0             594.0          1518.0                565.0
# 7              561.0             605.0          1451.0                566.0
# 8             1271.0             708.0           164.0                567.0
# 9             1258.0             944.0           217.0               1274.0
# 10            1234.0            1350.0           443.0               1246.0
# 11            1315.0             955.0           220.0               1243.0
# 12            1433.0             953.0           331.0               1319.0
# 13            1392.0             961.0           237.0               1434.0
# 14            2359.0             452.0           170.0               1389.0
# 15            2036.0             477.0           160.0               2350.0
# 16            1948.0             600.0           175.0               2034.0
# 17            1235.0            1346.0           305.0               1937.0
# 18            1282.0             701.0           227.0               1235.0
# 19            1298.0             957.0           184.0               1272.0
# 20            1234.0            1337.0           150.0               1296.0
# 21             571.0             601.0          1695.0               1233.0
# 22               NaN               NaN             NaN                586.0
#
#     SACC_y_t_s_position  SACC_t_duration  SACC_x_t_e_position  \
# 0                 739.0             46.0               1271.0
# 1                1331.0             13.0               1247.0
# 2                 229.0             43.0               1200.0
# 3                 113.0             49.0                662.0
# 4                 417.0             37.0                581.0
# 5                 580.0             14.0                559.0
# 6                 611.0              9.0                573.0
# 7                 587.0              4.0                564.0
# 8                 604.0              8.0                583.0
# 9                 698.0             47.0               1281.0
# 10                951.0             44.0               1240.0
# 11               1348.0             49.0               1312.0
# 12                961.0             26.0               1438.0
# 13                960.0             22.0               1390.0
# 14                953.0             41.0               1933.0
# 15                450.0             49.0               2041.0
# 16                471.0             35.0               1958.0
# 17                600.0             56.0               1228.0
# 18               1344.0             15.0               1240.0
# 19                711.0             32.0               1308.0
# 20                952.0             42.0               1239.0
# 21               1334.0             58.0                559.0
# 22                600.0             10.0                578.0
#
#     SACC_y_t_e_position  BLINK_t_duration
# 0                1329.0               NaN
# 1                1360.0               NaN
# 2                 124.0               NaN
# 3                 427.0               NaN
# 4                 582.0               NaN
# 5                 604.0               NaN
# 6                 596.0               NaN
# 7                 595.0               NaN
# 8                 597.0               NaN
# 9                 942.0               NaN
# 10               1366.0               NaN
# 11                959.0               NaN
# 12                946.0               NaN
# 13                959.0               NaN
# 14                601.0               NaN
# 15                480.0               NaN
# 16                608.0               NaN
# 17               1356.0               NaN
# 18               1357.0               NaN
# 19                962.0               NaN
# 20               1351.0               NaN
# 21                576.0               NaN
# 22                623.0               NaN

# %%
#3AFC stage pic_2
asc = open(asc_file)

fix_x_testing_2 = [] # List of all x positions
fix_y_testing_2 = [] # List of all y positions
fix_duration_testing_2 = [] # List of all durations

SACC_start_x_testing_2 = []
SACC_start_y_testing_2 = []
SACC_duration_testing_2 = []
SACC_end_x_testing_2 = []
SACC_end_y_testing_2 = []

BLINK_duration_testing_2 = []

new_trial = False
for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    if 'forcedchoice_start_2' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_testing = []
        fix_y_testing = []
        fix_duration_testing = []
        
        SACC_start_x_testing = []
        SACC_start_y_testing = []
        SACC_duration_testing = []
        SACC_end_x_testing = []
        SACC_end_y_testing = []
        
        BLINK_duration_testing = []
        
    if 'forcedchoice_end_2' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_testing_2.extend(fix_x_testing)
        fix_y_testing_2.extend(fix_y_testing)
        fix_duration_testing_2.extend(fix_duration_testing)
        
        SACC_start_x_testing_2.extend(SACC_start_x_testing)
        SACC_start_y_testing_2.extend(SACC_start_y_testing)
        SACC_duration_testing_2.extend(SACC_duration_testing) 
        SACC_end_x_testing_2.extend(SACC_end_x_testing)
        SACC_end_y_testing_2.extend(SACC_end_y_testing)
        
        BLINK_duration_testing_2.extend(BLINK_duration_testing)
        
    
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time, duration_t_f_2, x12, y12 = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_f_2 = duration_t_f_2 - (trial_start - start_time)
                    start_time = trial_start
            fix_x_testing_2.append(x12)
            fix_y_testing_2.append(y12)
            fix_duration_testing_2.append(duration_t_f_2) 
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity
        if 'ESACC' in line:
            start_time, end_time, duration_t_s_2, x13, y13,x14,y14 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_s_2 = duration_t_s_2 - (trial_start - start_time)
                    start_time = trial_start
            SACC_start_x_testing_2.append(x13)
            SACC_start_y_testing_2.append(y13)
            SACC_duration_testing_2.append(duration_t_s_2)
            SACC_end_x_testing_2.append(x14)
            SACC_end_y_testing_2.append(y14)
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

            start_time, end_time, duration_t_2_b = [int(float(x)) for x in tmp_data[2:]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_2_b = duration_t_2_b - (trial_start - start_time)
                    start_time = trial_start
            
            BLINK_duration_testing_2.append(duration_t_2_b)
                      
asc.close()
            # Combine the fixation data lists into a dictionary
eye_data_testing_pic_2 = {
    'fix_x_t_position': fix_x_testing_2,
    'fix_y_t_position': fix_y_testing_2,
    'fix_t_duration': fix_duration_testing_2,
    'SACC_x_t_s_position': SACC_start_x_testing_2,
    'SACC_y_t_s_position': SACC_start_y_testing_2,
    'SACC_t_duration': SACC_duration_testing_2,
    'SACC_x_t_e_position': SACC_end_x_testing_2,
    'SACC_y_t_e_position': SACC_end_y_testing_2,
    'BLINK_t_duration': BLINK_duration_testing_2,
}

# Create a DataFrame from the fixation data dictionary
#df_fixations_0 = pd.DataFrame(fixation_data)

#df = pd.DataFrame.from_dict(d, orient='index')

#print(df)
df_data_testing_pic_2 = pd.DataFrame.from_dict(eye_data_testing_pic_2, orient='index')
print(df_data_testing_pic_2.T)
df_data_testing_pic_2 =df_data_testing_pic_2.T
# Print the first 10 rows of the DataFrame
#df_fixations_2
# Out:
#      fix_x_t_position  fix_y_t_position  fix_t_duration  SACC_x_t_s_position  \
# 0              1895.0            1334.0            61.0               1255.0
# 1              1281.0             958.0           197.0               1891.0
# 2              1236.0            1356.0           206.0               1272.0
# 3              1060.0             875.0           448.0               1237.0
# 4               969.0             873.0           334.0               1060.0
# ..                ...               ...             ...                  ...
# 171             624.0             588.0           230.0                605.0
# 172             775.0             218.0           204.0                770.0
# 173             681.0             201.0           270.0                682.0
# 174             680.0             157.0           376.0                682.0
# 175            1842.0             308.0           156.0               1838.0
#
#      SACC_y_t_s_position  SACC_t_duration  SACC_x_t_e_position  \
# 0                  717.0            100.0               1898.0
# 1                 1332.0             52.0               1294.0
# 2                  956.0             38.0               1242.0
# 3                 1357.0             52.0               1060.0
# 4                  873.0             32.0                970.0
# ..                   ...              ...                  ...
# 171                599.0             42.0                793.0
# 172                219.0             37.0                682.0
# 173                204.0             18.0                677.0
# 174                159.0             63.0               1868.0
# 175                306.0             32.0               1940.0
#
#      SACC_y_t_e_position  BLINK_t_duration
# 0                 1322.0              37.0
# 1                  969.0              83.0
# 2                 1359.0             541.0
# 3                  874.0             104.0
# 4                  875.0              66.0
# ..                   ...               ...
# 171                209.0               NaN
# 172                199.0               NaN
# 173                165.0               NaN
# 174                319.0               NaN
# 175                593.0               NaN
#
# [176 rows x 9 columns]

# %%
#3AFC stage pic_3

asc = open(asc_file)

fix_x_testing_3 = [] # List of all x positions
fix_y_testing_3 = [] # List of all y positions
fix_duration_testing_3 = [] # List of all durations

SACC_start_x_testing_3 = []
SACC_start_y_testing_3 = []
SACC_duration_testing_3 = []
SACC_end_x_testing_3 = []
SACC_end_y_testing_3 = []

BLINK_duration_testing_3 = []

for line in asc:
    # Convert the current data line into a list
    tmp_data = line.rstrip().split()
    # Get the correct screen resolution from the DISPLAY_COORDS message
    # MSG    4302897 DISPLAY_COORDS 0 0 2559 1439
    if 'DISPLAY_COORDS' in line: 
        scn_w = int(tmp_data[-2]) + 1 
        scn_h = int(tmp_data[-1]) + 1
    # Look for the message marking image onset 
    if 'forcedchoice_start_3' in line:
        trial_start = int(float(tmp_data[1]))
        new_trial = True
        # Store the position and duration of all fixations in lists
        fix_x_testing = []
        fix_y_testing = []
        fix_duration_testing = []
        
        SACC_start_x_testing = []
        SACC_start_y_testing = []
        SACC_duration_testing = []
        SACC_end_x_testing = []
        SACC_end_y_testing = []
        
        BLINK_duration_testing = []
        
    if 'forcedchoice_end_3' in line:
        new_trial = False
        # Add the fixation data for this trial to the all-trials lists
        fix_x_testing_3.extend(fix_x_testing)
        fix_y_testing_3.extend(fix_y_testing)
        fix_duration_testing_3.extend(fix_duration_testing)
        
        SACC_start_x_testing_3.extend(SACC_start_x_testing)
        SACC_start_y_testing_3.extend(SACC_start_y_testing)
        SACC_duration_testing_3.extend(SACC_duration_testing) 
        SACC_end_x_testing_3.extend(SACC_end_x_testing)
        SACC_end_y_testing_3.extend(SACC_end_y_testing)
        
        BLINK_duration_testing_3.extend(BLINK_duration_testing)
    
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EFIX' in line:
            # EFIX R   349482768	349482935	167	 1312.5	  729.7	   3770
            start_time, end_time, duration_t_f_3, x15, y15 = [int(float(x)) for x in tmp_data[2:7]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_f_3 = duration_t_f_3 - (trial_start - start_time)
                    start_time = trial_start
            fix_x_testing.append(x15)
            fix_y_testing.append(y15)
            fix_duration_testing.append(duration_t_f_3) 
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        #ESACC R  554166	554204	38	 1207.8	  978.0	 1293.4	  761.3	   8.32	amplitude    517 velocity
        if 'ESACC' in line:
            start_time, end_time, duration_t_s_3, x16, y16,x17,y17 = [int(float(x)) for x in tmp_data[2:9]] 
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_s_3 = duration_t_s_3 - (trial_start - start_time)
                    start_time = trial_start
            SACC_start_x_testing_3.append(x16)
            SACC_start_y_testing_3.append(y16)
            SACC_duration_testing_3.append(duration_t_s_3)
            SACC_end_x_testing_3.append(x17)
            SACC_end_y_testing_3.append(y17)
            
    if new_trial:
        # Path to the background image
        # MSG 3558923 !V IMGLOAD FILL images/woods.jpg 
        if 'EBLINK' in line:
            #EBLINK R 565909	565986	77

            start_time, end_time, duration_t_3_b = [int(float(x)) for x in tmp_data[2:]]
            if start_time < trial_start :
                # Adjust the start time and duration of the fixation
                    duration_t_3_b = duration_t_3_b - (trial_start - start_time)
                    start_time = trial_start 
            
            BLINK_duration_testing_3.append(duration_t_3_b)
                      
asc.close()
            # Combine the fixation data lists into a dictionary
eye_data_testing_pic_3 = {
    'fix_x_t_position': fix_x_testing_3,
    'fix_y_t_position': fix_y_testing_3,
    'fix_t_duration': fix_duration_testing_3,
    'SACC_x_t_s_position': SACC_start_x_testing_3,
    'SACC_y_t_s_position': SACC_start_y_testing_3,
    'SACC_t_duration': SACC_duration_testing_3,
    'SACC_x_t_e_position': SACC_end_x_testing_3,
    'SACC_y_t_e_position': SACC_end_y_testing_3,
    'BLINK_t_duration': BLINK_duration_testing_3,
}

# Create a DataFrame from the fixation data dictionary
#df_fixations_0 = pd.DataFrame(fixation_data)

#df = pd.DataFrame.from_dict(d, orient='index')

#print(df)
df_data_testing_pic_3 = pd.DataFrame.from_dict(eye_data_testing_pic_3, orient='index')
print(df_data_testing_pic_3.T)
df_data_testing_pic_3 =df_data_testing_pic_3.T

# Print the first 10 rows of the DataFrame
#df_fixations_3
# Out:
#     fix_x_t_position  fix_y_t_position  fix_t_duration  SACC_x_t_s_position  \
# 0             2313.0             854.0           149.0               2309.0
# 1             1914.0             620.0           139.0               1911.0
# 2             1951.0             602.0           258.0               1946.0
# 3             1940.0             611.0           322.0               1944.0
# 4             1286.0             709.0           256.0               1266.0
# 5             1322.0             884.0           170.0               1320.0
# 6             1255.0            1323.0           196.0               1252.0
# 7             1113.0             886.0           202.0               1117.0
# 8              584.0             602.0           206.0                586.0
# 9              568.0             581.0          1941.0                583.0
# 10             562.0             584.0          1376.0                571.0
# 11             595.0             571.0           240.0                588.0
# 12             512.0             178.0           184.0                508.0
# 13             680.0             217.0           144.0                667.0
# 14             361.0             175.0           167.0                361.0
# 15             566.0             203.0            79.0                560.0
# 16             595.0             568.0           173.0                591.0
# 17             578.0             601.0           130.0                574.0
# 18            1273.0             989.0           142.0               1266.0
# 19            1255.0            1322.0           203.0               1249.0
#
#     SACC_y_t_s_position  SACC_t_duration  SACC_x_t_e_position  \
# 0                 850.0             53.0               1905.0
# 1                 619.0             19.0               1962.0
# 2                 597.0              8.0               1941.0
# 3                 602.0             14.0               1939.0
# 4                 705.0             30.0               1332.0
# 5                 882.0             39.0               1254.0
# 6                1328.0             47.0               1104.0
# 7                 885.0             57.0                582.0
# 8                 589.0             12.0                570.0
# 9                 578.0              9.0                567.0
# 10                579.0             14.0                600.0
# 11                570.0              7.0                574.0
# 12                181.0             36.0                687.0
# 13                214.0             42.0                578.0
# 14                178.0             28.0                565.0
# 15                198.0             37.0                611.0
# 16                568.0             15.0                579.0
# 17                602.0             44.0               1290.0
# 18                990.0             46.0               1264.0
# 19               1320.0             15.0               1238.0
#
#     SACC_y_t_e_position  BLINK_t_duration
# 0                 622.0               NaN
# 1                 605.0               NaN
# 2                 614.0               NaN
# 3                 580.0               NaN
# 4                 878.0               NaN
# 5                1328.0               NaN
# 6                 887.0               NaN
# 7                 598.0               NaN
# 8                 590.0               NaN
# 9                 584.0               NaN
# 10                579.0               NaN
# 11                571.0               NaN
# 12                213.0               NaN
# 13                605.0               NaN
# 14                197.0               NaN
# 15                583.0               NaN
# 16                594.0               NaN
# 17                998.0               NaN
# 18               1326.0               NaN
# 19               1348.0               NaN

# %%
df_testing = pd.concat([df_data_testing_pic_0, df_data_testing_pic_1, df_data_testing_pic_2, df_data_testing_pic_3]).reset_index()
df_testing
# Out:
#      index  fix_x_t_position  fix_y_t_position  fix_t_duration  \
# 0        0            1259.0             720.0            51.0
# 1        1            1233.0             730.0           175.0
# 2        2             593.0             585.0           135.0
# 3        3            1152.0             931.0           209.0
# 4        4            1104.0             919.0           309.0
# ..     ...               ...               ...             ...
# 239     15             566.0             203.0            79.0
# 240     16             595.0             568.0           173.0
# 241     17             578.0             601.0           130.0
# 242     18            1273.0             989.0           142.0
# 243     19            1255.0            1322.0           203.0
#
#      SACC_x_t_s_position  SACC_y_t_s_position  SACC_t_duration  \
# 0                 1246.0                740.0              6.0
# 1                 1231.0                724.0             65.0
# 2                  589.0                580.0             43.0
# 3                 1148.0                932.0             18.0
# 4                 1108.0                904.0             45.0
# ..                   ...                  ...              ...
# 239                560.0                198.0             37.0
# 240                591.0                568.0             15.0
# 241                574.0                602.0             44.0
# 242               1266.0                990.0             46.0
# 243               1249.0               1320.0             15.0
#
#      SACC_x_t_e_position  SACC_y_t_e_position  BLINK_t_duration
# 0                 1232.0                737.0               NaN
# 1                  597.0                593.0               NaN
# 2                 1177.0                951.0               NaN
# 3                 1100.0                926.0               NaN
# 4                 1009.0                997.0               NaN
# ..                   ...                  ...               ...
# 239                611.0                583.0               NaN
# 240                579.0                594.0               NaN
# 241               1290.0                998.0               NaN
# 242               1264.0               1326.0               NaN
# 243               1238.0               1348.0               NaN
#
# [244 rows x 10 columns]

# %%
df_testing = pd.concat([df_data_testing_pic_0, df_data_testing_pic_1, df_data_testing_pic_2, df_data_testing_pic_3]).reset_index()

df_eye_t = {'fix_t_duration':[], 'fix_x_t':[], 'fix_y_t':[],
         'SACC_t_duration':[], 
          'BLINK_t_duration':[], 
          'region_t':[],
         }

for i in range(0,len(df_testing)):
    df_eye_t['fix_t_duration'].append(df_testing['fix_t_duration'][i])
    df_eye_t['fix_x_t'].append(df_testing['fix_x_t_position'][i])
    df_eye_t['fix_y_t'].append(df_testing['fix_y_t_position'][i])
    if 352< df_testing['fix_x_t_position'][i] <928 and 92< df_testing['fix_y_t_position'][i] <412:
        df_eye_t['region_t'].append('left')
    elif 1632< df_testing['fix_x_t_position'][i] <2208 and 92< df_testing['fix_y_t_position'][i] <412:
        df_eye_t['region_t'].append('right')
    elif 992< df_testing['fix_x_t_position'][i] <1568 and 812< df_testing['fix_y_t_position'][i] <1132:
        df_eye_t['region_t'].append('bottom')
    else:
        df_eye_t['region_t'].append('N/A')
            
        
    df_eye_t['SACC_t_duration'].append(df_testing['SACC_t_duration'][i])

    df_eye_t['BLINK_t_duration'].append(df_testing['BLINK_t_duration'][i])
    
        
df_eye_t = pd.DataFrame.from_dict(df_eye_t, orient='index')
print(df_eye_t.T)
df_eye_t = df_eye_t.T
print(df_eye_t)

#df_eye_t.to_csv('df_eye_testing_030705.csv')
# Out:
#     fix_t_duration fix_x_t fix_y_t SACC_t_duration BLINK_t_duration region_t
# 0             51.0  1259.0   720.0             6.0              NaN      N/A
# 1            175.0  1233.0   730.0            65.0              NaN      N/A
# 2            135.0   593.0   585.0            43.0              NaN      N/A
# 3            209.0  1152.0   931.0            18.0              NaN   bottom
# 4            309.0  1104.0   919.0            45.0              NaN   bottom
# ..             ...     ...     ...             ...              ...      ...
# 239           79.0   566.0   203.0            37.0              NaN     left
# 240          173.0   595.0   568.0            15.0              NaN      N/A
# 241          130.0   578.0   601.0            44.0              NaN      N/A
# 242          142.0  1273.0   989.0            46.0              NaN   bottom
# 243          203.0  1255.0  1322.0            15.0              NaN      N/A
#
# [244 rows x 6 columns]
#     fix_t_duration fix_x_t fix_y_t SACC_t_duration BLINK_t_duration region_t
# 0             51.0  1259.0   720.0             6.0              NaN      N/A
# 1            175.0  1233.0   730.0            65.0              NaN      N/A
# 2            135.0   593.0   585.0            43.0              NaN      N/A
# 3            209.0  1152.0   931.0            18.0              NaN   bottom
# 4            309.0  1104.0   919.0            45.0              NaN   bottom
# ..             ...     ...     ...             ...              ...      ...
# 239           79.0   566.0   203.0            37.0              NaN     left
# 240          173.0   595.0   568.0            15.0              NaN      N/A
# 241          130.0   578.0   601.0            44.0              NaN      N/A
# 242          142.0  1273.0   989.0            46.0              NaN   bottom
# 243          203.0  1255.0  1322.0            15.0              NaN      N/A
#
# [244 rows x 6 columns]

# %%
fix_t_left = df_eye_t[df_eye_t['region_t']=='left']['fix_t_duration'].sum()
fix_t_right = df_eye_t[df_eye_t['region_t']=='right']['fix_t_duration'].sum()
fix_t_bottom = df_eye_t[df_eye_t['region_t']=='bottom']['fix_t_duration'].sum()

fix_t_on_pic = df_eye_t[df_eye_t['region_t']!='N/A']['fix_t_duration'].sum()
fix_t_off_pic = df_eye_t[df_eye_t['region_t']=='N/A']['fix_t_duration'].sum()
fix_t_total = df_eye_t['fix_t_duration'].sum()

SACC_t_total = df_eye_t['SACC_t_duration'].sum()

BLINK_t_total = df_eye_t['BLINK_t_duration'].sum()

#eye_t_total = fix_t_total+SACC_t_total+BLINK_t_total
eye_t_total = fix_t_total+SACC_t_total
percent_fix_t_on_pic = fix_t_on_pic/fix_t_total

percent_fix_t_off_pic = fix_t_off_pic/fix_t_total

df_eye_t['percent_fix_t_on_pic'] = percent_fix_t_on_pic
df_eye_t['percent_fix_t_off_pic'] = percent_fix_t_off_pic
df_eye_t['fix_t_total'] = fix_t_total
df_eye_t['SACC_t_total'] = SACC_t_total
df_eye_t['BLINK_t_total'] = BLINK_t_total
df_eye_t['eye_t_total'] = eye_t_total

df_eye_t['fix_t_left'] = fix_t_left
df_eye_t['fix_t_right'] = fix_t_right
df_eye_t['fix_t_bottom'] = fix_t_bottom
df_eye_t['fix_t_on_pic'] = fix_t_on_pic
df_eye_t['fix_t_off_pic'] = fix_t_off_pic

df_eye_testing=df_eye_t
df_eye_testing
# Out:
#     fix_t_duration fix_x_t fix_y_t SACC_t_duration BLINK_t_duration region_t  \
# 0             51.0  1259.0   720.0             6.0              NaN      N/A
# 1            175.0  1233.0   730.0            65.0              NaN      N/A
# 2            135.0   593.0   585.0            43.0              NaN      N/A
# 3            209.0  1152.0   931.0            18.0              NaN   bottom
# 4            309.0  1104.0   919.0            45.0              NaN   bottom
# ..             ...     ...     ...             ...              ...      ...
# 239           79.0   566.0   203.0            37.0              NaN     left
# 240          173.0   595.0   568.0            15.0              NaN      N/A
# 241          130.0   578.0   601.0            44.0              NaN      N/A
# 242          142.0  1273.0   989.0            46.0              NaN   bottom
# 243          203.0  1255.0  1322.0            15.0              NaN      N/A
#
#      percent_fix_t_on_pic  percent_fix_t_off_pic  fix_t_total  SACC_t_total  \
# 0                0.192035               0.807965      95540.0       12374.0
# 1                0.192035               0.807965      95540.0       12374.0
# 2                0.192035               0.807965      95540.0       12374.0
# 3                0.192035               0.807965      95540.0       12374.0
# 4                0.192035               0.807965      95540.0       12374.0
# ..                    ...                    ...          ...           ...
# 239              0.192035               0.807965      95540.0       12374.0
# 240              0.192035               0.807965      95540.0       12374.0
# 241              0.192035               0.807965      95540.0       12374.0
# 242              0.192035               0.807965      95540.0       12374.0
# 243              0.192035               0.807965      95540.0       12374.0
#
#      BLINK_t_total  eye_t_total  fix_t_left  fix_t_right  fix_t_bottom  \
# 0           1131.0     107914.0      7222.0       6681.0        4444.0
# 1           1131.0     107914.0      7222.0       6681.0        4444.0
# 2           1131.0     107914.0      7222.0       6681.0        4444.0
# 3           1131.0     107914.0      7222.0       6681.0        4444.0
# 4           1131.0     107914.0      7222.0       6681.0        4444.0
# ..             ...          ...         ...          ...           ...
# 239         1131.0     107914.0      7222.0       6681.0        4444.0
# 240         1131.0     107914.0      7222.0       6681.0        4444.0
# 241         1131.0     107914.0      7222.0       6681.0        4444.0
# 242         1131.0     107914.0      7222.0       6681.0        4444.0
# 243         1131.0     107914.0      7222.0       6681.0        4444.0
#
#      fix_t_on_pic  fix_t_off_pic
# 0         18347.0        77193.0
# 1         18347.0        77193.0
# 2         18347.0        77193.0
# 3         18347.0        77193.0
# 4         18347.0        77193.0
# ..            ...            ...
# 239       18347.0        77193.0
# 240       18347.0        77193.0
# 241       18347.0        77193.0
# 242       18347.0        77193.0
# 243       18347.0        77193.0
#
# [244 rows x 17 columns]

# %%
print(fix_t_left, fix_t_right, fix_t_bottom, fix_t_total, SACC_t_total, BLINK_t_total)
print(percent_fix_t_on_pic, percent_fix_t_off_pic, SACC_t_total, BLINK_t_total)
# Out:
# 7222.0 6681.0 4444.0 95540.0 12374.0 1131.0
# 0.1920347498429977 0.8079652501570023 12374.0 1131.0

# %%
df_eye_all = pd.concat([df_eye_encoding, df_eye_testing]).reset_index()
df_eye_all 
df_eye_all.to_csv(r'D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022306.csv')

# %%
# can paste csv in here for combination


#block_6 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022306.csv')
block_5 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022305.csv')
block_4 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022304.csv')
block_3 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022303.csv')
block_2 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022302.csv')
block_1 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J022301.csv')

df_all = pd.concat([block_1,block_2,block_3,block_4,block_5]).reset_index()
df_all.to_csv(r'D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0223.csv')
df_all
# Out:
#       level_0  Unnamed: 0  index  fix_e_duration  fix_x_e  fix_y_e  \
# 0           0           0      0            38.0    302.0    485.0
# 1           1           1      1            52.0    300.0    479.0
# 2           2           2      2           161.0   1247.0    685.0
# 3           3           3      3           242.0   1352.0    680.0
# 4           4           4      4           513.0   1130.0    671.0
# ...       ...         ...    ...             ...      ...      ...
# 1584      342         342    163             NaN      NaN      NaN
# 1585      343         343    164             NaN      NaN      NaN
# 1586      344         344    165             NaN      NaN      NaN
# 1587      345         345    166             NaN      NaN      NaN
# 1588      346         346    167             NaN      NaN      NaN
#
#       SACC_e_duration  BLINK_e_duration   region_e  percent_fix_e_on_pic  ...  \
# 0                49.0               5.0  off_pic_e              0.482936  ...
# 1                 9.0               NaN  off_pic_e              0.482936  ...
# 2                60.0               NaN   on_pic_e              0.482936  ...
# 3                28.0               NaN   on_pic_e              0.482936  ...
# 4                30.0               NaN   on_pic_e              0.482936  ...
# ...               ...               ...        ...                   ...  ...
# 1584              NaN               NaN        NaN                   NaN  ...
# 1585              NaN               NaN        NaN                   NaN  ...
# 1586              NaN               NaN        NaN                   NaN  ...
# 1587              NaN               NaN        NaN                   NaN  ...
# 1588              NaN               NaN        NaN                   NaN  ...
#
#       percent_fix_t_off_pic  fix_t_total  SACC_t_total  BLINK_t_total  \
# 0                       NaN          NaN           NaN            NaN
# 1                       NaN          NaN           NaN            NaN
# 2                       NaN          NaN           NaN            NaN
# 3                       NaN          NaN           NaN            NaN
# 4                       NaN          NaN           NaN            NaN
# ...                     ...          ...           ...            ...
# 1584               0.742619      55754.0        7526.0          308.0
# 1585               0.742619      55754.0        7526.0          308.0
# 1586               0.742619      55754.0        7526.0          308.0
# 1587               0.742619      55754.0        7526.0          308.0
# 1588               0.742619      55754.0        7526.0          308.0
#
#       eye_t_total  fix_t_left  fix_t_right  fix_t_bottom  fix_t_on_pic  \
# 0             NaN         NaN          NaN           NaN           NaN
# 1             NaN         NaN          NaN           NaN           NaN
# 2             NaN         NaN          NaN           NaN           NaN
# 3             NaN         NaN          NaN           NaN           NaN
# 4             NaN         NaN          NaN           NaN           NaN
# ...           ...         ...          ...           ...           ...
# 1584      63280.0      2338.0       2615.0        9397.0       14350.0
# 1585      63280.0      2338.0       2615.0        9397.0       14350.0
# 1586      63280.0      2338.0       2615.0        9397.0       14350.0
# 1587      63280.0      2338.0       2615.0        9397.0       14350.0
# 1588      63280.0      2338.0       2615.0        9397.0       14350.0
#
#       fix_t_off_pic
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1584        41404.0
# 1585        41404.0
# 1586        41404.0
# 1587        41404.0
# 1588        41404.0
#
# [1589 rows x 36 columns]

# %%
# # can paste csv in here for combination
block_13 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0223.csv').drop(columns=['level_0'])
block_12 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0224.csv').drop(columns=['level_0'])
block_11 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0225.csv').drop(columns=['level_0'])
block_10 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0226.csv').drop(columns=['level_0'])
block_9 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0227.csv').drop(columns=['level_0'])
block_8 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0228.csv').drop(columns=['level_0'])
block_7 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0301.csv').drop(columns=['level_0'])
block_6 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0302.csv').drop(columns=['level_0'])
block_5 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0303.csv').drop(columns=['level_0'])
block_4 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0304.csv').drop(columns=['level_0'])
block_3 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0305.csv').drop(columns=['level_0'])
block_2 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0306.csv').drop(columns=['level_0'])
block_1 = pd.read_csv('D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J0307.csv').drop(columns=['level_0'])

df_all_1 = pd.concat([block_1,block_2,block_3,block_4,block_5,block_6,block_7,block_8,block_9,block_10,block_11,block_12,block_13]).reset_index()
df_all_1.to_csv(r'D:/Jupiter_eyemovement_data/Pic_TOJ/formal/SESSION1/CSV/J_SESSION1_ALL.csv')
df_all_1
# Out:
#        level_0  Unnamed: 0  Unnamed: 0.1  index  fix_e_duration  fix_x_e  \
# 0            0           0             0      0           181.0   1266.0
# 1            1           1             1      1           199.0   1230.0
# 2            2           2             2      2           240.0   1001.0
# 3            3           3             3      3           233.0   1058.0
# 4            4           4             4      4           250.0   1217.0
# ...        ...         ...           ...    ...             ...      ...
# 20795     1584        1584           342    163             NaN      NaN
# 20796     1585        1585           343    164             NaN      NaN
# 20797     1586        1586           344    165             NaN      NaN
# 20798     1587        1587           345    166             NaN      NaN
# 20799     1588        1588           346    167             NaN      NaN
#
#        fix_y_e  SACC_e_duration  BLINK_e_duration  region_e  ...  \
# 0        715.0             28.0              28.0  on_pic_e  ...
# 1        593.0             29.0             130.0  on_pic_e  ...
# 2        612.0             19.0               NaN  on_pic_e  ...
# 3        661.0             29.0               NaN  on_pic_e  ...
# 4        617.0             28.0               NaN  on_pic_e  ...
# ...        ...              ...               ...       ...  ...
# 20795      NaN              NaN               NaN       NaN  ...
# 20796      NaN              NaN               NaN       NaN  ...
# 20797      NaN              NaN               NaN       NaN  ...
# 20798      NaN              NaN               NaN       NaN  ...
# 20799      NaN              NaN               NaN       NaN  ...
#
#        percent_fix_t_off_pic  fix_t_total  SACC_t_total  BLINK_t_total  \
# 0                        NaN          NaN           NaN            NaN
# 1                        NaN          NaN           NaN            NaN
# 2                        NaN          NaN           NaN            NaN
# 3                        NaN          NaN           NaN            NaN
# 4                        NaN          NaN           NaN            NaN
# ...                      ...          ...           ...            ...
# 20795               0.742619      55754.0        7526.0          308.0
# 20796               0.742619      55754.0        7526.0          308.0
# 20797               0.742619      55754.0        7526.0          308.0
# 20798               0.742619      55754.0        7526.0          308.0
# 20799               0.742619      55754.0        7526.0          308.0
#
#        eye_t_total  fix_t_left  fix_t_right  fix_t_bottom  fix_t_on_pic  \
# 0              NaN         NaN          NaN           NaN           NaN
# 1              NaN         NaN          NaN           NaN           NaN
# 2              NaN         NaN          NaN           NaN           NaN
# 3              NaN         NaN          NaN           NaN           NaN
# 4              NaN         NaN          NaN           NaN           NaN
# ...            ...         ...          ...           ...           ...
# 20795      63280.0      2338.0       2615.0        9397.0       14350.0
# 20796      63280.0      2338.0       2615.0        9397.0       14350.0
# 20797      63280.0      2338.0       2615.0        9397.0       14350.0
# 20798      63280.0      2338.0       2615.0        9397.0       14350.0
# 20799      63280.0      2338.0       2615.0        9397.0       14350.0
#
#        fix_t_off_pic
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 20795        41404.0
# 20796        41404.0
# 20797        41404.0
# 20798        41404.0
# 20799        41404.0
#
# [20800 rows x 37 columns]
